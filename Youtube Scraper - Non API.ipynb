# %%
import requests
import random
import pandas as pd
import re
import json
import datetime as dt
import time
from bs4 import BeautifulSoup
from headers import headers_list
from loading_bar import log_progress
from data_skills import DATA_SKILLS, SKILL_DICT
from skill_extraction import extract_skills, extract_ignore, extract_data_skills

# %%
base_url = 'https://www.youtube.com'
# Dictionary for filtering search query
sp_dict = {'this_year': 'EgQIBRAB', 'this_month': 'EgQIBBAB', 'this_week': 'EgQIAxAB', 'today': 'EgQIAhAB'}
url = base_url + '/results'

# %%
skill = 'Python'
query = 'learn ' + skill
params = {'search_query': query.replace(' ', '+'), 'sp': sp_dict['this_year']}
page = requests.get(url, params=params, headers=random.choice(headers_list))
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
json_text = str(soup.find_all('script')).split('var ytInitialData = ')[-1].split(';</script>')[0]
res = json.loads(json_text)
res = res['contents']['twoColumnSearchResultsRenderer']['primaryContents']['sectionListRenderer']['contents']

# %%
res
# Out:
# [{'itemSectionRenderer': {'contents': [{'promotedSparklesWebRenderer': {'thumbnail': {'thumbnails': [{'url': 'https://tpc.googlesyndication.com/simgad/8311815406293556737',
#          'width': 1955,
#          'height': 1024}]},
#       'title': {'simpleText': 'Coding Class for Kids & Teens - Ages 5 to 18 | Online Access'},
#       'description': {'simpleText': '6000+ Students, Open 7 Days, 10am-6pm. Coding, Mobile, Electronics, Robotics, and More'},
#       'websiteText': {'simpleText': 'https://www.kidocode.com/apply/trial-class'},
#       'navigationEndpoint': {'clickTrackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#        'loggingUrls': [{'baseUrl': 'https://www.youtube.com/pagead/paralleladinteraction?ai=CAqZ4ItKWYpThHsermsMPybqS2A8Aja7W77cLABABIABgywOCARNwYXJ0bmVyLXlvdXR1YmUtc3JwqAMEqgQXT9AOeOGYkCuKBX4bLLvRwH2TGhl4yAOQBwSoB4QIqAfOp7EC0ggOCIBBEAEYADICggI6AQCwCwG6CzgIAxAFGAwgCCgFMAVAAUgAWE5gAGgAcAGIAQCQAQGYAQGiAQgKAJgCAqgCAcABAdABAeABAYACAaAXAQ&sigh=Wvxrp_rKTgY&cid=CAASFeRoSeUvf5q_qOE4vT3iXHlg4W8-_Q&ad_mt=[AD_MT]&acvw=[VIEWABILITY]&gv=[GOOGLE_VIEWABILITY]&nb=%5BNB%5D&label=video_click_to_advertiser_site'}],
#        'commandMetadata': {'webCommandMetadata': {'url': 'https://www.google.com/aclk?sa=l&ai=CbxQsItKWYuLvItfqrAGlvo2YAvu01rFqja7W77cL77r5qt8cCAAQASC7m7pOYMvz_4SMF6AB_sHz1gLIAQGpAkD2v6eDqo4-qgRhT9ALH8REWooefkIvOSvyFQ20xWQ2qkqvc_5BF0rZnlu2CFDi9DWDHzo_bj58KqPepYuWNU4dvSMM0QNJS2mWXV2fllmBoc_2ocTKSq0-JZnhLUA7UCCLDXxBE4SPzjnkZcAE6ImFgYMDiAX4jpaxGKAGUYAH6r2MqQGQBwGoB9TSG6gHpr4bqAe5mrECqAfz0RuoB-7SG6gH_5yxAqgHytwbqAfYprECoAjzsakEsAgF0ggOEAEgpIECMgOGwAI6AQCxCRfbBJitXnzvuQkX2wSYrV587_gJAZgLAbgMAegMBIIUHggBEhpweXRob24gY291cnNlIGZvciBzdHVkZW50c4gUB9AVAZgWAfgWAYAXAZIXCBIGCAEQAxgo&sig=AOD64_0SgsOHZEtRPOBAUOp0LEiWUexI8Q&adurl=https://www.kidocode.com/ots%3Futm_source%3Dgoogle%26utm_medium%3Dcpc%26utm_campaign%3DMax_Conversion_Auto_Bid%26utm_content%3DTrial_Class%26keyword%3Dpython%2520course%2520for%2520students&ms=[CLICK_MS]&nx=[NX]&ny=[NY]&nb=[NB]',
#          'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#          'rootVe': 83769}},
#        'urlEndpoint': {'url': 'https://www.google.com/aclk?sa=l&ai=CbxQsItKWYuLvItfqrAGlvo2YAvu01rFqja7W77cL77r5qt8cCAAQASC7m7pOYMvz_4SMF6AB_sHz1gLIAQGpAkD2v6eDqo4-qgRhT9ALH8REWooefkIvOSvyFQ20xWQ2qkqvc_5BF0rZnlu2CFDi9DWDHzo_bj58KqPepYuWNU4dvSMM0QNJS2mWXV2fllmBoc_2ocTKSq0-JZnhLUA7UCCLDXxBE4SPzjnkZcAE6ImFgYMDiAX4jpaxGKAGUYAH6r2MqQGQBwGoB9TSG6gHpr4bqAe5mrECqAfz0RuoB-7SG6gH_5yxAqgHytwbqAfYprECoAjzsakEsAgF0ggOEAEgpIECMgOGwAI6AQCxCRfbBJitXnzvuQkX2wSYrV587_gJAZgLAbgMAegMBIIUHggBEhpweXRob24gY291cnNlIGZvciBzdHVkZW50c4gUB9AVAZgWAfgWAYAXAZIXCBIGCAEQAxgo&sig=AOD64_0SgsOHZEtRPOBAUOp0LEiWUexI8Q&adurl=https://www.kidocode.com/ots%3Futm_source%3Dgoogle%26utm_medium%3Dcpc%26utm_campaign%3DMax_Conversion_Auto_Bid%26utm_content%3DTrial_Class%26keyword%3Dpython%2520course%2520for%2520students&ms=[CLICK_MS]&nx=[NX]&ny=[NY]&nb=[NB]',
#         'target': 'TARGET_NEW_WINDOW'}},
#       'impressionCommands': [{'clickTrackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#         'loggingUrls': [{'baseUrl': 'https://www.youtube.com/pagead/paralleladview?ai=CuIUxItKWYpThHsermsMPybqS2A8Aja7W77cLABABIABgywOCARNwYXJ0bmVyLXlvdXR1YmUtc3JwqAMEqgQXT9AOeOGYkCuKBX4bLLvRwH2TGhl4yAOQBwTSCA4IgEEQARgAMgKCAjoBALALAboLLAgDEAUYDCAIKAUwBUABSABYTmAAaABwAYgBAJgBAaIBCAoAmAICqAIBgAIBoBcB&sigh=YIOBs6AVrXE&cid=CAASFeRoSeUvf5q_qOE4vT3iXHlg4W8-_Q&vt=0&ad_mt=[AD_MT]'}],
#         'pingingEndpoint': {'hack': True}}],
#       'menu': {'menuRenderer': {'items': [{'menuNavigationItemRenderer': {'text': {'simpleText': 'Why this ad?'},
#            'icon': {'iconType': 'INFO'},
#            'navigationEndpoint': {'clickTrackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#             'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
#             'adInfoDialogEndpoint': {'dialog': {'adInfoDialogRenderer': {'dialogMessage': {'runs': [{'text': '\n'},
#                  {'text': "Visit Google's "},
#                  {'text': 'Ad Settings',
#                   'navigationEndpoint': {'clickTrackingParams': 'CLYEEPWrAiITCM2Em7-di_gCFcGCYwYdZ6sNQA==',
#                    'commandMetadata': {'webCommandMetadata': {'url': 'https://adssettings.google.com/',
#                      'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#                      'rootVe': 83769}},
#                    'urlEndpoint': {'url': 'https://adssettings.google.com',
#                     'target': 'TARGET_NEW_WINDOW'}}},
#                  {'text': ' to learn more about how ads are targeted or to opt out of personalized ads.'}]},
#                'confirmLabel': {'simpleText': 'CLOSE'},
#                'trackingParams': 'CLYEEPWrAiITCM2Em7-di_gCFcGCYwYdZ6sNQA==',
#                'title': {'simpleText': 'This ad may be based on:'},
#                'adReasons': [{'simpleText': 'The time of day or your general location (like your country or city)'},
#                 {'simpleText': 'Your current search terms'}]}}}},
#            'trackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#          {'menuNavigationItemRenderer': {'text': {'runs': [{'text': 'Control your Google ads'}]},
#            'icon': {'iconType': 'SETTINGS'},
#            'navigationEndpoint': {'clickTrackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#             'commandMetadata': {'webCommandMetadata': {'url': 'https://adssettings.google.com/',
#               'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#               'rootVe': 83769}},
#             'urlEndpoint': {'url': 'https://adssettings.google.com',
#              'target': 'TARGET_NEW_WINDOW'}},
#            'trackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A'}}],
#         'trackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#       'trackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#       'clickLocationTargets': [{'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_AD_BADGE',
#         'code': 31,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_DESCRIPTION',
#         'code': 7,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_NOOP'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_ACTION_LABEL',
#         'code': 8,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_BACKGROUND',
#         'code': 2,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_NOOP'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_BORDER',
#         'code': 39,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_NOOP'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_AD_WEBSITE',
#         'code': 1,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_CTD_AD_RATING',
#         'code': 16,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_CTD_AD_PRICE',
#         'code': 15,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_CTD_AD_APP_STORE',
#         'code': 35,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_PRODUCT_PRICE',
#         'code': 15,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_INNER_BACKGROUND',
#         'code': 41,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_NOOP'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_CUSTOM_BADGE',
#         'code': 43,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TALKBACK_ACTIVATED',
#         'code': 17,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_ACTION_LABEL_TALKBACK_ACTIVATED',
#         'code': 8,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TITLE',
#         'code': 0,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_THUMBNAIL',
#         'code': 9,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'},
#        {'location': 'PROMOTED_SPARKLES_CLICK_LOCATION_TEXT_PRODUCT_ADVERTISER',
#         'code': 20,
#         'behaviorType': 'PROMOTED_SPARKLES_CLICK_BEHAVIOR_TYPE_OPEN_AD'}],
#       'mediaHoverOverlay': {'buttonRenderer': {'style': 'STYLE_LIGHT_TEXT',
#         'text': {'simpleText': 'VISIT SITE'},
#         'icon': {'iconType': 'EXTERNAL_LINK'},
#         'trackingParams': 'CLUEEPBbIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#         'iconPosition': 'BUTTON_ICON_POSITION_TYPE_RIGHT_OF_TEXT'}},
#       'mediaBadge': {'metadataBadgeRenderer': {'icon': {'iconType': 'EXTERNAL_LINK'},
#         'style': 'BADGE_STYLE_TYPE_BLACK',
#         'trackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#       'promotedSparklesWebStyle': 'PROMOTED_SPARKLES_WEB_STYLE_LANDSCAPE_IMAGE_ASPECT_RATIO',
#       'isSquareThumbnail': False,
#       'thumbnailNavigationEndpoint': {'clickTrackingParams': 'CLQEENjJBRgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#        'loggingUrls': [{'baseUrl': 'https://www.youtube.com/pagead/paralleladinteraction?ai=CAqZ4ItKWYpThHsermsMPybqS2A8Aja7W77cLABABIABgywOCARNwYXJ0bmVyLXlvdXR1YmUtc3JwqAMEqgQXT9AOeOGYkCuKBX4bLLvRwH2TGhl4yAOQBwSoB4QIqAfOp7EC0ggOCIBBEAEYADICggI6AQCwCwG6CzgIAxAFGAwgCCgFMAVAAUgAWE5gAGgAcAGIAQCQAQGYAQGiAQgKAJgCAqgCAcABAdABAeABAYACAaAXAQ&sigh=Wvxrp_rKTgY&cid=CAASFeRoSeUvf5q_qOE4vT3iXHlg4W8-_Q&ad_mt=[AD_MT]&acvw=[VIEWABILITY]&gv=[GOOGLE_VIEWABILITY]&nb=%5BNB%5D&label=video_click_to_advertiser_site'}],
#        'commandMetadata': {'webCommandMetadata': {'url': 'https://www.google.com/aclk?sa=l&ai=CbxQsItKWYuLvItfqrAGlvo2YAvu01rFqja7W77cL77r5qt8cCAAQASC7m7pOYMvz_4SMF6AB_sHz1gLIAQGpAkD2v6eDqo4-qgRhT9ALH8REWooefkIvOSvyFQ20xWQ2qkqvc_5BF0rZnlu2CFDi9DWDHzo_bj58KqPepYuWNU4dvSMM0QNJS2mWXV2fllmBoc_2ocTKSq0-JZnhLUA7UCCLDXxBE4SPzjnkZcAE6ImFgYMDiAX4jpaxGKAGUYAH6r2MqQGQBwGoB9TSG6gHpr4bqAe5mrECqAfz0RuoB-7SG6gH_5yxAqgHytwbqAfYprECoAjzsakEsAgF0ggOEAEgpIECMgOGwAI6AQCxCRfbBJitXnzvuQkX2wSYrV587_gJAZgLAbgMAegMBIIUHggBEhpweXRob24gY291cnNlIGZvciBzdHVkZW50c4gUB9AVAZgWAfgWAYAXAZIXCBIGCAEQAxgo&sig=AOD64_0SgsOHZEtRPOBAUOp0LEiWUexI8Q&adurl=https://www.kidocode.com/ots%3Futm_source%3Dgoogle%26utm_medium%3Dcpc%26utm_campaign%3DMax_Conversion_Auto_Bid%26utm_content%3DTrial_Class%26keyword%3Dpython%2520course%2520for%2520students&ms=[CLICK_MS]&nx=[NX]&ny=[NY]&nb=[NB]',
#          'webPageType': 'WEB_PAGE_TYPE_UNKNOWN',
#          'rootVe': 83769}},
#        'urlEndpoint': {'url': 'https://www.google.com/aclk?sa=l&ai=CbxQsItKWYuLvItfqrAGlvo2YAvu01rFqja7W77cL77r5qt8cCAAQASC7m7pOYMvz_4SMF6AB_sHz1gLIAQGpAkD2v6eDqo4-qgRhT9ALH8REWooefkIvOSvyFQ20xWQ2qkqvc_5BF0rZnlu2CFDi9DWDHzo_bj58KqPepYuWNU4dvSMM0QNJS2mWXV2fllmBoc_2ocTKSq0-JZnhLUA7UCCLDXxBE4SPzjnkZcAE6ImFgYMDiAX4jpaxGKAGUYAH6r2MqQGQBwGoB9TSG6gHpr4bqAe5mrECqAfz0RuoB-7SG6gH_5yxAqgHytwbqAfYprECoAjzsakEsAgF0ggOEAEgpIECMgOGwAI6AQCxCRfbBJitXnzvuQkX2wSYrV587_gJAZgLAbgMAegMBIIUHggBEhpweXRob24gY291cnNlIGZvciBzdHVkZW50c4gUB9AVAZgWAfgWAYAXAZIXCBIGCAEQAxgo&sig=AOD64_0SgsOHZEtRPOBAUOp0LEiWUexI8Q&adurl=https://www.kidocode.com/ots%3Futm_source%3Dgoogle%26utm_medium%3Dcpc%26utm_campaign%3DMax_Conversion_Auto_Bid%26utm_content%3DTrial_Class%26keyword%3Dpython%2520course%2520for%2520students&ms=[CLICK_MS]&nx=[NX]&ny=[NY]&nb=[NB]',
#         'target': 'TARGET_NEW_WINDOW'}}}}],
#    'trackingParams': 'CLMEELsvGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA='}},
#  {'itemSectionRenderer': {'contents': [{'videoRenderer': {'videoId': 'mRMmlo_Uqcs',
#       'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAFjSFxYnui85aGJkMof1-0yUE8lg',
#          'width': 360,
#          'height': 202},
#         {'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBF0G4hZ3rf-AHsseGtwUAW3CO78Q',
#          'width': 720,
#          'height': 404}]},
#       'title': {'runs': [{'text': 'you need to learn Python RIGHT NOW!! // EP 1'}],
#        'accessibility': {'accessibilityData': {'label': 'you need to learn Python RIGHT NOW!! // EP 1 by NetworkChuck 9 months ago 17 minutes 869,955 views'}}},
#       'longBylineText': {'runs': [{'text': 'NetworkChuck',
#          'navigationEndpoint': {'clickTrackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/NetworkChuck',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC9x0AN7BWHpCDHSm9NiJFJQ',
#            'canonicalBaseUrl': '/c/NetworkChuck'}}}]},
#       'publishedTimeText': {'simpleText': '9 months ago'},
#       'lengthText': {'accessibility': {'accessibilityData': {'label': '17 minutes, 42 seconds'}},
#        'simpleText': '17:42'},
#       'viewCountText': {'simpleText': '869,955 views'},
#       'navigationEndpoint': {'clickTrackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUAyBnNlYXJjaFIMbGVhcm4rUHl0aG9umgEDEPQk',
#        'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs',
#          'webPageType': 'WEB_PAGE_TYPE_WATCH',
#          'rootVe': 3832}},
#        'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#         'params': 'qgMMbGVhcm4rUHl0aG9uugMLCOm-6_2vku6u8wG6AwsIparx09DU6uqTAboDCwics-i39u-k3bwBugMLCOa3867B5sawkQG6AwoIp9eMn_yuqYQ6ugMKCLCc2oDH4eLRT7oDCgjAud3yiZ-9vSG6AwsIuY6gv7_X9OHaAboDCgiFmdvtrrX7z2K6AwsIloXF6vKc7JGwAboDCwiC5qnFndiS7e8BugMLCK7l05bH4LWo-QG6AwsI0Iqq4Lq51vjMAboDCgiqwMvxx_Oz5DS6AwoIrtDyo9rOlvA-ugMKCPiygPPmy8mpbLoDCwjU6NuAoaalnqsBugMKCIvEuISIm_2fEroDCwjfstqJ1YqxwcsBggQCEAE%3D',
#         'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#       'badges': [{'metadataBadgeRenderer': {'style': 'BADGE_STYLE_TYPE_SIMPLE',
#          'label': '4K',
#          'trackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA='}},
#        {'metadataBadgeRenderer': {'style': 'BADGE_STYLE_TYPE_SIMPLE',
#          'label': 'CC',
#          'trackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'accessibilityData': {'label': 'Closed captions'}}}],
#       'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#          'style': 'BADGE_STYLE_TYPE_VERIFIED',
#          'tooltip': 'Verified',
#          'trackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'accessibilityData': {'label': 'Verified'}}}],
#       'ownerText': {'runs': [{'text': 'NetworkChuck',
#          'navigationEndpoint': {'clickTrackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/NetworkChuck',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC9x0AN7BWHpCDHSm9NiJFJQ',
#            'canonicalBaseUrl': '/c/NetworkChuck'}}}]},
#       'shortBylineText': {'runs': [{'text': 'NetworkChuck',
#          'navigationEndpoint': {'clickTrackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/NetworkChuck',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC9x0AN7BWHpCDHSm9NiJFJQ',
#            'canonicalBaseUrl': '/c/NetworkChuck'}}}]},
#       'trackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUBAy9PS_ujSyYmZAQ==',
#       'showActionMenu': False,
#       'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '869K views'}},
#        'simpleText': '869K views'},
#       'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#            'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#            'serviceEndpoint': {'clickTrackingParams': 'CLIEEP6YBBgNIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#             'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#              'actions': [{'clickTrackingParams': 'CLIEEP6YBBgNIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                'addToPlaylistCommand': {'openMiniplayer': True,
#                 'videoId': 'mRMmlo_Uqcs',
#                 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                 'onCreateListCommand': {'clickTrackingParams': 'CLIEEP6YBBgNIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/playlist/create'}},
#                  'createPlaylistServiceEndpoint': {'videoIds': ['mRMmlo_Uqcs'],
#                   'params': 'CAQ%3D'}},
#                 'videoIds': ['mRMmlo_Uqcs']}}]}},
#            'trackingParams': 'CLIEEP6YBBgNIhMIzYSbv52L-AIVwYJjBh1nqw1A'}}],
#         'trackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#         'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#       'channelThumbnailSupportedRenderers': {'channelThumbnailWithLinkRenderer': {'thumbnail': {'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AKedOLTHjL08GyIUwy_6DxA3GtUzyPU1aOs2CwgNtuRJ4A=s68-c-k-c0x00ffffff-no-rj',
#            'width': 68,
#            'height': 68}]},
#         'navigationEndpoint': {'clickTrackingParams': 'CJ8EENwwGAAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'commandMetadata': {'webCommandMetadata': {'url': '/c/NetworkChuck',
#            'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#            'rootVe': 3611,
#            'apiUrl': '/youtubei/v1/browse'}},
#          'browseEndpoint': {'browseId': 'UC9x0AN7BWHpCDHSm9NiJFJQ',
#           'canonicalBaseUrl': '/c/NetworkChuck'}},
#         'accessibility': {'accessibilityData': {'label': 'Go to channel'}}}},
#       'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '17 minutes, 42 seconds'}},
#           'simpleText': '17:42'},
#          'style': 'DEFAULT'}},
#        {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#          'untoggledIcon': {'iconType': 'WATCH_LATER'},
#          'toggledIcon': {'iconType': 'CHECK'},
#          'untoggledTooltip': 'Watch later',
#          'toggledTooltip': 'Added',
#          'untoggledServiceEndpoint': {'clickTrackingParams': 'CLEEEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#             'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#           'playlistEditEndpoint': {'playlistId': 'WL',
#            'actions': [{'addedVideoId': 'mRMmlo_Uqcs',
#              'action': 'ACTION_ADD_VIDEO'}]}},
#          'toggledServiceEndpoint': {'clickTrackingParams': 'CLEEEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#             'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#           'playlistEditEndpoint': {'playlistId': 'WL',
#            'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#              'removedVideoId': 'mRMmlo_Uqcs'}]}},
#          'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#          'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#          'trackingParams': 'CLEEEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#        {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#          'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#          'untoggledTooltip': 'Add to queue',
#          'toggledTooltip': 'Added',
#          'untoggledServiceEndpoint': {'clickTrackingParams': 'CLAEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#           'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#            'actions': [{'clickTrackingParams': 'CLAEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'addToPlaylistCommand': {'openMiniplayer': True,
#               'videoId': 'mRMmlo_Uqcs',
#               'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#               'onCreateListCommand': {'clickTrackingParams': 'CLAEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                  'apiUrl': '/youtubei/v1/playlist/create'}},
#                'createPlaylistServiceEndpoint': {'videoIds': ['mRMmlo_Uqcs'],
#                 'params': 'CAQ%3D'}},
#               'videoIds': ['mRMmlo_Uqcs']}}]}},
#          'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#          'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#          'trackingParams': 'CLAEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#        {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}],
#       'richThumbnail': {'movingThumbnailRenderer': {'movingThumbnailDetails': {'thumbnails': [{'url': 'https://i.ytimg.com/an_webp/mRMmlo_Uqcs/mqdefault_6s.webp?du=3000&sqp=CIWQ25QG&rs=AOn4CLBdpKuqxqJe01hMFXvt5iABIEdMrQ',
#            'width': 320,
#            'height': 180}],
#          'logAsMovingThumbnail': True},
#         'enableHoveredLogging': True,
#         'enableOverlay': True}},
#       'detailedMetadataSnippets': [{'snippetText': {'runs': [{'text': '**Sponsored by ITProTV SUPPORT NETWORKCHUCK --------------------------------------------------- ➡️NetworkChuck membership:\xa0...'}]},
#         'snippetHoverText': {'runs': [{'text': 'From the video description'}]},
#         'maxOneLine': True}],
#       'expandableMetadata': {'expandableMetadataRenderer': {'header': {'collapsedTitle': {'simpleText': 'Intro | FREE Python lab | your FIRST Python code (hello world) | What is Python? | DEEP DIVE: Hello World!! | “Strings” | Comments | Erros in Python | “””multi-line strings””” | Add strings together (concatenate)'},
#          'collapsedThumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_15166.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBWMf_8vk329LzqLStkE1yI9zsQ8w',
#             'width': 336,
#             'height': 188}]},
#          'collapsedLabel': {'runs': [{'text': '10'}, {'text': ' chapters'}]},
#          'expandedTitle': {'runs': [{'text': '10'},
#            {'text': ' chapters in this video'}]}},
#         'expandedContent': {'horizontalCardListRenderer': {'cards': [{'macroMarkersListItemRenderer': {'title': {'simpleText': 'Intro'},
#              'timeDescription': {'simpleText': '0:00'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_15166.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBWMf_8vk329LzqLStkE1yI9zsQ8w',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CK8EENDQBhgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CK8EENDQBhgAIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'FREE Python lab'},
#              'timeDescription': {'simpleText': '1:23'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_112833.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCLvI0KsscDr4sNDaFAhFxgOGbe1w',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CK4EENDQBhgBIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=83s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 83,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=83&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CK4EENDQBhgBIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'your FIRST Python code (hello world)'},
#              'timeDescription': {'simpleText': '2:39'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_188266.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDlnFLIrM_NdWq6c2zajyuSWDBwdA',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CK0EENDQBhgCIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=159s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 159,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=159&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CK0EENDQBhgCIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'What is Python?'},
#              'timeDescription': {'simpleText': '3:20'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_202133.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDWE0HkidNswd07XqhO6Y7JJ-ardQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKwEENDQBhgDIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=200s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 200,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=200&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKwEENDQBhgDIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'DEEP DIVE: Hello World!!'},
#              'timeDescription': {'simpleText': '4:16'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_264733.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBhujXMCRDnnVpoKVV_PKqZH2n8Tw',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKsEENDQBhgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=256s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 256,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=256&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKsEENDQBhgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': '“Strings”'},
#              'timeDescription': {'simpleText': '4:43'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_291133.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCOGoVFrx23AcKLaa4yl8jWoDrUZg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKoEENDQBhgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=283s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 283,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=283&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKoEENDQBhgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Comments'},
#              'timeDescription': {'simpleText': '6:35'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_398700.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAjYAsLz1pgoAEilO1KLSUqAuY2LA',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKkEENDQBhgGIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=395s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 395,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=395&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKkEENDQBhgGIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Erros in Python'},
#              'timeDescription': {'simpleText': '8:22'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_530833.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAzUcrX2SuDBQpr0rXlUFekvcaSNg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKgEENDQBhgHIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=502s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 502,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=502&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKgEENDQBhgHIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': '“””multi-line strings”””'},
#              'timeDescription': {'simpleText': '10:30'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_636966.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB83thEQsEEKo3rvz16RFJPkdsoSQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKcEENDQBhgIIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=630s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 630,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=630&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKcEENDQBhgIIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Add strings together (concatenate)'},
#              'timeDescription': {'simpleText': '11:42'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/mRMmlo_Uqcs/hqdefault_730900.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA1b3uAUuhZgfzpxQYs_uqYj2jJfQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CKYEENDQBhgJIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=mRMmlo_Uqcs&t=702s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'mRMmlo_Uqcs',
#                'startTimeSeconds': 702,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30ad.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=991326968fd4a9cb&ip=115.135.184.8&osts=702&initcwndbps=1332500&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CKYEENDQBhgJIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}}],
#           'trackingParams': 'CKMEEJFaIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'style': {'type': 'HORIZONTAL_CARD_LIST_STYLE_TYPE_ENGAGEMENT_PANEL_SECTION'},
#           'previousButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'icon': {'iconType': 'CHEVRON_LEFT'},
#             'trackingParams': 'CKUEEPBbIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#           'nextButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'icon': {'iconType': 'CHEVRON_RIGHT'},
#             'trackingParams': 'CKQEEPBbIhMIzYSbv52L-AIVwYJjBh1nqw1A'}}}},
#         'expandButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#           'size': 'SIZE_DEFAULT',
#           'isDisabled': False,
#           'icon': {'iconType': 'EXPAND_MORE'},
#           'trackingParams': 'CKIEEPBbIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'accessibilityData': {'accessibilityData': {'label': 'More'}}}},
#         'collapseButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#           'size': 'SIZE_DEFAULT',
#           'isDisabled': False,
#           'icon': {'iconType': 'EXPAND_LESS'},
#           'trackingParams': 'CKEEEPBbIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'accessibilityData': {'accessibilityData': {'label': 'Less'}}}},
#         'trackingParams': 'CKAEEO_DByITCM2Em7-di_gCFcGCYwYdZ6sNQA==',
#         'loggingDirectives': {'trackingParams': 'CKAEEO_DByITCM2Em7-di_gCFcGCYwYdZ6sNQA==',
#          'visibility': {'types': '12'}}}}}},
#     {'videoRenderer': {'videoId': '8124kv-632k',
#       'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/8124kv-632k/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBJpEFlfmIT_ZhxOddf2AITQscOcw',
#          'width': 360,
#          'height': 202},
#         {'url': 'https://i.ytimg.com/vi/8124kv-632k/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCRlPciXQCpBkaWUjYUyZU_Sw20yw',
#          'width': 720,
#          'height': 404}]},
#       'title': {'runs': [{'text': 'Python Tutorial for Beginners'}],
#        'accessibility': {'accessibilityData': {'label': 'Python Tutorial for Beginners by freeCodeCamp.org 2 months ago 2 hours, 52 minutes 172,224 views'}}},
#       'longBylineText': {'runs': [{'text': 'freeCodeCamp.org',
#          'navigationEndpoint': {'clickTrackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/Freecodecamp',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#            'canonicalBaseUrl': '/c/Freecodecamp'}}}]},
#       'publishedTimeText': {'simpleText': '2 months ago'},
#       'lengthText': {'accessibility': {'accessibilityData': {'label': '2 hours, 52 minutes, 13 seconds'}},
#        'simpleText': '2:52:13'},
#       'viewCountText': {'simpleText': '172,224 views'},
#       'navigationEndpoint': {'clickTrackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUAyBnNlYXJjaFIMbGVhcm4rUHl0aG9umgEDEPQk',
#        'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=8124kv-632k',
#          'webPageType': 'WEB_PAGE_TYPE_WATCH',
#          'rootVe': 3832}},
#        'watchEndpoint': {'videoId': '8124kv-632k',
#         'params': 'qgMMbGVhcm4rUHl0aG9uugMLCMvT0v7o0smJmQG6AwsIparx09DU6uqTAboDCwics-i39u-k3bwBugMLCOa3867B5sawkQG6AwoIp9eMn_yuqYQ6ugMKCLCc2oDH4eLRT7oDCgjAud3yiZ-9vSG6AwsIuY6gv7_X9OHaAboDCgiFmdvtrrX7z2K6AwsIloXF6vKc7JGwAboDCwiC5qnFndiS7e8BugMLCK7l05bH4LWo-QG6AwsI0Iqq4Lq51vjMAboDCgiqwMvxx_Oz5DS6AwoIrtDyo9rOlvA-ugMKCPiygPPmy8mpbLoDCwjU6NuAoaalnqsBugMKCIvEuISIm_2fEroDCwjfstqJ1YqxwcsBggQCEAE%3D',
#         'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-uh-30all.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=f35db892ffbadf69&ip=115.135.184.8&initcwndbps=835000&mt=1654050543&oweuc='}}}}},
#       'badges': [{'metadataBadgeRenderer': {'style': 'BADGE_STYLE_TYPE_SIMPLE',
#          'label': '4K',
#          'trackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA='}},
#        {'metadataBadgeRenderer': {'style': 'BADGE_STYLE_TYPE_SIMPLE',
#          'label': 'CC',
#          'trackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'accessibilityData': {'label': 'Closed captions'}}}],
#       'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'CHECK_CIRCLE_THICK'},
#          'style': 'BADGE_STYLE_TYPE_VERIFIED',
#          'tooltip': 'Verified',
#          'trackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'accessibilityData': {'label': 'Verified'}}}],
#       'ownerText': {'runs': [{'text': 'freeCodeCamp.org',
#          'navigationEndpoint': {'clickTrackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/Freecodecamp',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#            'canonicalBaseUrl': '/c/Freecodecamp'}}}]},
#       'shortBylineText': {'runs': [{'text': 'freeCodeCamp.org',
#          'navigationEndpoint': {'clickTrackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'commandMetadata': {'webCommandMetadata': {'url': '/c/Freecodecamp',
#             'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#             'rootVe': 3611,
#             'apiUrl': '/youtubei/v1/browse'}},
#           'browseEndpoint': {'browseId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#            'canonicalBaseUrl': '/c/Freecodecamp'}}}]},
#       'trackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUBA6b7r_a-S7q7zAQ==',
#       'showActionMenu': False,
#       'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '172K views'}},
#        'simpleText': '172K views'},
#       'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#            'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#            'serviceEndpoint': {'clickTrackingParams': 'CJ4EEP6YBBgXIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#             'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#              'actions': [{'clickTrackingParams': 'CJ4EEP6YBBgXIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                'addToPlaylistCommand': {'openMiniplayer': True,
#                 'videoId': '8124kv-632k',
#                 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#                 'onCreateListCommand': {'clickTrackingParams': 'CJ4EEP6YBBgXIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                  'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                    'apiUrl': '/youtubei/v1/playlist/create'}},
#                  'createPlaylistServiceEndpoint': {'videoIds': ['8124kv-632k'],
#                   'params': 'CAQ%3D'}},
#                 'videoIds': ['8124kv-632k']}}]}},
#            'trackingParams': 'CJ4EEP6YBBgXIhMIzYSbv52L-AIVwYJjBh1nqw1A'}}],
#         'trackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#         'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#       'channelThumbnailSupportedRenderers': {'channelThumbnailWithLinkRenderer': {'thumbnail': {'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AKedOLRR2uNiXJiFH-XRmtGgkdICxTuDJxCPJidKFRNCNg=s68-c-k-c0x00ffffff-no-rj',
#            'width': 68,
#            'height': 68}]},
#         'navigationEndpoint': {'clickTrackingParams': 'CJsEENwwGAEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#          'commandMetadata': {'webCommandMetadata': {'url': '/c/Freecodecamp',
#            'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#            'rootVe': 3611,
#            'apiUrl': '/youtubei/v1/browse'}},
#          'browseEndpoint': {'browseId': 'UC8butISFwT-Wl7EV0hUK0BQ',
#           'canonicalBaseUrl': '/c/Freecodecamp'}},
#         'accessibility': {'accessibilityData': {'label': 'Go to channel'}}}},
#       'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '2 hours, 52 minutes, 13 seconds'}},
#           'simpleText': '2:52:13'},
#          'style': 'DEFAULT'}},
#        {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#          'untoggledIcon': {'iconType': 'WATCH_LATER'},
#          'toggledIcon': {'iconType': 'CHECK'},
#          'untoggledTooltip': 'Watch later',
#          'toggledTooltip': 'Added',
#          'untoggledServiceEndpoint': {'clickTrackingParams': 'CJ0EEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#             'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#           'playlistEditEndpoint': {'playlistId': 'WL',
#            'actions': [{'addedVideoId': '8124kv-632k',
#              'action': 'ACTION_ADD_VIDEO'}]}},
#          'toggledServiceEndpoint': {'clickTrackingParams': 'CJ0EEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#             'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#           'playlistEditEndpoint': {'playlistId': 'WL',
#            'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#              'removedVideoId': '8124kv-632k'}]}},
#          'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#          'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#          'trackingParams': 'CJ0EEPnnAxgEIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#        {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#          'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#          'untoggledTooltip': 'Add to queue',
#          'toggledTooltip': 'Added',
#          'untoggledServiceEndpoint': {'clickTrackingParams': 'CJwEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#           'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#            'actions': [{'clickTrackingParams': 'CJwEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#              'addToPlaylistCommand': {'openMiniplayer': True,
#               'videoId': '8124kv-632k',
#               'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#               'onCreateListCommand': {'clickTrackingParams': 'CJwEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#                'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#                  'apiUrl': '/youtubei/v1/playlist/create'}},
#                'createPlaylistServiceEndpoint': {'videoIds': ['8124kv-632k'],
#                 'params': 'CAQ%3D'}},
#               'videoIds': ['8124kv-632k']}}]}},
#          'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#          'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#          'trackingParams': 'CJwEEMfsBBgFIhMIzYSbv52L-AIVwYJjBh1nqw1A'}},
#        {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}],
#       'richThumbnail': {'movingThumbnailRenderer': {'movingThumbnailDetails': {'thumbnails': [{'url': 'https://i.ytimg.com/an_webp/8124kv-632k/mqdefault_6s.webp?du=3000&sqp=CPWL25QG&rs=AOn4CLACNvoTtEYCrcOPG15vTX2dS9IUGA',
#            'width': 320,
#            'height': 180}],
#          'logAsMovingThumbnail': True},
#         'enableHoveredLogging': True,
#         'enableOverlay': True}},
#       'detailedMetadataSnippets': [{'snippetText': {'runs': [{'text': 'Learn',
#            'bold': True},
# ...
#              'trackingParams': 'CE4Q0NAGGAoiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Implementing the naive solution'},
#              'timeDescription': {'simpleText': '34:22'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2071633.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB1NUX3tlectXwzbEigDdvSNhmGvQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CE0Q0NAGGAsiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2062s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2062,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2062&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CE0Q0NAGGAsiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Testing the naive solution'},
#              'timeDescription': {'simpleText': '37:24'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2246166.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAdyUlBPKh8to0MBTJPmYeH97HRDQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEwQ0NAGGAwiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2244s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2244,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2244&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEwQ0NAGGAwiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Q-table implementation'},
#              'timeDescription': {'simpleText': '39:35'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2391066.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAnrRloqhAyVSZXge5IVojN-YlJfQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEsQ0NAGGA0iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2375s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2375,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2375&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEsQ0NAGGA0iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Adding get_number_of_states to the Field Class'},
#              'timeDescription': {'simpleText': '41:40'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2508300.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCTTIIQqJII0JjR0WN-4RQ1_MUKfg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEoQ0NAGGA4iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2500s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2500,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2500&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEoQ0NAGGA4iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Adding get_state to the Field Class'},
#              'timeDescription': {'simpleText': '42:50'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2582900.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCPCwDL9R9G91X1py_qu4DQSlL6Wg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEkQ0NAGGA8iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2570s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2570,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2570&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEkQ0NAGGA8iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Q-table Learning'},
#              'timeDescription': {'simpleText': '46:17'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2777033.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAC1n9M1mEC3M6k9EFWDsUGeqFdzQ',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEgQ0NAGGBAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2777s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2777,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2777&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEgQ0NAGGBAiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Implementing the Q-table Learning'},
#              'timeDescription': {'simpleText': '47:50'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_2880933.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLB5P22xzbhdkbqPk_9re8NI2eDuGg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEcQ0NAGGBEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=2870s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 2870,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=2870&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEcQ0NAGGBEiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'The actual Learning Algorithm'},
#              'timeDescription': {'simpleText': '50:15'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_3044000.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBOlXxeNwpvd2DdjwoXtbgEKwxDZA',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEYQ0NAGGBIiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=3015s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 3015,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=3015&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEYQ0NAGGBIiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Q-table Evaluation'},
#              'timeDescription': {'simpleText': '56:02'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_3362133.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAbliH0qcWK2JxEHBRiLkKEDgMwjg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEUQ0NAGGBMiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=3362s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 3362,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=3362&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEUQ0NAGGBMiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}},
#            {'macroMarkersListItemRenderer': {'title': {'simpleText': 'Next Step'},
#              'timeDescription': {'simpleText': '1:00:52'},
#              'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/y4LEVVE2mV8/hqdefault_3679866.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCXDk8lfleorzZRo0S-HRxnWrTsZg',
#                 'width': 336,
#                 'height': 188}]},
#              'onTap': {'clickTrackingParams': 'CEQQ0NAGGBQiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#               'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=y4LEVVE2mV8&t=3652s',
#                 'webPageType': 'WEB_PAGE_TYPE_WATCH',
#                 'rootVe': 3832}},
#               'watchEndpoint': {'videoId': 'y4LEVVE2mV8',
#                'startTimeSeconds': 3652,
#                'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-uh-30as7.googlevideo.com/initplayback?source=youtube&orc=1&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odeak=1&odepv=1&osfc=1&id=cb82c4555136995f&ip=115.135.184.8&osts=3652&initcwndbps=1308750&mt=1654050543&oweuc='}}}}},
#              'trackingParams': 'CEQQ0NAGGBQiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#              'layout': 'MACRO_MARKERS_LIST_ITEM_RENDERER_LAYOUT_VERTICAL',
#              'isHighlighted': False}}],
#           'trackingParams': 'CEEQkVoiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'style': {'type': 'HORIZONTAL_CARD_LIST_STYLE_TYPE_ENGAGEMENT_PANEL_SECTION'},
#           'previousButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'icon': {'iconType': 'CHEVRON_LEFT'},
#             'trackingParams': 'CEMQ8FsiEwjNhJu_nYv4AhXBgmMGHWerDUA='}},
#           'nextButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#             'size': 'SIZE_DEFAULT',
#             'isDisabled': False,
#             'icon': {'iconType': 'CHEVRON_RIGHT'},
#             'trackingParams': 'CEIQ8FsiEwjNhJu_nYv4AhXBgmMGHWerDUA='}}}},
#         'expandButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#           'size': 'SIZE_DEFAULT',
#           'isDisabled': False,
#           'icon': {'iconType': 'EXPAND_MORE'},
#           'trackingParams': 'CEAQ8FsiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'accessibilityData': {'accessibilityData': {'label': 'More'}}}},
#         'collapseButton': {'buttonRenderer': {'style': 'STYLE_DEFAULT',
#           'size': 'SIZE_DEFAULT',
#           'isDisabled': False,
#           'icon': {'iconType': 'EXPAND_LESS'},
#           'trackingParams': 'CD8Q8FsiEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#           'accessibilityData': {'accessibilityData': {'label': 'Less'}}}},
#         'trackingParams': 'CD4Q78MHIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#         'loggingDirectives': {'trackingParams': 'CD4Q78MHIhMIzYSbv52L-AIVwYJjBh1nqw1A',
#          'visibility': {'types': '12'}}}}}}],
#    'trackingParams': 'CDwQuy8YASITCM2Em7-di_gCFcGCYwYdZ6sNQA=='}},
#  {'continuationItemRenderer': {'trigger': 'CONTINUATION_TRIGGER_ON_ITEM_SHOWN',
#    'continuationEndpoint': {'clickTrackingParams': 'CBkQui8iEwjNhJu_nYv4AhXBgmMGHWerDUA=',
#     'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#       'apiUrl': '/youtubei/v1/search'}},
#     'continuationCommand': {'token': '...%3D',
#      'request': 'CONTINUATION_REQUEST_TYPE_SEARCH'}}}}]

# %%
def get_text(content, info):
    try:
        return ' '.join(t['text'] for t in content[info]['runs'])
    except:
        return None

def get_channel_id(content):
    try:
        return content['ownerText']['runs'][0]['navigationEndpoint']['browseEndpoint']['browseId']
    except:
        return None

def get_length(content):
    try:
        length = content['lengthText']['simpleText']
        length = length.split(':')
        if len(length) == 1:
            length.insert(0, '00')
        if len(length) == 2:
            length.insert(0, '00')
        return ':'.join(length)
    except:
        return None

def get_published_date(content):
    try:
        published_time = content['publishedTimeText']['simpleText']
        val = [int(s) for s in published_time.split() if s.isdigit()][0]
        current = dt.datetime.now()
        if 'year' in published_time:
            published = current - dt.timedelta(days=365.25*val)
        elif 'month' in published_time:
            published = current - dt.timedelta(days=30.436875*val)
        elif 'week' in published_time:
            published = current - dt.timedelta(weeks=val)
        elif 'day' in published_time:
            published = current - dt.timedelta(days=val)
        elif 'hour' in published_time:
            published = current - dt.timedelta(hours=val)
        elif 'minute' in published_time:
            published = current - dt.timedelta(minutes=val)
        elif 'second' in published_time:
            published = current - dt.timedelta(seconds=val)
        return published.year, published.month
    except:
        return None, None

def get_view_count(content):
    try:
        view_count = content['viewCountText']['simpleText']
        view_count = view_count.split(' views')[0].replace(',', '')
        return int(view_count)
    except:
        return None

def get_url(content):
    try:
        url = content['navigationEndpoint']['commandMetadata']['webCommandMetadata']['url']
        return base_url + url
    except:
        return None

def get_description(content):
    try:
        description = ' '.join([t['text'] for t in content['detailedMetadataSnippets'][0]['snippetText']['runs']])
        return description
    except:
        return None

def get_skills(title, description):
    context = title
    if description is not None:
        context = context + ' ' + description
    all_skills = extract_skills(context)
    # Ignore the Video skill as it is not relevant for Youtube
    if 'Video' in all_skills:
        all_skills.remove('Video')
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    if len(keep_skills) > 0:
        data_skills = extract_data_skills(keep_skills)
        if len(data_skills) > 0:
            return '; '.join(keep_skills), '; '.join(data_skills)
        return '; '.join(keep_skills), None
    return None, None

# %%
video_list = []
# Iterate through each video
for contents in res:
    # Get only those with video
    if 'itemSectionRenderer' not in contents:
        continue
    contents = contents['itemSectionRenderer']['contents']
    for content in contents:
        # Ignore ads
        if 'videoRenderer' not in content:
            continue
        content = content['videoRenderer']
        title = get_text(content, 'title')
        if title is None:
            continue
        description = get_description(content)
        skills, data_skills = get_skills(title, description)
        published_year, published_month = get_published_date(content)
        video_list.append({
            'id': content['videoId'],
            'title': title,
            'channel_id': get_channel_id(content),
            'channel': get_text(content, 'ownerText'),
            'published_year': published_year,
            'published_month': published_month,
            'length': get_length(content),
            'view_count': get_view_count(content),
            'url': get_url(content),
            'description': description,
            'skills': skills,
            'data_skills': data_skills
        })
df = pd.DataFrame.from_dict(video_list)
df['length'] = pd.to_timedelta(df['length'])
df.head()
# Out:
#             id                                              title  \
# 0  mRMmlo_Uqcs       you need to learn Python RIGHT NOW!! // EP 1
# 1  8124kv-632k                      Python Tutorial for Beginners
# 2  k9WqpQp8VSU  How I Would Learn To Code (If I Could Start Over)
# 3  vLqTf2b6GZw  Python Tutorial for Beginners | Learn Python i...
# 4  kWEbNBXc2-Y  Python Full Course 2022 | Python Tutorial For ...
#
#                  channel_id           channel  published_year  \
# 0  UC9x0AN7BWHpCDHSm9NiJFJQ      NetworkChuck            2021
# 1  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org            2022
# 2  UCLpovxJVLBZrXJGCymB6LYw      Namanh Kapur            2022
# 3  UCBwmMxybNva6P_5VmxjzwqA      Apna College            2021
# 4  UCsvqVGtbbyHaMoevxPAq9Fg       Simplilearn            2022
#
#    published_month          length  view_count  \
# 0                8 0 days 00:17:42    869955.0
# 1                4 0 days 02:52:13    172224.0
# 2                5 0 days 00:13:43    868569.0
# 3               12 0 days 01:17:12   1651019.0
# 4                1 0 days 09:39:29    100904.0
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=mRMmlo_Uqcs
# 1  https://www.youtube.com/watch?v=8124kv-632k
# 2  https://www.youtube.com/watch?v=k9WqpQp8VSU
# 3  https://www.youtube.com/watch?v=vLqTf2b6GZw
# 4  https://www.youtube.com/watch?v=kWEbNBXc2-Y
#
#                                          description  \
# 0  **Sponsored by ITProTV SUPPORT NETWORKCHUCK --...
# 1  Learn  the  Python  programming language in th...
# 2  If I could go back in time and  learn  to code...
# 3  Note - This video shows installation of 2  Pyt...
# 4  Any aspiring programmer can  learn Python  fro...
#
#                                               skills         data_skills
# 0                                             Python  Python Programming
# 1              Programming Language; Python; SystemC  Python Programming
# 2                                             Golang                None
# 3                            Editor; Python; Windows  Python Programming
# 4  Game Development; Golang; Python; Web Development  Python Programming

# %%
def get_youtube_videos(skill, filter_time=None):
    base_url = 'https://www.youtube.com'
    # Dictionary for filtering search query
    sp_dict = {'this_year': 'EgQIBRAB', 'this_month': 'EgQIBBAB', 'this_week': 'EgQIAxAB', 'today': 'EgQIAhAB'}
    if filter_time not in sp_dict.keys():
        return None
    url = base_url + '/results'
    query = 'learn ' + skill
    params = {'search_query': query.replace(' ', '+')}
    # Default is no filter
    if filter_time is not None:
        params['sp'] = sp_dict[filter_time]
    page = requests.get(url, params=params, headers=random.choice(headers_list))
    if page.status_code != 200:
        print(page, page.reason)
        return None
    soup = BeautifulSoup(page.content, 'html.parser')
    json_text = str(soup.find_all('script')).split('var ytInitialData = ')[-1].split(';</script>')[0]
    res = json.loads(json_text)
    res = res['contents']['twoColumnSearchResultsRenderer']['primaryContents']['sectionListRenderer']['contents']
    video_list = []
    # Iterate through each video
    for contents in res:
        # Get only those with video
        if 'itemSectionRenderer' not in contents:
            continue
        contents = contents['itemSectionRenderer']['contents']
        for content in contents:
            # Ignore ads
            if 'videoRenderer' not in content:
                continue
            content = content['videoRenderer']
            title = get_text(content, 'title')
            if title is None:
                continue
            description = get_description(content)
            skills, data_skills = get_skills(title, description)
            published_year, published_month = get_published_date(content)
            video_list.append({
                'id': content['videoId'],
                'title': title,
                'channel_id': get_channel_id(content),
                'channel': get_text(content, 'ownerText'),
                'published_year': published_year,
                'published_month': published_month,
                'length': get_length(content),
                'view_count': get_view_count(content),
                'url': get_url(content),
                'description': description,
                'skills': skills,
                'data_skills': data_skills
            })
    df = pd.DataFrame.from_dict(video_list) 
    df['length'] = pd.to_timedelta(df['length'])
    return df

# %%
df_yt = pd.DataFrame()
ignore = ['apache', 'c++', 'financial statement']

for skill in log_progress(DATA_SKILLS):
    if skill.lower() in ignore:
        continue
    df_temp = get_youtube_videos(skill, 'this_year')
    df_yt = df_yt.append(df_temp)
    time.sleep(5)

df_yt.head()
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=37)))
#             id                                              title  \
# 0  lBBtq3Oawqw  MongoDB Full Course | MongoDB Tutorial | Mongo...
# 1  Www6cTUymCY       MongoDB Tutorial For Beginners | Full Course
# 2  SnqPyqRh4r4  What Is MongoDB? | What Is MongoDB And How It ...
# 3  ofme2o29ngU                               MongoDB Crash Course
# 4  oSIv-E60NiU         MongoDb Tutorial For Beginners in Hindi 🔥🔥
#
#               channel  published_year  published_month          length  \
# 0         Simplilearn            2021                7 0 days 02:16:59
# 1          Amigoscode            2021                6 0 days 01:08:31
# 2         Simplilearn            2021                4 0 days 00:06:32
# 3  Web Dev Simplified            2021                9 0 days 00:29:59
# 4       CodeWithHarry            2021                7 0 days 01:13:36
#
#    view_count                                          url  \
# 0     15375.0  https://www.youtube.com/watch?v=lBBtq3Oawqw
# 1     39019.0  https://www.youtube.com/watch?v=Www6cTUymCY
# 2     23857.0  https://www.youtube.com/watch?v=SnqPyqRh4r4
# 3     22333.0  https://www.youtube.com/watch?v=ofme2o29ngU
# 4    161229.0  https://www.youtube.com/watch?v=oSIv-E60NiU
#
#                                          description  \
# 0  This  MongoDB  full course will help you under...
# 1  MongoDB  is great database for any project. In...
# 2  So here's the list of topics covered: 00:00:00...
# 3  MongoDB  Cheat Sheet: https://webdevsimplified...
# 4  MongoDB  crash course: In this video, we will ...
#
#                             skills      data_skills
# 0         Database; MongoDB; NoSQL  Mongo DB; NoSQL
# 1                Database; MongoDB         Mongo DB
# 2                          MongoDB         Mongo DB
# 3         Database; MongoDB; NoSQL  Mongo DB; NoSQL
# 4  Database; Hindi; MongoDB; NoSQL  Mongo DB; NoSQL

# %%
len(df_yt), len(df_yt.drop_duplicates()), len(df_yt.drop_duplicates(subset='id'))
# Out:
# (740, 727, 698)

# %%
df_yt = df_yt.drop_duplicates(subset='id')
df_yt = df_yt.sort_values(by=['published_year', 'published_month', 'id'])
# df_yt['view_count'] = df_yt['view_count'].astype(int)
df_yt.head()
# Out:
#              id                                              title  \
# 14  -T_l8TjAzXk  WHY LEARN TABLEAU? | Is Tableau worth learning...
# 11  0nH1ospwJd4  4 Quick Tips to Make an Engaging PowerPoint Pr...
# 19  1LHch7usbzY         Processing Covid-19 Data with Apache Spark
# 8   2ViNp_UijMQ  Apache Spark with Scala By Example - learn Apa...
# 13  2sTeNU3nE3o                         ETL explained in 5 Minutes
#
#                  channel  published_year  published_month          length  \
# 14     Abhishek Agarrwal            2020               10 0 days 00:12:04
# 11            ClassPoint            2020               10 0 days 00:09:36
# 19  Manning Publications            2020               10 0 days 01:14:32
# 8         Petrina Corine            2020               10 0 days 00:03:46
# 13           DaveSplains            2020               10 0 days 00:04:50
#
#     view_count                                          url  \
# 14      6634.0  https://www.youtube.com/watch?v=-T_l8TjAzXk
# 11      5578.0  https://www.youtube.com/watch?v=0nH1ospwJd4
# 19      1056.0  https://www.youtube.com/watch?v=1LHch7usbzY
# 8          5.0  https://www.youtube.com/watch?v=2ViNp_UijMQ
# 13       132.0  https://www.youtube.com/watch?v=2sTeNU3nE3o
#
#                                           description  \
# 14  Many people who are a beginner and aspiring to...
# 11  Here're 4 quick tips on how to make engaging P...
# 19  "Spark in Action, Second Edition: Covers  Apac...
# 8   Learn  the fundamentals and run examplesof Spa...
# 13  The concept of  Extract Transform Load , or  E...
#
#                                                skills  \
# 14  Business Intelligence (BI); Business Intellige...
# 11      Animation; Microsoft PowerPoint; Presentation
# 19      Apache Spark; Java; Processing; Python; Scala
# 8   Apache Spark; Dataset; Distributed Database; S...
# 13  Extract Transform Load (ETL); Programming; Tra...
#
#                         data_skills
# 14                          Tableau
# 11               Presentation Skill
# 19  SPARK; Java; Python Programming
# 8                             SPARK
# 13                              ETL

# %%
df_yt.to_csv('database/youtube.csv', index=False)
