# %%
import requests
import random
import pandas as pd
import re
import json
import datetime as dt
from bs4 import BeautifulSoup
from headers import headers_list
from loading_bar import log_progress
from data_skills import SKILLS, SKILL_DICT
from skill_extraction import extract_skills, extract_ignore
from secrets import api_keys

# %%
URL = 'https://www.googleapis.com/youtube/v3/search'
ORDERS = ['date', 'rating', 'relevance', 'title', 'videoCount', 'viewCount']

API_KEY = api_keys['youtube']
# Must be in RFC 3339 formatted date-time value (1970-01-01T00:00:00Z)
START_DATE = (dt.datetime.now(dt.timezone.utc) - dt.timedelta(days=365.25)).isoformat()

# %%
def get_youtube_videos(query, max_results=50, order='viewCount', start_date=None):
    params = {'q': query, 'part': 'snippet', 'type': 'video', 'maxResults': max_results, 'order': order,
              'key': API_KEY}
    if start_date is not None:
        params['publishedAfter'] = start_date
    page = requests.get(URL, params=params, headers=random.choice(headers_list))
    if page.status_code != 200:
        return None
    res = json.loads(page.content.decode('utf8'))
    video_dict = []
    video_url = 'https://youtube.com/watch?v='
    for i, item in enumerate(res['items']):
        video_id = get_object(item['id'], 'videoId')
        snippet = item['snippet']
        video_dict.append({
            'id': video_id,
            'title': get_object(snippet, 'title'),
            'channel': get_object(snippet, 'channelTitle'),
            'url': video_url + video_id,
            'published_date': get_object(snippet, 'publishTime'),
            'description': get_object(snippet, 'description'),
            'relevance': i+1
        })
    return pd.DataFrame.from_dict(video_dict)

def get_object(item, key):
    try:
        return item[key]
    except:
        return None

# %%
df = pd.DataFrame()

for i in log_progress(range(len(SKILLS))):
    skill = SKILLS[i]
    query = 'learn ' + skill
    df_temp = get_youtube_videos(query, order='relevance')
    df_temp['data_skills'] = skill
    df = df.append(df_temp)

df.head()
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=37)))
#             id                                              title  \
# 0  rCr3-YlL5S8                         Basics of Apache Webserver
# 1  0E3RAUIx1Ms  How to play Apache by The Shadows - Guitar Les...
# 2  zC9cnh8rJd0  Spark Tutorial | Spark Tutorial for Beginners ...
# 3  L-GRrGAghKk                    Bylas Apache Lesson 1 Greetings
# 4  RG77qqGwVls                                 Bike chalana Sikha
#
#                   channel                                      url  \
# 0              Amit Nepal  https://youtube.com/watch?v=rCr3-YlL5S8
# 1  Heanor School Of Music  https://youtube.com/watch?v=0E3RAUIx1Ms
# 2          Great Learning  https://youtube.com/watch?v=zC9cnh8rJd0
# 3              Safford JW  https://youtube.com/watch?v=L-GRrGAghKk
# 4    Samiul Aashiqui wala  https://youtube.com/watch?v=RG77qqGwVls
#
#          published_date                                        description  \
# 0  2019-07-07T18:45:01Z  A video tutorial on the basics of Apache Web S...
# 1  2015-07-19T12:28:54Z  How to play Apache by The Shadows In this guit...
# 2  2020-04-24T11:55:52Z  Great Learning offers a range of extensive Dat...
# 3  2015-11-04T17:53:51Z  This is basic greetings in the Bylas Apache La...
# 4  2018-01-19T08:05:30Z                                      Samiul Islam.
#
#    relevance data_skills
# 0          1      APACHE
# 1          2      APACHE
# 2          3      APACHE
# 3          4      APACHE
# 4          5      APACHE

# %%
len(df), len(df.drop_duplicates(subset=['id']))
# Out:
# (1850, 1793)

# %%
df = df.merge(df.groupby('id').mean(), left_on='id', right_index=True)
df = df.merge(df[['id', 'data_skills']].groupby('id').agg(lambda x: '; '.join(x)), left_on='id', right_index=True)
df.head()
# Out:
#             id                                              title  \
# 0  rCr3-YlL5S8                         Basics of Apache Webserver
# 1  0E3RAUIx1Ms  How to play Apache by The Shadows - Guitar Les...
# 2  zC9cnh8rJd0  Spark Tutorial | Spark Tutorial for Beginners ...
# 0  zC9cnh8rJd0  Spark Tutorial | Spark Tutorial for Beginners ...
# 3  L-GRrGAghKk                    Bylas Apache Lesson 1 Greetings
#
#                   channel                                      url  \
# 0              Amit Nepal  https://youtube.com/watch?v=rCr3-YlL5S8
# 1  Heanor School Of Music  https://youtube.com/watch?v=0E3RAUIx1Ms
# 2          Great Learning  https://youtube.com/watch?v=zC9cnh8rJd0
# 0          Great Learning  https://youtube.com/watch?v=zC9cnh8rJd0
# 3              Safford JW  https://youtube.com/watch?v=L-GRrGAghKk
#
#          published_date                                        description  \
# 0  2019-07-07T18:45:01Z  A video tutorial on the basics of Apache Web S...
# 1  2015-07-19T12:28:54Z  How to play Apache by The Shadows In this guit...
# 2  2020-04-24T11:55:52Z  Great Learning offers a range of extensive Dat...
# 0  2020-04-24T11:55:52Z  Great Learning offers a range of extensive Dat...
# 3  2015-11-04T17:53:51Z  This is basic greetings in the Bylas Apache La...
#
#    relevance_x data_skills_x  relevance_y  data_skills_y
# 0            1        APACHE          1.0         APACHE
# 1            2        APACHE          2.0         APACHE
# 2            3        APACHE          2.0  APACHE; SPARK
# 0            1         SPARK          2.0  APACHE; SPARK
# 3            4        APACHE          4.0         APACHE

# %%
df = df.drop_duplicates(subset=['id'])
df = df.drop(columns=['relevance_x', 'data_skills_x'])
df = df.rename(columns={'relevance_y': 'relevance', 'data_skills_y': 'data_skills'})
df = df.reset_index(drop=True)
df.head()
# Out:
#             id                                              title  \
# 0  rCr3-YlL5S8                         Basics of Apache Webserver
# 1  0E3RAUIx1Ms  How to play Apache by The Shadows - Guitar Les...
# 2  zC9cnh8rJd0  Spark Tutorial | Spark Tutorial for Beginners ...
# 3  L-GRrGAghKk                    Bylas Apache Lesson 1 Greetings
# 4  RG77qqGwVls                                 Bike chalana Sikha
#
#                   channel                                      url  \
# 0              Amit Nepal  https://youtube.com/watch?v=rCr3-YlL5S8
# 1  Heanor School Of Music  https://youtube.com/watch?v=0E3RAUIx1Ms
# 2          Great Learning  https://youtube.com/watch?v=zC9cnh8rJd0
# 3              Safford JW  https://youtube.com/watch?v=L-GRrGAghKk
# 4    Samiul Aashiqui wala  https://youtube.com/watch?v=RG77qqGwVls
#
#          published_date                                        description  \
# 0  2019-07-07T18:45:01Z  A video tutorial on the basics of Apache Web S...
# 1  2015-07-19T12:28:54Z  How to play Apache by The Shadows In this guit...
# 2  2020-04-24T11:55:52Z  Great Learning offers a range of extensive Dat...
# 3  2015-11-04T17:53:51Z  This is basic greetings in the Bylas Apache La...
# 4  2018-01-19T08:05:30Z                                      Samiul Islam.
#
#    relevance    data_skills
# 0        1.0         APACHE
# 1        2.0         APACHE
# 2        2.0  APACHE; SPARK
# 3        4.0         APACHE
# 4        5.0         APACHE

# %%
def get_full_description(video_id):
    url = 'https://www.googleapis.com/youtube/v3/videos'
    params = {'part': 'snippet', 'id': video_id, 'key': API_KEY}
    page = requests.get(url, params=params, headers=random.choice(headers_list))
    if page.status_code != 200:
        return None
    try:
        res = json.loads(page.content.decode('utf8'))
        return res['items'][0]['snippet']['description']
    except:
        return None

# %%
df['description_full'] = None
df['skills'] = None

for i in log_progress(range(0, len(df))):
    row = df.loc[i]
    full_text = row['title']
    if row['description'].endswith('...'):
        full_description = get_full_description(row['id'])
        full_text += ' ' + full_description
        df.loc[i, 'description_full'] = full_description
    else:
        full_text += ' ' + row['description']
    all_skills = extract_skills(full_text)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    df.loc[i, 'skills'] = '; '.join(keep_skills)

df.head()
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1789)))
#             id                                              title  \
# 0  rCr3-YlL5S8                         Basics of Apache Webserver
# 1  0E3RAUIx1Ms  How to play Apache by The Shadows - Guitar Les...
# 2  zC9cnh8rJd0  Spark Tutorial | Spark Tutorial for Beginners ...
# 3  L-GRrGAghKk                    Bylas Apache Lesson 1 Greetings
# 4  RG77qqGwVls                                 Bike chalana Sikha
#
#                   channel                                      url  \
# 0              Amit Nepal  https://youtube.com/watch?v=rCr3-YlL5S8
# 1  Heanor School Of Music  https://youtube.com/watch?v=0E3RAUIx1Ms
# 2          Great Learning  https://youtube.com/watch?v=zC9cnh8rJd0
# 3              Safford JW  https://youtube.com/watch?v=L-GRrGAghKk
# 4    Samiul Aashiqui wala  https://youtube.com/watch?v=RG77qqGwVls
#
#          published_date                                        description  \
# 0  2019-07-07T18:45:01Z  A video tutorial on the basics of Apache Web S...
# 1  2015-07-19T12:28:54Z  How to play Apache by The Shadows In this guit...
# 2  2020-04-24T11:55:52Z  Great Learning offers a range of extensive Dat...
# 3  2015-11-04T17:53:51Z  This is basic greetings in the Bylas Apache La...
# 4  2018-01-19T08:05:30Z                                      Samiul Islam.
#
#   data_skills                                   description_full  \
# 0      APACHE  A video tutorial on the basics of Apache Web S...
# 1      APACHE  How to play Apache by The Shadows\n\nIn this g...
# 2      APACHE  Great Learning offers a range of extensive Dat...
# 3      APACHE                                               None
# 4      APACHE                                               None
#
#                                               skills
# 0  Apache; Configuration; Operating System; Servi...
# 1    Apache; Facebook; Music; Play; Twitter; Youtube
# 2  Apache Hadoop; Apache Hive; Apache Spark; Apac...
# 3                                             Apache
# 4

# %%
df.loc[df['skills'] == '', 'skills'] = None
df.loc[df['skills'].isna()]
# Out:
#                id                                              title  \
# 4     RG77qqGwVls                                 Bike chalana Sikha
# 1598  uMz6LtCOU6A                How to AB Test with Google Optimize
# 1659  2UphAzryVpY  A different way to visualize rhythm - John Varney
#
#                    channel                                      url  \
# 4     Samiul Aashiqui wala  https://youtube.com/watch?v=RG77qqGwVls
# 1598        Digital Basics  https://youtube.com/watch?v=uMz6LtCOU6A
# 1659                TED-Ed  https://youtube.com/watch?v=2UphAzryVpY
#
#             published_date                                        description  \
# 4     2018-01-19T08:05:30Z                                      Samiul Islam.
# 1598  2019-03-05T13:08:27Z  Learn how to modify and change parts of your w...
# 1659  2014-10-20T15:27:13Z  View full lesson: http://ed.ted.com/lessons/a-...
#
#       relevance     data_skills description_full skills
# 4           5.0          APACHE             None   None
# 1598       14.0      AB Testing             None   None
# 1659       32.0  Visualizations             None   None

# %%
df = df.sort_values(by='id')
df.drop(columns=['description_full']).to_csv('results/youtube.csv', index=False)
df.to_csv('results/youtube_full.csv', index=False)
