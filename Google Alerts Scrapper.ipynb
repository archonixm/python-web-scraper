# %%
import requests
import random
import pandas as pd
import re
from bs4 import BeautifulSoup
from bs4.element import Comment
from datetime import datetime
from headers import headers_list
from loading_bar import log_progress
from skill_extraction import extract_skills, extract_ignore
from secrets import rss_links

# %%
def get_id(entry):
    id_ = entry.find('id')
    try:
        return id_.text.split(':')[-1]
    except:
        return None

def get_text(item):
    try:
        return item.text
    except:
        return None

def get_url(item):
    try:
        url = item['href']
        return url.split('url=')[-1].split('&')[0]
    except:
        return None

def get_author(entry):
    authors = entry.find('author')
    if len(authors) == 0:
        return None
    try:
        return '; '.join(a.text for a in authors)
    except:
        return None

def get_page_text(url):
    try:
        page = requests.get(url, headers=random.choice(headers_list))
        if page.status_code != 200:
            return None
        soup = BeautifulSoup(page.content, 'html.parser')
        texts = soup.findAll(text=True)
        visible_texts = filter(tag_visible, texts)
        return u" ".join(t.strip() for t in visible_texts if len(t.strip()) > 0).replace('\n', ' ')
    except:
        return None

def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

# %%
def get_content(url):
    page = requests.get(url, headers=random.choice(headers_list))
    soup = BeautifulSoup(page.content, 'html.parser')
    entries = soup.findAll('entry')
    entry_list = []
    entry_list = []
    for entry in entries:
        page_url = get_url(entry.find('link'))
        entry_list.append({
            'id': get_id(entry),
            'title': get_text(entry.find('title')),
            'url': page_url,
            'published_date': get_text(entry.find('published')),
            'updated_date': get_text(entry.find('updated')),
            'content': get_text(entry.find('content')),
            'author': get_author(entry),
            'page_text': get_page_text(page_url),
        })

    df = pd.DataFrame.from_dict(entry_list)
    df['published_date'] = pd.to_datetime(df['published_date'])
    df['updated_date'] = pd.to_datetime(df['updated_date'])
    return df

# %%
df_ds = get_content(rss_links['Data Science'])
df_ds.head()
# Out:
#                     id                                              title  \
# 0  5410161394141722453  <b>Data Science</b> Platform Market Expected t...
# 1  9544898260592202046  Dubber acquires world class AI technology comp...
# 2  8799730211579595871  Srikrishnan V, vice-president - Enterprise Bus...
# 3  4619331074291668668  Targeted, hyperlocal, personalized… PepsiCo mi...
# 4  4339679955055703986  Unleashing 5G with semiconductor chip innovati...
#
#                                                  url  \
# 0  https://soccernurds.com/uncategorized/5794380/...
# 1  https://www.prnewswire.com/news-releases/dubbe...
# 2  https://www.financialexpress.com/education-2/w...
# 3  https://www.foodnavigator-usa.com/Article/2021...
# 4  https://www.straitstimes.com/branded-content/u...
#
#              published_date              updated_date  \
# 0 2021-09-20 01:28:31+00:00 2021-09-20 01:28:31+00:00
# 1 2021-09-19 23:48:45+00:00 2021-09-19 23:48:45+00:00
# 2 2021-09-19 21:56:15+00:00 2021-09-19 21:56:15+00:00
# 3 2021-09-19 20:48:45+00:00 2021-09-19 20:48:45+00:00
# 4 2021-09-19 20:05:15+00:00 2021-09-19 20:05:15+00:00
#
#                                              content author  \
# 0  <b>Data Science</b> Platform Market Expected t...   None
# 1  We welcome the Notiv team to Dubber along with...   None
# 2  ... full stack development, <b>data science</b...   None
# 3  A proprietary data practice developed by Pepsi...   None
# 4  ... last year as a Global Lighthouse for its e...   None
#
#                                            page_text
# 0  Skip to content Search for: SoccerNurds Primar...
# 1  Resources Blog Journalists Log In Sign Up Data...
# 2  Home India News Markets Stocks Health Economy ...
# 3  CONTINUE TO SITE > Or wait... Home News News M...
# 4                                               None

# %%
df_ai = get_content(rss_links['Artificial Intelligence'])
df_ai.head()
# Out:
#                      id                                              title  \
# 0  13014725768370886466  Justice, Equity, And Fairness: Exploring The T...
# 1  14622698968680201748  Hamilton County court officials see number of ...
# 2  12394354945011969774  Dubber acquires world class AI technology comp...
# 3   6871009256076724404  Covid-19 is a &#39;wake-up call&#39; to act on...
# 4  11536432840799974222  Can apps manage our chronic health conditions?...
#
#                                                  url  \
# 0  https://www.forbes.com/sites/anniebrown/2021/0...
# 1  https://www.wlwt.com/article/hamilton-county-c...
# 2  https://www.prnewswire.com/news-releases/dubbe...
# 3  https://www.cnbc.com/2021/09/20/covid-is-call-...
# 4         https://www.bbc.com/news/business-58556777
#
#              published_date              updated_date  \
# 0 2021-09-20 01:30:00+00:00 2021-09-20 01:30:00+00:00
# 1 2021-09-20 01:30:00+00:00 2021-09-20 01:30:00+00:00
# 2 2021-09-19 23:48:45+00:00 2021-09-19 23:48:45+00:00
# 3 2021-09-19 23:26:15+00:00 2021-09-19 23:26:15+00:00
# 4 2021-09-19 23:03:45+00:00 2021-09-19 23:03:45+00:00
#
#                                              content author  \
# 0  How <b>artificial intelligence</b> is impactin...   None
# 1  The court is launching new <b>artificial intel...   None
# 2  Adds advanced technology capabilities in real-...   None
# 3  The firm developed an <b>artificial intelligen...   None
# 4  The 55-year-old, from Stockholm, says it&#39;s...   None
#
#                                            page_text
# 0  Explore Billionaires All Billionaires World's ...
# 1  Skip to content NOWCAST WLWT News on METV at 1...
# 2  Resources Blog Journalists Log In Sign Up Data...
# 3  Skip Navigation Markets Pre-Markets U.S. Marke...
# 4  BBC Homepage Skip to content Accessibility Hel...

# %%
df_ml = get_content(rss_links['Machine Learning'])
df_ml.head()
# Out:
#                      id                                              title  \
# 0  16875981523583924953  How to reshape business strategy to be future-...
# 1   7827283391740030815  Justice, Equity, And Fairness: Exploring The T...
# 2   2165638237057178897  Leonid Bershidsky column: &#39;Techlash&#39; i...
# 3  12161401120620571128  Doctors to use remotely controlled robot to as...
# 4    257248246512481826  Fusionex Signs MoU with Alliance Islamic Bank ...
#
#                                                  url  \
# 0  https://www.bit.com.au/guide/how-to-reshape-bu...
# 1  https://www.forbes.com/sites/anniebrown/2021/0...
# 2  https://richmond.com/opinion/columnists/leonid...
# 3  https://uk.sports.yahoo.com/news/doctors-remot...
# 4  https://www.kulr8.com/news/money/fusionex-sign...
#
#              published_date              updated_date  \
# 0 2021-09-20 01:41:15+00:00 2021-09-20 01:41:15+00:00
# 1 2021-09-20 01:30:00+00:00 2021-09-20 01:30:00+00:00
# 2 2021-09-19 23:03:45+00:00 2021-09-19 23:03:45+00:00
# 3 2021-09-19 23:03:45+00:00 2021-09-19 23:03:45+00:00
# 4 2021-09-19 22:52:30+00:00 2021-09-19 22:52:30+00:00
#
#                                              content author  \
# 0  <b>Machine learning</b> will filter the standa...   None
# 1  There have also been studies that prove that <...   None
# 2  (Bloomberg uses supervised <b>machine learning...   None
# 3  ... will use technology pioneered by The Natio...   None
# 4  ... <b>Machine Learning</b> and Artificial Int...   None
#
#                                            page_text
# 0  Log In Subscribe Reviews Photo Galleries Guide...
# 1  Explore Billionaires All Billionaires World's ...
# 2  Skip to main content × × Please register or lo...
# 3  guce Your data. Your experience. Yahoo is part...
# 4  You have permission to edit this article. Edit...

# %%
df = df_ds.append(df_ai)
df = df.append(df_ml)
df = df.sort_values(by='id')
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.head()
# Out:
#                      id                                              title  \
# 0  10398587313766518210  Fusionex Signs MoU with Alliance Islamic Bank ...
# 1  11399624425384127367  Honor and Microsoft have teamed up to build ne...
# 2  11536432840799974222  Can apps manage our chronic health conditions?...
# 3  11932885372878281443  Safety-minded feds want Tesla to pump the brak...
# 4  12104198783093585461          Network Security Market 2021 - Datamation
#
#                                                  url  \
# 0  https://finance.yahoo.com/news/fusionex-signs-...
# 1  https://thedigitalhacker.com/honor-and-microso...
# 2         https://www.bbc.com/news/business-58556777
# 3  https://mashable.com/article/tesla-full-self-d...
# 4  https://www.datamation.com/security/network-se...
#
#              published_date              updated_date  \
# 0 2021-09-19 22:52:30+00:00 2021-09-19 22:52:30+00:00
# 1 2021-09-19 18:33:15+00:00 2021-09-19 18:33:15+00:00
# 2 2021-09-19 23:03:45+00:00 2021-09-19 23:03:45+00:00
# 3 2021-09-19 16:56:16+00:00 2021-09-19 16:56:16+00:00
# 4 2021-09-19 16:52:30+00:00 2021-09-19 16:52:30+00:00
#
#                                              content author  \
# 0  PETALING JAYA, Malaysia, September 19, 2021--(...   None
# 1  Honor and Microsoft have teamed up to build ne...   None
# 2  The 55-year-old, from Stockholm, says it&#39;s...   None
# 3  These features, which are powered by <b>machin...   None
# 4  More recently, the network detection and respo...   None
#
#                                            page_text
# 0  HOME MAIL NEWS FINANCE SPORTS ENTERTAINMENT LI...
# 1  Sunday, September 19 2021 Trending Honor and M...
# 2  BBC Homepage Skip to content Accessibility Hel...
# 3  Tech Life Social Good Entertainment Newsletter...
# 4  Trends Big Data Data Center AI Cloud Applicati...

# %%
df.loc[df['page_text'].isna()]
# Out:
#                      id                                              title  \
# 28  4339679955055703986  Unleashing 5G with semiconductor chip innovati...
#
#                                                   url  \
# 28  https://www.straitstimes.com/branded-content/u...
#
#               published_date              updated_date  \
# 28 2021-09-19 20:05:15+00:00 2021-09-19 20:05:15+00:00
#
#                                               content author page_text
# 28  ... last year as a Global Lighthouse for its e...   None      None

# %%
df.to_csv('results/contents.csv', mode='a', header=False, index=False)

# %%
for i, row in df.iterrows():
    content = row['page_text']
    if not isinstance(content, str):
        continue
    all_skills = extract_skills(content)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    df.loc[i, 'skills'] = '; '.join(keep_skills)

df.head()
# Out:
#                      id                                              title  \
# 0  10398587313766518210  Fusionex Signs MoU with Alliance Islamic Bank ...
# 1  11399624425384127367  Honor and Microsoft have teamed up to build ne...
# 2  11536432840799974222  Can apps manage our chronic health conditions?...
# 3  11932885372878281443  Safety-minded feds want Tesla to pump the brak...
# 4  12104198783093585461          Network Security Market 2021 - Datamation
#
#                                                  url  \
# 0  https://finance.yahoo.com/news/fusionex-signs-...
# 1  https://thedigitalhacker.com/honor-and-microso...
# 2         https://www.bbc.com/news/business-58556777
# 3  https://mashable.com/article/tesla-full-self-d...
# 4  https://www.datamation.com/security/network-se...
#
#              published_date              updated_date  \
# 0 2021-09-19 22:52:30+00:00 2021-09-19 22:52:30+00:00
# 1 2021-09-19 18:33:15+00:00 2021-09-19 18:33:15+00:00
# 2 2021-09-19 23:03:45+00:00 2021-09-19 23:03:45+00:00
# 3 2021-09-19 16:56:16+00:00 2021-09-19 16:56:16+00:00
# 4 2021-09-19 16:52:30+00:00 2021-09-19 16:52:30+00:00
#
#                                              content author  \
# 0  PETALING JAYA, Malaysia, September 19, 2021--(...   None
# 1  Honor and Microsoft have teamed up to build ne...   None
# 2  The 55-year-old, from Stockholm, says it&#39;s...   None
# 3  These features, which are powered by <b>machin...   None
# 4  More recently, the network detection and respo...   None
#
#                                            page_text  \
# 0  HOME MAIL NEWS FINANCE SPORTS ENTERTAINMENT LI...
# 1  Sunday, September 19 2021 Trending Honor and M...
# 2  BBC Homepage Skip to content Accessibility Hel...
# 3  Tech Life Social Good Entertainment Newsletter...
# 4  Trends Big Data Data Center AI Cloud Applicati...
#
#                                               skills
# 0  .NET Framework; Array; Artificial Intelligence...
# 1  Artificial Intelligence (AI); Collaboration; C...
# 2  .NET Framework; Artificial Intelligence (AI); ...
# 3  Blink; Branding; Communication; Cybercrime; Cy...
# 4  Analysis; Analytical; Anomaly Detection; Archi...

# %%
df.loc[df['skills'].isna()]
# Out:
#                      id                                              title  \
# 28  4339679955055703986  Unleashing 5G with semiconductor chip innovati...
#
#                                                   url  \
# 28  https://www.straitstimes.com/branded-content/u...
#
#               published_date              updated_date  \
# 28 2021-09-19 20:05:15+00:00 2021-09-19 20:05:15+00:00
#
#                                               content author page_text skills
# 28  ... last year as a Global Lighthouse for its e...   None      None    NaN

# %%
df.drop(columns=['page_text']).to_csv('results/contents_skills.csv', mode='a', header=False, index=False)
