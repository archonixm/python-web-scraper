# %%
import requests
import random
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from headers import headers_list
from loading_bar import log_progress
from secrets import rss_links

# %%
def get_content(url):
    page = requests.get(url, headers=random.choice(headers_list))
    soup = BeautifulSoup(page.content, 'html.parser')
    entries = soup.findAll('entry')
    entry_list = []
    entry_list = []
    for entry in entries:
        entry_list.append({
            'id': get_id(entry),
            'title': get_text(entry.find('title')),
            'url': get_url(entry.find('link')),
            'published_date': get_text(entry.find('published')),
            'updated_date': get_text(entry.find('updated')),
            'content': get_text(entry.find('content')),
            'author': get_author(entry),
        })

    df = pd.DataFrame.from_dict(entry_list)
    df['published_date'] = pd.to_datetime(df['published_date'])
    df['updated_date'] = pd.to_datetime(df['updated_date'])
    return df

# %%
def get_id(entry):
    id_ = entry.find('id')
    try:
        return id_.text.split(':')[-1]
    except:
        return None

def get_text(item):
    try:
        return item.text
    except:
        return None

def get_url(item):
    try:
        return item['href']
    except:
        return None

def get_author(entry):
    authors = entry.find('author')
    if len(authors) == 0:
        return None
    try:
        return '; '.join(a.text for a in authors)
    except:
        return None

# %%
df_ds = get_content(rss_links['Data Science'])
df_ds.head()
# Out:
#                      id                                              title  \
# 0  17140745780390785304  A 10-Course Introduction to <b>Data Science</b...
# 1   9727360739504798718  Who&#39;s hiring in Pittsburgh? Aurora, Carlow...
# 2  12332808078289061785  Our classroom is becoming more flexible, hybri...
# 3  15919742716733308327  Radio ratings to include livestreaming data - ...
# 4  17834455628474359737  Axiata Digital Labs announces first-ever ADL A...
#
#                                                  url  \
# 0  https://www.google.com/url?rct=j&sa=t&url=http...
# 1  https://www.google.com/url?rct=j&sa=t&url=http...
# 2  https://www.google.com/url?rct=j&sa=t&url=http...
# 3  https://www.google.com/url?rct=j&sa=t&url=http...
# 4  https://www.google.com/url?rct=j&sa=t&url=http...
#
#              published_date              updated_date  \
# 0 2021-09-13 00:18:17+00:00 2021-09-13 00:18:17+00:00
# 1 2021-09-13 00:00:00+00:00 2021-09-13 00:00:00+00:00
# 2 2021-09-12 22:30:00+00:00 2021-09-12 22:30:00+00:00
# 3 2021-09-12 21:00:00+00:00 2021-09-12 21:00:00+00:00
# 4 2021-09-12 21:00:00+00:00 2021-09-12 21:00:00+00:00
#
#                                              content author
# 0  Data is now everywhere. And those who can harn...   None
# 1  Aurora has an opening for an Autonomy Safety <...   None
# 2  We also launched the online BSc in Programming...   None
# 3  ... strongest radio markets in the world and t...   None
# 4  “This event will enable <b>data science</b> an...   None

# %%
df_ai = get_content(rss_links['Artificial Intelligence'])
df_ai.head()
# Out:
#                      id                                              title  \
# 0   2067305417285265579  <b>Artificial Intelligence</b> (AI) in Cyberse...
# 1  14877738212203842889  CMS Awards NCI $112M Contract Extension Suppor...
# 2   6357025403358493258  Patrol cams adding more security to local park...
# 3   7397605872053070764  BioXcel Therapeutics to Present Updates from O...
# 4  13462936679277205821  Decisiv Unveils Automatic VMRS Encoding Soluti...
#
#                                                  url  \
# 0  https://www.google.com/url?rct=j&sa=t&url=http...
# 1  https://www.google.com/url?rct=j&sa=t&url=http...
# 2  https://www.google.com/url?rct=j&sa=t&url=http...
# 3  https://www.google.com/url?rct=j&sa=t&url=http...
# 4  https://www.google.com/url?rct=j&sa=t&url=http...
#
#              published_date              updated_date  \
# 0 2021-09-13 00:56:15+00:00 2021-09-13 00:56:15+00:00
# 1 2021-09-12 22:52:30+00:00 2021-09-12 22:52:30+00:00
# 2 2021-09-12 22:18:03+00:00 2021-09-12 22:18:03+00:00
# 3 2021-09-12 21:56:15+00:00 2021-09-12 21:56:15+00:00
# 4 2021-09-12 21:53:21+00:00 2021-09-12 21:53:21+00:00
#
#                                              content author
# 0  Organizations across industries are turning to...   None
# 1  Under the Comprehensive Error Rate Testing con...   None
# 2  Lindsey also says the cameras use <b>artificia...   None
# 3  ... a clinical-stage biopharmaceutical company...   None
# 4  The VMRS Encoding for Fleets analyzes individu...   None

# %%
df_ml = get_content(rss_links['Machine Learning'])
df_ml.head()
# Out:
#                      id                                              title  \
# 0   2346801807311996214  Artificial Intelligence (AI) in Cybersecurity ...
# 1   2817446043385123314  Who&#39;s hiring in Pittsburgh? Aurora, Carlow...
# 2  15874292272497799359  CMS Awards NCI $112M Contract Extension Suppor...
# 3  14512119619492113720  SJC sets limits on use of police body camera f...
# 4  17187327455440134029  BioXcel Therapeutics to Present Updates from O...
#
#                                                  url  \
# 0  https://www.google.com/url?rct=j&sa=t&url=http...
# 1  https://www.google.com/url?rct=j&sa=t&url=http...
# 2  https://www.google.com/url?rct=j&sa=t&url=http...
# 3  https://www.google.com/url?rct=j&sa=t&url=http...
# 4  https://www.google.com/url?rct=j&sa=t&url=http...
#
#              published_date              updated_date  \
# 0 2021-09-13 00:56:15+00:00 2021-09-13 00:56:15+00:00
# 1 2021-09-13 00:00:00+00:00 2021-09-13 00:00:00+00:00
# 2 2021-09-12 22:52:30+00:00 2021-09-12 22:52:30+00:00
# 3 2021-09-12 22:07:30+00:00 2021-09-12 22:07:30+00:00
# 4 2021-09-12 21:56:15+00:00 2021-09-12 21:56:15+00:00
#
#                                              content author
# 0  Platforms enhanced by <b>machine learning</b> ...   None
# 1  Peptilogics seeks a <b>Machine Learning</b> Sc...   None
# 2  “As federal agencies continue to embrace artif...   None
# 3  “When combined with limitless data storage and...   None
# 4  ... validated product candidates together with...   None

# %%
df = df_ds.append(df_ai)
df = df.append(df_ml)
df = df.sort_values(by='id')
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.head()
# Out:
#                      id                                              title  \
# 0  10058609923349150707  Computer science continues to be favourite amo...
# 1  10257980602360460347  Yinqiu He - The <b>Data Science</b> Institute ...
# 2  10369779799486769808  <b>Data Science</b> Renee on Twitter: &quot;  ...
# 3  10882429297873722339  Risks versus opportunities in national securit...
# 4  11381515111146361903  SAMK among top for applied sciences - Telangan...
#
#                                                  url  \
# 0  https://www.google.com/url?rct=j&sa=t&url=http...
# 1  https://www.google.com/url?rct=j&sa=t&url=http...
# 2  https://www.google.com/url?rct=j&sa=t&url=http...
# 3  https://www.google.com/url?rct=j&sa=t&url=http...
# 4  https://www.google.com/url?rct=j&sa=t&url=http...
#
#              published_date              updated_date  \
# 0 2021-09-12 18:33:45+00:00 2021-09-12 18:33:45+00:00
# 1 2021-09-12 08:46:44+00:00 2021-09-12 08:46:44+00:00
# 2 2021-09-12 07:27:28+00:00 2021-09-12 07:27:28+00:00
# 3 2021-09-12 20:00:13+00:00 2021-09-12 20:00:13+00:00
# 4 2021-09-12 18:27:30+00:00 2021-09-12 18:27:30+00:00
#
#                                              content author
# 0  Once again, Computer Science, <b>Artificial In...   None
# 1  Yinqiu He. <b>Data Science</b> Institute: Post...   None
# 2  <b>Data Science</b> Renee &middot; @BecomingDa...   None
# 3  Advances in additive manufacturing (also known...   None
# 4  Of all the technologies that drive digital tra...   None

# %%
df.to_csv('results/contents.csv', mode='a', header=False, index=False)
