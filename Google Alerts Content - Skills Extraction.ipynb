# %%
import pandas as pd
from skill_extraction import extract_skills, extract_ignore

# %%
df = pd.read_csv('results/contents.csv')
df = df[['id', 'title', 'url', 'published_date', 'updated_date', 'content', 'author', 'page_text']]
df.head()
# Out:
#             id                                              title  \
# 0  1.01838E+19  IT Leaders Adjust Hiring Strategies With Tech ...
# 1  1.09203E+19  Assessment Industry Leader Holds Summit on <b>...
# 2   1.1214E+19  Ethical <b>Artificial Intelligence</b> is Focu...
# 3   1.1278E+18  Global Artificial Intelligence Market (2021 to...
# 4  1.14093E+19  Featurespace&#39;s ARIC Risk Hub™ v3.19 delive...
#
#                                                  url  \
# 0  https://www.wsj.com/articles/it-leaders-adjust...
# 1  https://www.einnews.com/pr_news/550966900/asse...
# 2  https://news.utexas.edu/2021/09/09/ethical-art...
# 3  https://www.businesswire.com/news/home/2021090...
# 4  https://www.businesswire.com/news/home/2021090...
#
#               published_date               updated_date  \
# 0  2021-09-09 20:12:59+00:00  2021-09-09 20:12:59+00:00
# 1  2021-09-09 16:58:06+00:00  2021-09-09 16:58:06+00:00
# 2  2021-09-09 18:11:15+00:00  2021-09-09 18:11:15+00:00
# 3  2021-09-09 16:52:30+00:00  2021-09-09 16:52:30+00:00
# 4  2021-09-09 17:37:30+00:00  2021-09-09 17:37:30+00:00
#
#                                              content author  \
# 0  <b>Data science</b> jobs are difficult roles t...    NaN
# 1  Global ATP Chair John Kleeman, Founder of Ques...    NaN
# 2  Ethical <b>Artificial Intelligence</b> is Focu...    NaN
# 3  “Artificial Intelligence Market, By Offering (...    NaN
# 4  “Our <b>machine learning</b> models are proven...    NaN
#
#                                            page_text
# 0  Skip to Main Content Skip to Search Dow Jones,...
# 1  About About EIN Presswire How We Are Different...
# 2  Skip to content ↓ Information and resources re...
# 3  Global Artificial Intelligence Market (2021 to...
# 4  Featurespace’s ARIC Risk Hub™ v3.19 delivers e...

# %%
for i, row in df.iterrows():
    content = row['page_text']
    if not isinstance(content, str):
        continue
    all_skills = extract_skills(content)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    df.loc[i, 'skills'] = '; '.join(keep_skills)

df.head()
# Out:
#             id                                              title  \
# 0  1.01838E+19  IT Leaders Adjust Hiring Strategies With Tech ...
# 1  1.09203E+19  Assessment Industry Leader Holds Summit on <b>...
# 2   1.1214E+19  Ethical <b>Artificial Intelligence</b> is Focu...
# 3   1.1278E+18  Global Artificial Intelligence Market (2021 to...
# 4  1.14093E+19  Featurespace&#39;s ARIC Risk Hub™ v3.19 delive...
#
#                                                  url  \
# 0  https://www.wsj.com/articles/it-leaders-adjust...
# 1  https://www.einnews.com/pr_news/550966900/asse...
# 2  https://news.utexas.edu/2021/09/09/ethical-art...
# 3  https://www.businesswire.com/news/home/2021090...
# 4  https://www.businesswire.com/news/home/2021090...
#
#               published_date               updated_date  \
# 0  2021-09-09 20:12:59+00:00  2021-09-09 20:12:59+00:00
# 1  2021-09-09 16:58:06+00:00  2021-09-09 16:58:06+00:00
# 2  2021-09-09 18:11:15+00:00  2021-09-09 18:11:15+00:00
# 3  2021-09-09 16:52:30+00:00  2021-09-09 16:52:30+00:00
# 4  2021-09-09 17:37:30+00:00  2021-09-09 17:37:30+00:00
#
#                                              content author  \
# 0  <b>Data science</b> jobs are difficult roles t...    NaN
# 1  Global ATP Chair John Kleeman, Founder of Ques...    NaN
# 2  Ethical <b>Artificial Intelligence</b> is Focu...    NaN
# 3  “Artificial Intelligence Market, By Offering (...    NaN
# 4  “Our <b>machine learning</b> models are proven...    NaN
#
#                                            page_text  \
# 0  Skip to Main Content Skip to Search Dow Jones,...
# 1  About About EIN Presswire How We Are Different...
# 2  Skip to content ↓ Information and resources re...
# 3  Global Artificial Intelligence Market (2021 to...
# 4  Featurespace’s ARIC Risk Hub™ v3.19 delivers e...
#
#                                               skills
# 0  Aerospace; Amazon Web Service (AWS); Artificia...
# 1  Agriculture; Airlines; Algorithm; Artificial I...
# 2  Architectural Engineering; Architecture; Artif...
# 3  Alibaba Cloud; Amazon Web Service (AWS); Artif...
# 4  Analytical; Anti Money Laundering; Artificial ...

# %%
for i, row in df.loc[df['skills'].isna()].iterrows():
    content = row['page_text']
    if not isinstance(content, str):
        content = row['content']
    if not isinstance(content, str):
        continue
    all_skills = extract_skills(content)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    df.loc[i, 'skills'] = '; '.join(keep_skills)

df.head()
# Out:
#             id                                              title  \
# 0  1.01838E+19  IT Leaders Adjust Hiring Strategies With Tech ...
# 1  1.09203E+19  Assessment Industry Leader Holds Summit on <b>...
# 2   1.1214E+19  Ethical <b>Artificial Intelligence</b> is Focu...
# 3   1.1278E+18  Global Artificial Intelligence Market (2021 to...
# 4  1.14093E+19  Featurespace&#39;s ARIC Risk Hub™ v3.19 delive...
#
#                                                  url  \
# 0  https://www.wsj.com/articles/it-leaders-adjust...
# 1  https://www.einnews.com/pr_news/550966900/asse...
# 2  https://news.utexas.edu/2021/09/09/ethical-art...
# 3  https://www.businesswire.com/news/home/2021090...
# 4  https://www.businesswire.com/news/home/2021090...
#
#               published_date               updated_date  \
# 0  2021-09-09 20:12:59+00:00  2021-09-09 20:12:59+00:00
# 1  2021-09-09 16:58:06+00:00  2021-09-09 16:58:06+00:00
# 2  2021-09-09 18:11:15+00:00  2021-09-09 18:11:15+00:00
# 3  2021-09-09 16:52:30+00:00  2021-09-09 16:52:30+00:00
# 4  2021-09-09 17:37:30+00:00  2021-09-09 17:37:30+00:00
#
#                                              content author  \
# 0  <b>Data science</b> jobs are difficult roles t...    NaN
# 1  Global ATP Chair John Kleeman, Founder of Ques...    NaN
# 2  Ethical <b>Artificial Intelligence</b> is Focu...    NaN
# 3  “Artificial Intelligence Market, By Offering (...    NaN
# 4  “Our <b>machine learning</b> models are proven...    NaN
#
#                                            page_text  \
# 0  Skip to Main Content Skip to Search Dow Jones,...
# 1  About About EIN Presswire How We Are Different...
# 2  Skip to content ↓ Information and resources re...
# 3  Global Artificial Intelligence Market (2021 to...
# 4  Featurespace’s ARIC Risk Hub™ v3.19 delivers e...
#
#                                               skills
# 0  Aerospace; Amazon Web Service (AWS); Artificia...
# 1  Agriculture; Airlines; Algorithm; Artificial I...
# 2  Architectural Engineering; Architecture; Artif...
# 3  Alibaba Cloud; Amazon Web Service (AWS); Artif...
# 4  Analytical; Anti Money Laundering; Artificial ...

# %%
df.loc[df['skills'].isna()]
# Out:
#                                                     id  \
# 222  few endings more horrible than death from star...
#
#                                                  title  url published_date  \
# 222   the Robotic Revolution Has Begun."" From Your...  NaN            NaN
#
#     updated_date content author page_text skills
# 222          NaN     NaN    NaN       NaN    NaN

# %%
def safe_float_convert(x):
    try:
        float(x)
        return True
    except ValueError:
        return False
    except TypeError:
        return False

# %%
mask = df['id'].map(safe_float_convert)
df_new = df.loc[mask].copy()
df_new = df_new.drop(columns=['page_text'])
df_new.head()
# Out:
#             id                                              title  \
# 0  1.01838E+19  IT Leaders Adjust Hiring Strategies With Tech ...
# 1  1.09203E+19  Assessment Industry Leader Holds Summit on <b>...
# 2   1.1214E+19  Ethical <b>Artificial Intelligence</b> is Focu...
# 3   1.1278E+18  Global Artificial Intelligence Market (2021 to...
# 4  1.14093E+19  Featurespace&#39;s ARIC Risk Hub™ v3.19 delive...
#
#                                                  url  \
# 0  https://www.wsj.com/articles/it-leaders-adjust...
# 1  https://www.einnews.com/pr_news/550966900/asse...
# 2  https://news.utexas.edu/2021/09/09/ethical-art...
# 3  https://www.businesswire.com/news/home/2021090...
# 4  https://www.businesswire.com/news/home/2021090...
#
#               published_date               updated_date  \
# 0  2021-09-09 20:12:59+00:00  2021-09-09 20:12:59+00:00
# 1  2021-09-09 16:58:06+00:00  2021-09-09 16:58:06+00:00
# 2  2021-09-09 18:11:15+00:00  2021-09-09 18:11:15+00:00
# 3  2021-09-09 16:52:30+00:00  2021-09-09 16:52:30+00:00
# 4  2021-09-09 17:37:30+00:00  2021-09-09 17:37:30+00:00
#
#                                              content author  \
# 0  <b>Data science</b> jobs are difficult roles t...    NaN
# 1  Global ATP Chair John Kleeman, Founder of Ques...    NaN
# 2  Ethical <b>Artificial Intelligence</b> is Focu...    NaN
# 3  “Artificial Intelligence Market, By Offering (...    NaN
# 4  “Our <b>machine learning</b> models are proven...    NaN
#
#                                               skills
# 0  Aerospace; Amazon Web Service (AWS); Artificia...
# 1  Agriculture; Airlines; Algorithm; Artificial I...
# 2  Architectural Engineering; Architecture; Artif...
# 3  Alibaba Cloud; Amazon Web Service (AWS); Artif...
# 4  Analytical; Anti Money Laundering; Artificial ...

# %%
df_new.to_csv('results/contents_skills.csv', index=False)
