# %%
import requests
import random
import pandas as pd
import re
import json
import datetime as dt
import time
from bs4 import BeautifulSoup
from headers import headers_list
from loading_bar import log_progress
from data_skills import DATA_SKILLS
from skill_extraction import extract_skills, extract_ignore, extract_data_skills

# %%
base_url = 'https://www.kdnuggets.com/{}/{:>02}/tutorials.html' #:>02 to add leading 0 to month
url = base_url.format(2021, 10)
url
# Out:
# 'https://www.kdnuggets.com/2021/10/tutorials.html'

# %%
page = requests.get(url, headers=random.choice(headers_list))
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head profile="https://gmpg.org/xfn/11">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <title>
#    2021 Oct Tutorials, Overviews - KDnuggets
#   </title>
#   <link href="/wp-content/themes/kdn17/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/wp-content/themes/kdn17/style.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="/wp-content/themes/kdn17/js/jquery-1.9.1.min.js" type="text/javascript">
#   </script>
#   <script src="/aps/kda_all.js" type="text/javascript">
#   </script>
#   <link href="/feed/" rel="alternate" title="KDnuggets: AI, Analytics, Data Science, Machine Learning Feed" type="application/rss+xml"/>
#   <link href="https://www.kdnuggets.com/2021-10/k10-tutorials/" rel="canonical"/>
#   <meta content="https://www.kdnuggets.com/2021-10/k10-tutorials/" property="og:url">
#    <meta content="KDnuggets" property="og:site_name">
#     <meta content="en_US" property="og:locale"/>
#     <meta content="object" property="og:type"/>
#     <meta content="2021 Oct Tutorials, Overviews - KDnuggets" property="og:title"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="@kdnuggets" name="twitter:site"/>
#     <meta content="@kdnuggets" name="twitter:creator"/>
#     <meta content="2021 Oct Tutorials, Overviews - KDnuggets" name="twitter:title"/>
#     <link href="//s.w.org" rel="dns-prefetch"/>
#     <link href="https://www.kdnuggets.com/feed" rel="alternate" title="KDnuggets » Feed" type="application/rss+xml"/>
#     <link href="https://www.kdnuggets.com/comments/feed" rel="alternate" title="KDnuggets » Comments Feed" type="application/rss+xml"/>
#     <link href="https://www.kdnuggets.com/2021/10/tutorials.html/feed" rel="alternate" title="KDnuggets » 2021 Oct Tutorials, Overviews Category Feed" type="application/rss+xml"/>
#     <link href="https://www.kdnuggets.com/wp-json/" rel="https://api.w.org/"/>
#     <link href="https://www.kdnuggets.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#     <link href="https://www.kdnuggets.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#     <meta content="WordPress 4.9.18" name="generator"/>
#     <!-- BEGIN ExactMetrics v5.3.7 Universal Analytics - https://exactmetrics.com/ -->
#     <script>
#      (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-361129-1', 'auto');
#   ga('send', 'pageview');
#     </script>
#     <!-- END ExactMetrics Universal Analytics -->
#    </meta>
#   </meta>
#  </head>
#  <body class="archive category category-k10-tutorials category-5240">
#   <div class="main_wrapper">
#    <!-- publ: 29-Oct, 2021  -->
#    <div id="wrapper">
#     <div id="header">
#      <div id="header_log">
#       <div class="logo">
#        <a href="/">
#        </a>
#       </div>
#       <table>
#        <tr>
#         <td style="text-align:center" width="150">
#          <span style="font-size:16px; font-weight:700">
#           <a href="/news/subscribe.html" onclick="ga('send','pageview','/x/top/sub');" target="_blank">
#            <b>
#             Subscribe to KDnuggets
#            </b>
#           </a>
#          </span>
#         </td>
#         <td width="200">
#          <a href="https://twitter.com/kdnuggets" onclick="ga('send','pageview','/x/top/twt');" target="_blank">
#           <img alt="Twitter" height="48" src="/images/tw_c48.png" style="vertical-align: bottom" width="48"/>
#          </a>
#          <a href="https://www.linkedin.com/groups/54257/" onclick="ga('send','pageview','/x/top/in');" target="_blank">
#           <img alt="LinkedIn" height="48" src="/images/in_c48.png" style="vertical-align: bottom" width="48"/>
#          </a>
#          <a href="https://www.facebook.com/kdnuggets" onclick="ga('send','pageview','/x/top/fb');" target="_blank">
#           <img alt="Facebook" height="48" src="/images/fb_c48.png" style="vertical-align: bottom" width="48"/>
#          </a>
#         </td>
#         <td width="150">
#          <span style="font-size:16px; font-weight:700">
#           <a href="/news/submissions.html" onclick="ga('send','pageview','/x/top/blo');">
#            Submit a blog
#            <br/>
#            to KDnuggets
#           </a>
#          </span>
#         </td>
#        </tr>
#       </table>
#      </div>
#      <div class="search">
#       <form action="/" id="searchform" method="get">
#        <input id="s" name="s" placeholder="search KDnuggets" type="text" value=""/>
#        <input type="submit" value="Search"/>
#       </form>
#      </div>
#      <div href="#" id="pull">
#       <img class="menu" src="/images/menu-30.png">
#        <div class="logo">
#         <a href="/">
#         </a>
#        </div>
#        <img class="search-icon" src="/images/search-icon.png">
#        </img>
#       </img>
#      </div>
#      <div id="pull-menu">
#       <div class="navigation">
#        <ul class="menu" id="menu-menu">
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-13756" id="menu-item-13756">
#          <a href="/news/index.html" title="News">
#           Blog
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-42152" id="menu-item-42152">
#          <a href="https://www.kdnuggets.com/opinions/index.html" title="Opinions">
#           Opinions
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-46415" id="menu-item-46415">
#          <a href="https://www.kdnuggets.com/tutorials/index.html">
#           Tutorials
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-46286" id="menu-item-46286">
#          <a href="/news/top-stories.html">
#           Top stories
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-105257" id="menu-item-105257">
#          <a href="https://www.kdnuggets.com/courses/index.html">
#           Courses
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1499" id="menu-item-1499">
#          <a href="https://www.kdnuggets.com/datasets/index.html">
#           Datasets
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-121265" id="menu-item-121265">
#          <a href="https://www.kdnuggets.com/education/online.html" title="Online MS and other Education in AI, Data Science, Machine Learning">
#           Education: Online
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-121264" id="menu-item-121264">
#          <a href="https://www.kdnuggets.com/education/analytics-data-mining-certificates.html">
#           Certificates
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-105258" id="menu-item-105258">
#          <a href="https://www.kdnuggets.com/meetings/index.html">
#           Events / Meetings
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-13364" id="menu-item-13364">
#          <a href="/jobs/index.html" title="Jobs in Analytics, Data Science">
#           Jobs
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-105259" id="menu-item-105259">
#          <a href="https://www.kdnuggets.com/software/index.html">
#           Software
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-105260" id="menu-item-105260">
#          <a href="https://www.kdnuggets.com/webcasts/index.html">
#           Webinars
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <!--#header end-->
#     <div id="spacer">
#     </div>
#     <div id="content_wrapper">
#      <div id="ad_wrapper">
#       <script type="text/javascript">
#        jQuery(function() {
#    	    var pull        = $('#pull');
#             menu        = $('#header .navigation ul');
#             menuImage = $('#header img.menu');
#             mobileMenu        = $('#pull-menu-mobile');
#             search = $('img.search-icon');
#             searchBar = $('div.search');
#             searchClick = false;
#             search.on('click', function() {
#                   searchBar.slideToggle();
#                   searchClick = true;
#             });
#      	    $(menuImage).on('click', function(e) {
# 	        //e.preventDefault();
#                 if (!searchClick) {
#                   menu.slideToggle();
#                 }
#                 searchClick = false;
# 	    });
#            /* pullMobile.on('click', function(e) {
#               e.preventDefault();
#                 if (!searchClick) {
#                   mobileMenu.slideToggle();
#                 }
#                 searchClick = false;
# 	    });*/
#
# 	});
# 	kpath = '/'; kda_top(); kda_sid_init(); kda_sid_n=1;
#       </script>
#       <div style="float:center;margin:auto; width:90%">
#        <b>
#         <a href="/topic">
#          Topics
#         </a>
#         :
#         <a href="/topic/ai">
#          AI
#         </a>
#         |
#         <a href="/topic/data-science">
#          Data Science
#         </a>
#         |
#         <a href="/topic/data-visualization">
#          Data Visualization
#         </a>
#         |
#         <a href="/topic/deep-learning">
#          Deep Learning
#         </a>
#         |
#         <a href="/topic/machine-learning">
#          Machine Learning
#         </a>
#         |
#         <a href="/topic/nlp">
#          NLP
#         </a>
#         |
#         <a href="/topic/python">
#          Python
#         </a>
#         |
#         <a href="/topic/r">
#          R
#         </a>
#         |
#         <a href="/topic/statistics">
#          Statistics
#         </a>
#        </b>
#        <br/>
#       </div>
#       <br/>
#      </div>
#      <!-- /ad_wrapper -->
#      <div class="breadcumb">
#       <a href="/">
#        KDnuggets Home
#       </a>
#       »
#       <a href="/news/index.html">
#        News
#       </a>
#       »
#       <a href="/2021/index.html">
#        2021
#       </a>
#       »
#       <a href="https://www.kdnuggets.com/2021/10/index.html">
#        Oct
#       </a>
#       »  Tutorials, Overviews (
#       <a href="/2021/09/tutorials.html">
#        <img alt="&lt;" border="0" height="10" src="/images/prv.gif" width="8"/>
#        Sep
#       </a>
#       |
#       <a href="/2021/11/tutorials.html">
#        Nov
#        <img alt="&gt;" border="0" height="10" src="/images/nxt.gif" width="8"/>
#       </a>
#       )
#      </div>
#      <div class="single testclass" id="content">
#       <h1 id="title">
#        2021 Oct Tutorials, Overviews
#       </h1>
#       <div class="addthis_native_toolbox">
#       </div>
#       <hr class="gray-line"/>
#       <div class="cat-crumbs">
#        <a href="https://www.kdnuggets.com/2021/10/index.html">
#         <b>
#          All
#         </b>
#        </a>
#        (88) |
#        <a href="https://www.kdnuggets.com/2021/10/opinions.html">
#         <b>
#          Opinions
#         </b>
#        </a>
#        (16) |
#        <a href="https://www.kdnuggets.com/2021/10/products.html">
#         <b>
#          Products, Services
#         </b>
#        </a>
#        (16) |
#        <a href="https://www.kdnuggets.com/2021/10/tops.html">
#         <b>
#          Top Stories
#         </b>
#        </a>
#        (6) |
#        <b>
#         Tutorials, Overviews
#        </b>
#        (50)
#       </div>
#       <ul class="three_ul test">
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/multivariate-time-series-analysis-lstm-based-rnn.html" id="134487">
#          <b>
#           Multivariate Time Series Analysis with an LSTM based RNN
#          </b>
#         </a>
#         , by Kathrin Melcher
#         <font color="#808080">
#          - Oct 29, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Check out this codeless solution using the Keras integration.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/keras" rel="tag">
#           Keras
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/knime" rel="tag">
#           Knime
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/low-code" rel="tag">
#           Low-Code
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/lstm" rel="tag">
#           LSTM
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/time-series" rel="tag">
#           Time Series
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/etl-elt-guide-market-analysis.html" id="134506">
#          <b>
#           ETL and ELT: A Guide and Market Analysis
#          </b>
#         </a>
#         , by Louise de Leyritz
#         <font color="#808080">
#          - Oct 29, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          ETL and related techniques remain a powerful and foundational tool in the data industry. We explain what ETL is and how ETL and ELT processes have evolved over the years, with a close eye toward how third-generation ETL tools are about to disrupt standard data processing practices.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/data-preparation" rel="tag">
#           Data Preparation
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/elt" rel="tag">
#           ELT
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/etl" rel="tag">
#           ETL
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/market-research" rel="tag">
#           Market Research
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/pipeline" rel="tag">
#           Pipeline
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/simple-text-scraping-parsing-processing-python-library.html" id="134496">
#          <b>
#           Simple Text Scraping, Parsing, and Processing with this Python Library
#          </b>
#         </a>
#         , by Matthew Mayo
#         <font color="#808080">
#          - Oct 29, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Scraping, parsing, and processing text data from the web can be difficult. But it can also be easy, using Newspaper3k.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/data-processing" rel="tag">
#           Data Processing
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/nlp" rel="tag">
#           NLP
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/text-analytics" rel="tag">
#           Text Analytics
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/web-scraping" rel="tag">
#           Web Scraping
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/google-recommends-before-machine-learning-data-science-course.html" id="134473">
#          <b>
#           <img align="right" alt="Silver Blog" src="/images/tkb-2110-s.png" width="96"/>
#           What Google Recommends You do Before Taking Their Machine Learning or Data Science Course
#          </b>
#         </a>
#         , by Harshit Tyagi
#         <font color="#808080">
#          - Oct 28, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          First steps to learning data science &amp; machine learning are the foundations.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/beginners" rel="tag">
#           Beginners
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/courses" rel="tag">
#           Courses
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-science" rel="tag">
#           Data Science
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/google" rel="tag">
#           Google
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/bank-data-scientists-working-fintech.html" id="134465">
#          <b>
#           Want to Join a Bank? Everything Data Scientists Need to Know About Working in Fintech
#          </b>
#         </a>
#         , by Shameek Kundu
#         <font color="#808080">
#          - Oct 28, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          There is ample opportunity for data scientists in the financial services sector. The career experience can be very different, however, from similar roles at pure technology organizations. So, it's best to first consider if this industry is right for your interests, preferences for how you work, and long-term goals.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/career-advice" rel="tag">
#           Career Advice
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-scientist" rel="tag">
#           Data Scientist
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/finance" rel="tag">
#           Finance
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/fintech" rel="tag">
#           Fintech
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/analyze-python-code-jupyter-notebooks.html" id="134455">
#          <b>
#           Analyze Python Code in Jupyter Notebooks
#          </b>
#         </a>
#         , by Julien Delange
#         <font color="#808080">
#          - Oct 28, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          We present a new tool that integrates modern code analysis techniques with Jupyter notebooks and helps developers find bugs as they write code.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/jupyter" rel="tag">
#           Jupyter
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/programming" rel="tag">
#           Programming
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/guide-14-different-data-science-jobs.html" id="134425">
#          <b>
#           <img align="right" alt="Silver Blog" src="/images/tkb-2110-s.png" width="96"/>
#           A Guide to 14 Different Data Science Jobs
#          </b>
#         </a>
#         , by Nate Rosidi
#         <font color="#808080">
#          - Oct 27, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          The field of data science is growing into one that features a variety of job titles This guide reviews different positions available for you to consider if you have a data science background.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/business-analyst" rel="tag">
#           Business Analyst
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/career-advice" rel="tag">
#           Career Advice
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-analyst" rel="tag">
#           Data Analyst
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-engineer" rel="tag">
#           Data Engineer
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-scientist" rel="tag">
#           Data Scientist
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/jobs" rel="tag">
#           Jobs
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning-engineer" rel="tag">
#           Machine Learning Engineer
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/machine-learning-model-development-operations-principles-practice.html" id="134407">
#          <b>
#           <img align="right" alt="Gold Blog" src="/images/tkb-2110-g.png" width="96"/>
#           Machine Learning Model Development and Model Operations: Principles and Practices
#          </b>
#         </a>
#         , by Suresh Yaram
#         <font color="#808080">
#          - Oct 27, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          The ML model management and the delivery of highly performing model is as important as the initial build of the model by choosing right dataset. The concepts around model retraining, model versioning, model deployment and model monitoring are the basis for machine learning operations (MLOps) that helps the data science teams deliver highly performing models.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/algorithms" rel="tag">
#           Algorithms
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/deployment" rel="tag">
#           Deployment
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/feature-engineering" rel="tag">
#           Feature Engineering
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/mlops" rel="tag">
#           MLOps
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/getting-started-pytorch-lightning.html" id="134350">
#          <b>
#           Getting Started with PyTorch Lightning
#          </b>
#         </a>
#         , by Kevin Vu
#         <font color="#808080">
#          - Oct 26, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          As a library designed for production research, PyTorch Lightning streamlines hardware support and distributed training as well, and we’ll show how easy it is to move training to a GPU toward the end.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/deep-learning" rel="tag">
#           Deep Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/pytorch" rel="tag">
#           PyTorch
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/pytorch-lightning" rel="tag">
#           PyTorch Lightning
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/four-basic-steps-data-preparation.html" id="134281">
#          <b>
#           Four Basic Steps in Data Preparation
#          </b>
#         </a>
#         , by Rosaria Silipo
#         <font color="#808080">
#          - Oct 26, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          What we would like to do here is introduce four very basic and very general steps in data preparation for machine learning algorithms. We will describe how and why to apply such transformations within a specific example.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/data-preparation" rel="tag">
#           Data Preparation
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-preprocessing" rel="tag">
#           Data Preprocessing
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-science" rel="tag">
#           Data Science
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/missing-values" rel="tag">
#           Missing Values
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/normalization" rel="tag">
#           Normalization
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/sampling" rel="tag">
#           Sampling
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/guide-right-predictive-maintenance-machine-learning-techniques.html" id="134260">
#          <b>
#           Guide To Finding The Right Predictive Maintenance Machine Learning Techniques
#          </b>
#         </a>
#         , by Maruti Techlabs
#         <font color="#808080">
#          - Oct 25, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          What happens to a life so dependent on machines, when that particular machine breaks down? This is precisely why there’s a dire need for predictive maintenance with machine learning.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/maintenance" rel="tag">
#           Maintenance
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/monitoring" rel="tag">
#           Monitoring
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/learn-reproduce-papers-beginners-guide.html" id="134270">
#          <b>
#           Learn To Reproduce Papers: Beginner’s Guide
#          </b>
#         </a>
#         , by Olga Chernytska
#         <font color="#808080">
#          - Oct 25, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Step-by-step instructions on how to understand Deep Learning papers and implement the described approaches.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/beginners" rel="tag">
#           Beginners
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/deep-learning" rel="tag">
#           Deep Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/papers-with-code" rel="tag">
#           Papers with code
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/research" rel="tag">
#           Research
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/deploying-serverless-spacy-transformer-model-aws-lambda.html" id="134204">
#          <b>
#           Deploying Serverless spaCy Transformer Model with AWS Lambda
#          </b>
#         </a>
#         , by Walid Amamou
#         <font color="#808080">
#          - Oct 22, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          A step-by-step guide on how to deploy NER transformer model serverless.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/aws" rel="tag">
#           AWS
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/deployment" rel="tag">
#           Deployment
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/nlp" rel="tag">
#           NLP
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/spacy" rel="tag">
#           spaCy
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/transformer" rel="tag">
#           Transformer
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/introduction-autoencoder-variational-autoencoder-vae.html" id="134213">
#          <b>
#           Introduction to AutoEncoder and Variational AutoEncoder (VAE)
#          </b>
#         </a>
#         , by Nagesh Chauhan
#         <font color="#808080">
#          - Oct 22, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Autoencoders and their variants are interesting and powerful artificial neural networks used in unsupervised learning scenarios. Learn how autoencoders perform in their different approaches and how to implement with Keras on the instructional data set of the MNIST digits.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/autoencoder" rel="tag">
#           Autoencoder
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/deep-learning" rel="tag">
#           Deep Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/best-matching-distribution-data-effortlessly.html" id="134195">
#          <b>
#           Find the Best-Matching Distribution for Your Data Effortlessly
#          </b>
#         </a>
#         , by Tirthajyoti Sarkar
#         <font color="#808080">
#          - Oct 22, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          How to find the best-matching statistical distributions for your data points — in an automated and easy way. And, then how to extend the utility further.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/distribution" rel="tag">
#           Distribution
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/statistics" rel="tag">
#           Statistics
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/synthetic-data" rel="tag">
#           Synthetic Data
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/bpe-wordpiece-unigram-tokenizers-using-hugging-face.html" id="134170">
#          <b>
#           Training BPE, WordPiece, and Unigram Tokenizers from Scratch using Hugging Face
#          </b>
#         </a>
#         , by Harshit Tyagi
#         <font color="#808080">
#          - Oct 21, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Comparing the tokens generated by SOTA tokenization algorithms using Hugging Face's tokenizers package.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/huggingface" rel="tag">
#           Hugging Face
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/nlp" rel="tag">
#           NLP
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/tokenization" rel="tag">
#           Tokenization
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/tripled-my-income-data-science-18-months.html" id="134156">
#          <b>
#           <img align="right" alt="Gold Blog" src="/images/tkb-2110-g.png" width="96"/>
#           How I Tripled My Income With Data Science in 18 Months
#          </b>
#         </a>
#         , by Natassha Selvaraj
#         <font color="#808080">
#          - Oct 21, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Over a year ago, I lost my job due to the COVID-19 pandemic. During this this, I taught myself data science and tripled my income.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/career-advice" rel="tag">
#           Career Advice
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-science" rel="tag">
#           Data Science
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/salary" rel="tag">
#           Salary
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/simple-question-answering-web-app-hugging-face-pipelines.html" id="134130">
#          <b>
#           Simple Question Answering Web App with HuggingFace Pipelines
#          </b>
#         </a>
#         , by Matthew Mayo
#         <font color="#808080">
#          - Oct 21, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          See how easy it can be to build a simple web app for question answering from text using Streamlit and HuggingFace pipelines.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/huggingface" rel="tag">
#           Hugging Face
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/nlp" rel="tag">
#           NLP
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/question-answering" rel="tag">
#           Question answering
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/streamlit" rel="tag">
#           Streamlit
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/data-preparation-r-dplyr-cheat-sheet.html" id="134110">
#          <b>
#           Data Preparation in R using dplyr, with Cheat Sheet!
#          </b>
#         </a>
#         , by Stan Pugsley
#         <font color="#808080">
#          - Oct 20, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Leverage the powerful data wrangling tools in R’s dplyr to clean and prepare your data.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/cheat-sheet" rel="tag">
#           Cheat Sheet
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-preparation" rel="tag">
#           Data Preparation
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/r" rel="tag">
#           R
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/data-science-portfolio-project-ideas.html" id="134100">
#          <b>
#           <img align="right" alt="Gold Blog" src="/images/tkb-2110-g.png" width="96"/>
#           Data Science Portfolio Project Ideas That Can Get You Hired (Or Not)
#          </b>
#         </a>
#         , by Nate Rosidi
#         <font color="#808080">
#          - Oct 20, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Choosing what to include in your data science portfolio during the job search is the most important part of the process. Each project should be well-structured so that a hiring manager can assess your skills quickly. To help you get started, we highlight a few data science project ideas that you should consider for your portfolio.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/career-advice" rel="tag">
#           Career Advice
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-science" rel="tag">
#           Data Science
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/portfolio" rel="tag">
#           Portfolio
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/project" rel="tag">
#           Project
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/11-most-practical-data-science-skills-2022.html" id="134041">
#          <b>
#           11 Most Practical Data Science Skills for 2022
#          </b>
#         </a>
#         , by Terence Shin
#         <font color="#808080">
#          - Oct 19, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          While the field of data science continues to evolve with exciting new progress in analytical approaches and machine learning, there remain a core set of skills that are foundational for all general practitioners and specialists, especially those who want to be employable with full-stack capabilities.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/career-advice" rel="tag">
#           Career Advice
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-science-skills" rel="tag">
#           Data Science Skills
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/explainable-ai" rel="tag">
#           Explainable AI
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/feature-engineering" rel="tag">
#           Feature Engineering
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/github" rel="tag">
#           GitHub
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/nlp" rel="tag">
#           NLP
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/regression" rel="tag">
#           Regression
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/sql" rel="tag">
#           SQL
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/interactive-dashboard-three-steps-knime-analytics-platform.html" id="134027">
#          <b>
#           How to Create an Interactive Dashboard in Three Steps with KNIME Analytics Platform
#          </b>
#         </a>
#         , by Emilio Silvestri
#         <font color="#808080">
#          - Oct 19, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          In this blog post I will show you how to build a simple, but useful and good-looking dashboard to present your data - in three simple steps!
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/analytics" rel="tag">
#           Analytics
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/dashboard" rel="tag">
#           Dashboard
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/data-visualization" rel="tag">
#           Data Visualization
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/knime" rel="tag">
#           Knime
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/platform" rel="tag">
#           Platform
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/real-time-image-segmentation-5-lines-code.html" id="133959">
#          <b>
#           Real Time Image Segmentation Using 5 Lines of Code
#          </b>
#         </a>
#         , by Ayoola Olafenwa
#         <font color="#808080">
#          - Oct 18, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          PixelLib Library is a library created to allow easy integration of object segmentation in images and videos using few lines of python code. PixelLib now provides support for PyTorch backend to perform faster, more accurate segmentation and extraction of objects in images and videos using PointRend segmentation architecture.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/computer-vision" rel="tag">
#           Computer Vision
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/image-processing" rel="tag">
#           Image Processing
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/segmentation" rel="tag">
#           Segmentation
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/serving-ml-models-production-common-patterns.html" id="133938">
#          <b>
#           Serving ML Models in Production: Common Patterns
#          </b>
#         </a>
#         , by Mo, Oakes &amp; Galarnyk
#         <font color="#808080">
#          - Oct 18, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Over the past couple years, we've seen 4 common patterns of machine learning in production: pipeline, ensemble, business logic, and online learning. In the ML serving space, implementing these patterns typically involves a tradeoff between ease of development and production readiness. Ray Serve was built to support these patterns by being both easy to develop and production ready.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/fastapi" rel="tag">
#           FastAPI
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/production" rel="tag">
#           Production
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/ray" rel="tag">
#           Ray
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/samsung-computing-paradigm-ai-in-memory.html" id="133899">
#          <b>
#           New Computing Paradigm for AI: Processing-in-Memory (PIM) Architecture
#          </b>
#         </a>
#         , by Nam Sung Kim
#         <font color="#808080">
#          - Oct 15, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          As larger deep neural networks are trained on the latest and fastest chip technologies, an important challenge remains that bottlenecks performance -- and it is not compute power. You can try to calculate a DNN as fast as possible, but there is data -- and it has to move. Data pipelines on the chip are expensive and new solutions must be developed to advance capabilities.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/ai" rel="tag">
#           AI
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/hardware" rel="tag">
#           Hardware
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/in-memory-computing" rel="tag">
#           In-Memory Computing
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/samsung" rel="tag">
#           Samsung
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/calculate-confidence-intervals-performance-metrics-machine-learning.html" id="133874">
#          <b>
#           How to calculate confidence intervals for performance metrics in Machine Learning using an automatic bootstrap method
#          </b>
#         </a>
#         , by David B Rosen (PhD)
#         <font color="#808080">
#          - Oct 15, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Are your model performance measurements very precise due to a “large” test set, or very uncertain due to a “small” or imbalanced test set?
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/metrics" rel="tag">
#           Metrics
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/statistics" rel="tag">
#           Statistics
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/deploying-first-machine-learning-api.html" id="133839">
#          <b>
#           <img align="right" alt="Silver Blog" src="/images/tkb-2110-s.png" width="96"/>
#           Deploying Your First Machine Learning API
#          </b>
#         </a>
#         , by Abid Ali Awan
#         <font color="#808080">
#          - Oct 14, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Effortless way to develop and deploy your machine learning API using FastAPI and Deta.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/api" rel="tag">
#           API
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/deployment" rel="tag">
#           Deployment
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/fastapi" rel="tag">
#           FastAPI
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/spacy" rel="tag">
#           spaCy
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/20-python-packages.html" id="133846">
#          <b>
#           The 20 Python Packages You Need For Machine Learning and Data Science
#          </b>
#         </a>
#         , by Sandro Luck
#         <font color="#808080">
#          - Oct 14, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Do you do Python? Do you do data science and machine learning? Then, you need to do these crucial Python libraries that enable nearly all you will want to do.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/data-science" rel="tag">
#           Data Science
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/keras" rel="tag">
#           Keras
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/machine-learning" rel="tag">
#           Machine Learning
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/matplotlib" rel="tag">
#           Matplotlib
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/numpy" rel="tag">
#           numpy
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/pandas" rel="tag">
#           Pandas
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/plotly" rel="tag">
#           Plotly
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/python" rel="tag">
#           Python
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/pytorch" rel="tag">
#           PyTorch
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/scikit-learn" rel="tag">
#           scikit-learn
#          </a>
#          ,
#          <a href="https://www.kdnuggets.com/tag/tensorflow" rel="tag">
#           TensorFlow
#          </a>
#         </p>
#        </li>
#        <li>
#         <a href="https://www.kdnuggets.com/2021/10/clustering-what-is-how-works.html" id="133832">
#          <b>
#           What is Clustering and How Does it Work?
#          </b>
#         </a>
#         , by Satoru Hayasaka
#         <font color="#808080">
#          - Oct 14, 2021
#         </font>
#         .
#         <div style="margin-left: 12px; font-size: small;">
#          Let us examine how clusters with different properties are produced by different clustering algorithms. In particular, we give an overview of three clustering methods: k-Means clustering, hierarchical clustering, and DBSCAN.
#         </div>
#         <p class="tags">
#          Tags:
#          <a href="https://www.kdnuggets.com/tag/clustering" rel="tag">
#           Clustering
#          </a>
# ...
#              </b>
#             </a>
#             <li>
#              <a 11-mp-3-papers');'="" 2021="" href="/2021/10/learn-reproduce-papers-beginners-guide.html" onclick="ga(" sbm="" send','pageview','="" x="">
#               <b>
#                Learn To Reproduce Papers: Beginner’s Guide
#               </b>
#              </a>
#              <li>
#               <a 11-mp-4-365');'="" 2021="" href="/2021/10/365datascience-courses-free.html" onclick="ga(" sbm="" send','pageview','="" x="">
#                <b>
#                 365 Data Science courses free until 18 November
#                </b>
#               </a>
#               <li>
#                <a 11-mp-5-14-jobs');'="" 2021="" href="/2021/10/guide-14-different-data-science-jobs.html" onclick="ga(" sbm="" send','pageview','="" x="">
#                 <b>
#                  A Guide to 14 Different Data Science Jobs
#                 </b>
#                </a>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </ol>
#         </td>
#        </tr>
#        <br/>
#        <br/>
#        <tr>
#         <td align="left">
#          <b>
#           <font size="+1">
#            <a href="https://www.kdnuggets.com/2021/11/top-news-week-1025-1031.html" target="_blank">
#             Most Shared
#            </a>
#           </font>
#          </b>
#          <ol class="three_ol">
#           <li>
#            <a 11-ms-1-model-dev');'="" 2021="" href="/2021/10/machine-learning-model-development-operations-principles-practice.html" onclick="ga(" sbm="" send','pageview','="" x="">
#             <b>
#              Machine Learning Model Development and Model Operations: Principles and Practices
#             </b>
#            </a>
#            <li>
#             <a 11-ms-2-14-jobs');'="" 2021="" href="/2021/10/guide-14-different-data-science-jobs.html" onclick="ga(" sbm="" send','pageview','="" x="">
#              <b>
#               A Guide to 14 Different Data Science Jobs
#              </b>
#             </a>
#             <li>
#              <a 11-ms-3-google');'="" 2021="" href="/2021/10/google-recommends-before-machine-learning-data-science-course.html" onclick="ga(" sbm="" send','pageview','="" x="">
#               <b>
#                What Google Recommends You do Before Taking Their Machine Learning or Data Science Course
#               </b>
#              </a>
#              <li>
#               <a 11-ms-4-papers');'="" 2021="" href="/2021/10/learn-reproduce-papers-beginners-guide.html" onclick="ga(" sbm="" send','pageview','="" x="">
#                <b>
#                 Learn To Reproduce Papers: Beginner’s Guide
#                </b>
#               </a>
#               <li>
#                <a 11-ms-5-data-prep');'="" 2021="" href="/2021/10/four-basic-steps-data-preparation.html" onclick="ga(" sbm="" send','pageview','="" x="">
#                 <b>
#                  Four Basic Steps in Data Preparation
#                 </b>
#                </a>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </ol>
#         </td>
#        </tr>
#       </table>
#       <div class="latn" style="margin-top: 15px;">
#        <h3>
#         <b>
#          More Recent Stories
#         </b>
#        </h3>
#        <ul class="next-posts">
#         <li>
#          <a href="https://www.kdnuggets.com/2021/10/multivariate-time-series-analysis-lstm-based-rnn.html">
#           Multivariate Time Series Analysis with an LSTM based RNN
#          </a>
#          <li>
#           <a href="https://www.kdnuggets.com/2021/10/etl-elt-guide-market-analysis.html">
#            ETL and ELT: A Guide and Market Analysis
#           </a>
#           <li>
#            <a href="https://www.kdnuggets.com/2021/10/simple-text-scraping-parsing-processing-python-library.html">
#             Simple Text Scraping, Parsing, and Processing with this Python...
#            </a>
#            <li>
#             <a href="https://www.kdnuggets.com/2021/10/google-recommends-before-machine-learning-data-science-course.html">
#              What Google Recommends You do Before Taking Their Machine Learning or Data Science Course
#              <b>
#               [Silver Blog]
#              </b>
#             </a>
#             <li>
#              <a href="https://www.kdnuggets.com/2021/10/bank-data-scientists-working-fintech.html">
#               Want to Join a Bank? Everything Data Scientists Need to Know A...
#              </a>
#              <li>
#               <a href="https://www.kdnuggets.com/2021/10/analyze-python-code-jupyter-notebooks.html">
#                Analyze Python Code in Jupyter Notebooks
#               </a>
#               <li>
#                <a href="https://www.kdnuggets.com/2021/10/build-data-frameworks-open-source-tools-agility-security.html">
#                 How to Build Data Frameworks with Open Source Tools to Enhance...
#                </a>
#                <li>
#                 <a href="https://www.kdnuggets.com/2021/10/guide-14-different-data-science-jobs.html">
#                  A Guide to 14 Different Data Science Jobs
#                  <b>
#                   [Silver Blog]
#                  </b>
#                 </a>
#                 <li>
#                  <a href="https://www.kdnuggets.com/2021/10/machine-learning-model-development-operations-principles-practice.html">
#                   Machine Learning Model Development and Model Operations: Principles and Practices
#                   <b>
#                    [Gold Blog]
#                   </b>
#                  </a>
#                  <li>
#                   <a href="https://www.kdnuggets.com/2021/n41.html">
#                    KDnuggets 21:n41, Oct 27: How I Tripled My Income With Data...
#                   </a>
#                   <li>
#                    <a href="https://www.kdnuggets.com/2021/10/octoparse-web-scraping-zapier-integration.html">
#                     Export Data from the Web Scraping Tool through Zapier Integration
#                    </a>
#                    <li>
#                     <a href="https://www.kdnuggets.com/2021/10/getting-started-pytorch-lightning.html">
#                      Getting Started with PyTorch Lightning
#                     </a>
#                     <li>
#                      <a href="https://www.kdnuggets.com/2021/10/defeat-machine-learning-engineer-impostor-syndrome.html">
#                       How To Defeat The Machine Learning Engineer Impostor Syndrome
#                      </a>
#                      <li>
#                       <a href="https://www.kdnuggets.com/2021/10/four-basic-steps-data-preparation.html">
#                        Four Basic Steps in Data Preparation
#                       </a>
#                       <li>
#                        <a href="https://www.kdnuggets.com/2021/10/top-news-week-1018-1024.html">
#                         Top Stories, Oct 18-24: How I Tripled My Income With Data Scie...
#                        </a>
#                        <li>
#                         <a href="https://www.kdnuggets.com/2021/10/365datascience-courses-free.html">
#                          365 Data Science courses free until 18 November
#                         </a>
#                         <li>
#                          <a href="https://www.kdnuggets.com/2021/10/guide-right-predictive-maintenance-machine-learning-techniques.html">
#                           Guide To Finding The Right Predictive Maintenance Machine Lear...
#                          </a>
#                          <li>
#                           <a href="https://www.kdnuggets.com/2021/10/save-sarah-connor-data-science.html">
#                            Save Sarah Connor with Data Science
#                           </a>
#                           <li>
#                            <a href="https://www.kdnuggets.com/2021/10/learn-reproduce-papers-beginners-guide.html">
#                             Learn To Reproduce Papers: Beginner’s Guide
#                            </a>
#                            <li>
#                             <a href="https://www.kdnuggets.com/2021/10/exclusive-openai-summarizes-kdnuggets.html">
#                              Exclusive: OpenAI summarizes KDnuggets
#                              <b>
#                               [Silver Blog]
#                              </b>
#                             </a>
#                            </li>
#                           </li>
#                          </li>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </li>
#                    </li>
#                   </li>
#                  </li>
#                 </li>
#                </li>
#               </li>
#              </li>
#             </li>
#            </li>
#           </li>
#          </li>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="breadcumb">
#       <a href="/">
#        KDnuggets Home
#       </a>
#       »
#       <a href="/news/index.html">
#        News
#       </a>
#       »
#       <a href="/2021/index.html">
#        2021
#       </a>
#       »
#       <a href="https://www.kdnuggets.com/2021/10/index.html">
#        Oct
#       </a>
#       »  Tutorials, Overviews (
#       <a href="/2021/09/tutorials.html">
#        <img alt="&lt;" border="0" height="10" src="/images/prv.gif" width="8"/>
#        Sep
#       </a>
#       |
#       <a href="/2021/11/tutorials.html">
#        Nov
#        <img alt="&gt;" border="0" height="10" src="/images/nxt.gif" width="8"/>
#       </a>
#       )
#      </div>
#      <!--#content_wrapper end-->
#     </div>
#     <br>
#      <div id="footer">
#       <br/>
#       © 2021 KDnuggets. |
#       <a href="/about/index.html">
#        About KDnuggets
#       </a>
#       |
#       <a href="/contact.html">
#        Contact
#       </a>
#       |
#       <a href="/news/privacy-policy.html">
#        Privacy policy
#       </a>
#       |
#       <a href="/terms-of-service.html">
#        Terms of Service
#       </a>
#       <br/>
#       <div class="kd_bottom">
#        <div class="footer-container">
#         <div class="footer-news">
#          <a href="/news/subscribe.html" onclick="ga('send','pageview','/x/bot/sub');" target="_blank">
#           <b>
#            Subscribe to KDnuggets News
#           </b>
#          </a>
#         </div>
#         <!-- div class="footer-sm">
#       <a href="https://twitter.com/kdnuggets" target="_blank" onclick="ga('send','pageview','/x/bot/twt');"><img src="/images/tw_c48.png" width=32 height=32></a>
#       <a href="https://facebook.com/kdnuggets" target="_blank" onclick="ga('send','pageview','/x/bot/fb');"><img src="/images/fb_c48.png" alt="Facebook" width=32 height=32></a>
#       <a href="https://www.linkedin.com/groups/54257" target="_blank"  onclick="ga('send','pageview','/x/bot/in');"><img src="/images/in_c48.png" alt="LinkedIn" width=32 height=32></a>
#     </div -->
#        </div>
#        <div class="close-footer">
#         X
#        </div>
#       </div>
#       <script type="text/javascript">
#        jQuery('.close-footer').click(
#       function(){
#          jQuery('.kd_bottom').hide();
#       }
#    );
#       </script>
#      </div>
#      <div class="clear">
#       <!--blank-->
#      </div>
#     </br>
#    </div>
#    <div style="display: none;">
#     <div id="boxzilla-box-82996-content">
#      <script type="text/javascript">
#       (function() {
# 	if (!window.mc4wp) {
# 		window.mc4wp = {
# 			listeners: [],
# 			forms    : {
# 				on: function (event, callback) {
# 					window.mc4wp.listeners.push({
# 						event   : event,
# 						callback: callback
# 					});
# 				}
# 			}
# 		}
# 	}
# })();
#      </script>
#      <!-- MailChimp for WordPress v4.1.14 - https://wordpress.org/plugins/mailchimp-for-wp/ -->
#      <form class="mc4wp-form mc4wp-form-77281" data-id="77281" data-name="Subscribe to KDnuggets News" id="mc4wp-form-1" method="post">
#       <div class="mc4wp-form-fields">
#        <div class="header-container">
#         <img align="left" src="/wp-content/uploads/envelope.png">
#          <a href="/news/subscribe.html">
#           Get KDnuggets, a leading newsletter on AI,
#   Data Science, and Machine Learning
#          </a>
#         </img>
#        </div>
#        <div class="form-fields">
#         <div class="field-container">
#          <label>
#           Email:
#          </label>
#          <input maxlength="60" name="EMAIL" placeholder="Your email" required="" size="30" type="email"/>
#         </div>
#         <div class="field-container submit-container">
#          <div class="form-button" onclick="document.getElementById('mc4wp-form-1').submit()">
#           Sign Up
#          </div>
#          <p style="font-size:9px">
#           By subscribing you accept KDnuggets
#           <a href="https://www.kdnuggets.com/news/privacy-policy.html" style="font-size:9px" target="_blank">
#            Privacy Policy
#           </a>
#          </p>
#         </div>
#        </div>
#        <label style="display: none !important;">
#         Leave this field empty if you're human:
#         <input autocomplete="off" name="_mc4wp_honeypot" tabindex="-1" type="text" value=""/>
#        </label>
#        <input name="_mc4wp_timestamp" type="hidden" value="1635815955"/>
#        <input name="_mc4wp_form_id" type="hidden" value="77281"/>
#        <input name="_mc4wp_form_element_id" type="hidden" value="mc4wp-form-1"/>
#       </div>
#       <div class="mc4wp-response">
#       </div>
#      </form>
#      <!-- / MailChimp for WordPress Plugin -->
#     </div>
#    </div>
#    <script type="text/javascript">
#     (function() {function addEventListener(element,event,handler) {
# 	if(element.addEventListener) {
# 		element.addEventListener(event,handler, false);
# 	} else if(element.attachEvent){
# 		element.attachEvent('on'+event,handler);
# 	}
# }function maybePrefixUrlField() {
# 	if(this.value.trim() !== '' && this.value.indexOf('http') !== 0) {
# 		this.value = "http://" + this.value;
# 	}
# }
#
# var urlFields = document.querySelectorAll('.mc4wp-form input[type="url"]');
# if( urlFields && urlFields.length > 0 ) {
# 	for( var j=0; j < urlFields.length; j++ ) {
# 		addEventListener(urlFields[j],'blur',maybePrefixUrlField);
# 	}
# }/* test if browser supports date fields */
# var testInput = document.createElement('input');
# testInput.setAttribute('type', 'date');
# if( testInput.type !== 'date') {
#
# 	/* add placeholder & pattern to all date fields */
# 	var dateFields = document.querySelectorAll('.mc4wp-form input[type="date"]');
# 	for(var i=0; i<dateFields.length; i++) {
# 		if(!dateFields[i].placeholder) {
# 			dateFields[i].placeholder = 'YYYY-MM-DD';
# 		}
# 		if(!dateFields[i].pattern) {
# 			dateFields[i].pattern = '[0-9]{4}-(0[1-9]|1[012])-(0[1-9]|1[0-9]|2[0-9]|3[01])';
# 		}
# 	}
# }
#
# })();
#    </script>
#    <script type="text/javascript">
#     /* <![CDATA[ */
# var boxzilla_options = {"testMode":"","boxes":[{"id":82996,"icon":"&times;","content":"","css":{"background_color":"#eeee22","width":600,"border_width":2,"border_style":"double","position":"center"},"trigger":{"method":"time_on_page","value":"3"},"animation":"fade","cookie":{"triggered":0,"dismissed":336},"rehide":true,"position":"center","screenWidthCondition":{"condition":"larger","value":500},"closable":true,"post":{"id":82996,"title":"Subscribe to KDnuggets","slug":"subscribe-to-kdnuggets"}}]};
# /* ]]> */
#    </script>
#    <script src="https://www.kdnuggets.com/wp-content/plugins/boxzilla/assets/js/script.min.js?ver=3.2.5" type="text/javascript">
#    </script>
#    <script src="https://www.kdnuggets.com/wp-includes/js/wp-embed.min.js?ver=4.9.18" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     /* <![CDATA[ */
# var mc4wp_forms_config = [];
# /* ]]> */
#    </script>
#    <script src="https://www.kdnuggets.com/wp-content/plugins/mailchimp-for-wp/assets/js/forms-api.min.js?ver=4.1.14" type="text/javascript">
#    </script>
#    <!--[if lte IE 9]>
# <script type='text/javascript' src='https://www.kdnuggets.com/wp-content/plugins/mailchimp-for-wp/assets/js/third-party/placeholders.min.js?ver=4.1.14'></script>
# <![endif]-->
#    <!--/.main_wrapper-->
#   </div>
#   <script src="https://s7.addthis.com/js/300/addthis_widget.js#pubid=gpsaddthis" type="text/javascript">
#   </script>
#  </body>
# </html>
# <!-- Dynamic page generated in 3.273 seconds. -->
# <!-- Cached page generated by WP-Super-Cache on 2021-11-01 21:19:15 -->
# <!-- Compression = gzip -->

# %%
items = soup.find('ul', class_='three_ul test').find_all('li')
items[0]
# Out:
# <li> <a href="https://www.kdnuggets.com/2021/10/multivariate-time-series-analysis-lstm-based-rnn.html" id="134487"><b>Multivariate Time Series Analysis with an LSTM based RNN</b></a>, by Kathrin Melcher         <font color="#808080">- Oct 29, 2021</font>.
#          <div style="margin-left: 12px; font-size: small;">
#          Check out this codeless solution using the Keras integration.
#  </div>
# <p class="tags">Tags: <a href="https://www.kdnuggets.com/tag/keras" rel="tag">Keras</a>, <a href="https://www.kdnuggets.com/tag/knime" rel="tag">Knime</a>, <a href="https://www.kdnuggets.com/tag/low-code" rel="tag">Low-Code</a>, <a href="https://www.kdnuggets.com/tag/lstm" rel="tag">LSTM</a>, <a href="https://www.kdnuggets.com/tag/time-series" rel="tag">Time Series</a></p>
# </li>

# %%
item = items[0]
item.find('a')['id']
# Out:
# '134487'

# %%
def get_id(item):
    try:
        return item.find('a')['id']
    except:
        return None

def get_title(item):
    try:
        return item.find('b').text
    except:
        return None

def get_author(item, title):
    try:
        this_text = item.text.replace(title, '')
        author = this_text.split('by')[1].split('-')[0]
        return author.strip()
    except:
        return None

def get_date(item):
    try:
        date = item.find('font').text
        return date.replace('-', '').strip()
    except:
        return None

def get_url(item):
    try:
        return item.find('a')['href']
    except:
        return None

def get_description(item):
    try:
        return item.find('div').text.strip()
    except:
        return None

def get_tags(item):
    try:
        tags = item.find('p', class_='tags').text
        return tags.split(': ')[-1]
    except:
        return None

def get_skills(title, description, tags):
    context = title
    if description is not None:
        context = context + ' ' + description
    if tags is not None:
        context = context + ' ' + tags
    all_skills = extract_skills(context)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    if len(keep_skills) > 0:
        data_skills = extract_data_skills(keep_skills)
        if len(data_skills) > 0:
            return '; '.join(keep_skills), '; '.join(data_skills)
        return '; '.join(keep_skills), None
    return None, None

# %%
# type_: tutorials/opinions
def get_posts(type_, month, year):
    base_url = 'https://www.kdnuggets.com/{}/{:>02}/{}.html' #:>02 to add leading 0 to month
    url = base_url.format(year, month, type_)
    page = requests.get(url, headers=random.choice(headers_list))
    if page.status_code != 200:
        print(page, page.reason)
        return None
    soup = BeautifulSoup(page.content, 'html.parser')
    items = soup.find('ul', class_='three_ul test').find_all('li')
    post_list = []
    for item in items:
        title = get_title(item)
        if title is None:
            continue
        description = get_description(item)
        tags = get_tags(item)
        skills, data_skills = get_skills(title, description, tags)
        post_list.append({
            'id': get_id(item),
            'title': title,
            'author': get_author(item, title),
            'date': get_date(item),
            'url': get_url(item),
            'description': description,
            'type': type_,
            'tags': tags,
            'skills': skills,
            'data_skills': data_skills,
        })
    df = pd.DataFrame.from_dict(post_list)
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by='id')
    return df

# %%
type_ = 'tutorials'
this_month = dt.datetime.today().month
df_tut = pd.DataFrame()

for i in log_progress(range(1, this_month)):
    df_tut = df_tut.append(get_posts(type_, i, 2021))

df_tut.tail()
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=10)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7cc59a6700a2> in <module>
#       4
#       5 for i in log_progress(range(1, this_month)):
# ----> 6     df_tut = df_tut.append(get_posts(type_, i, 2021))
#       7
#       8 df_tut.tail()
#
# <ipython-input-8-6c6edea206c5> in get_posts(type_, month, year)
#      16         description = get_description(item)
#      17         tags = get_tags(item)
# ---> 18         skills, data_skills = get_skills(title, description, tags)
#      19         post_list.append({
#      20             'id': get_id(item),
#
# <ipython-input-7-9fb32bcb0374> in get_skills(title, description, tags)
#      51     if tags is not None:
#      52         context = context + ' ' + tags
# ---> 53     all_skills = extract_skills(context)
#      54     keep_skills, _ = extract_ignore(all_skills)
#      55     keep_skills.sort()
#
# ~/Desktop/python-web-scraper/skill_extraction.py in extract_skills(info, threshold)
#      64         # Skill consist of two words
#      65         elif len(s2) == 2:
# ---> 66             if len(gcm(s, bigrams, cutoff=threshold)) > 0:
#      67                 results.append(skill)
#      68         # Skill consist of three words
#
# ~/opt/anaconda3/lib/python3.7/difflib.py in get_close_matches(word, possibilities, n, cutoff)
#     725         s.set_seq1(x)
#     726         if s.real_quick_ratio() >= cutoff and \
# --> 727            s.quick_ratio() >= cutoff and \
#     728            s.ratio() >= cutoff:
#     729             result.append((s.ratio(), x))
#
# ~/opt/anaconda3/lib/python3.7/difflib.py in quick_ratio(self)
#     669             else:
#     670                 numb = fullbcount.get(elt, 0)
# --> 671             avail[elt] = numb - 1
#     672             if numb > 0:
#     673                 matches = matches + 1
#
# KeyboardInterrupt:

# %%
type_ = 'opinions'
this_month = dt.datetime.today().month
df_op = pd.DataFrame()

for i in log_progress(range(1, this_month)):
    df_op = df_op.append(get_posts(type_, i, 2021))

df_op.tail()

# %%
df_kd = df_tut.append(df_op)
df_kd = df_kd.sort_values(by=['date', 'id'])
df_kd.head()

# %%
df_kd.info()

# %%
df_kd.to_csv('database/kdnuggets.csv', index=False)
