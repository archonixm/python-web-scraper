# %%
import requests
import random
import pandas as pd
import re
from bs4 import BeautifulSoup
from datetime import datetime
from headers import headers_list
from loading_bar import log_progress
from skill_extraction import extract_skills, extract_ignore

# %%
BASE_URL = 'https://jmlr.org'
url = BASE_URL + '/papers/v22/'
url
# Out:
# 'https://jmlr.org/papers/v22/'

# %%
page = requests.get(url, headers=random.choice(headers_list))
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
dls = soup.findAll('dl')
papers = []

for dl in dls:
    paper = {}
    paper['title'] = dl.find('dt').get_text()
    dd = dl.find('dd')
    paper['authors'] = dd.get_text().split(';')[0].strip()
    paper['journal_num'] = dd.get_text().split(';')[-1].split('\n')[0].strip()
    for a in dd.findAll('a'):
        if a.get_text() == '(Machine Learning Open Source Software Paper)':
            continue
        href = a['href']
        if 'http' not in href:
            href = 'https://jmlr.org' + href
        paper[a.get_text()] = href
    papers.append(paper)

papers
# Out:
# [{'title': 'On the Optimality of Kernel-Embedding Based Goodness-of-Fit Tests',
#   'authors': 'Krishnakumar Balasubramanian, Tong Li, Ming Yuan',
#   'journal_num': '(1):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/17-570.html',
#   'pdf': 'https://jmlr.org/papers/volume22/17-570/17-570.pdf',
#   'bib': 'https://jmlr.org/papers/v22/17-570.bib'},
#  {'title': 'Domain Generalization by Marginal Transfer Learning',
#   'authors': 'Gilles Blanchard, Aniket Anand Deshmukh, Urun Dogan, Gyemin Lee, Clayton Scott',
#   'journal_num': '(2):1−55, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/17-679.html',
#   'pdf': 'https://jmlr.org/papers/volume22/17-679/17-679.pdf',
#   'bib': 'https://jmlr.org/papers/v22/17-679.bib',
#   'code': 'https://github.com/aniketde/DomainGeneralizationMarginal'},
#  {'title': 'Regulating Greed Over Time in Multi-Armed Bandits',
#   'authors': 'Stefano Tracà, Cynthia Rudin, Weiyu Yan',
#   'journal_num': '(3):1−99, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/17-720.html',
#   'pdf': 'https://jmlr.org/papers/volume22/17-720/17-720.pdf',
#   'bib': 'https://jmlr.org/papers/v22/17-720.bib',
#   'code': 'https://github.com/ShrekFelix/Regulating-Greed-Over-Time'},
#  {'title': 'An Empirical Study of Bayesian Optimization: Acquisition Versus Partition',
#   'authors': 'Erich Merrill, Alan Fern, Xiaoli Fern, Nima Dolatnia',
#   'journal_num': '(4):1−25, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-220.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-220/18-220.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-220.bib',
#   'code': 'https://github.com/Eiii/opt_cmp'},
#  {'title': 'The Decoupled Extended Kalman Filter for Dynamic Exponential-Family Factorization Models',
#   'authors': 'Carlos A. Gomez-Uribe, Brian Karrer',
#   'journal_num': '(5):1−25, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-417.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-417/18-417.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-417.bib'},
#  {'title': 'Consistent estimation of small masses in feature sampling',
#   'authors': 'Fadhel Ayed, Marco Battiston, Federico Camerlenghi, Stefano Favaro',
#   'journal_num': '(6):1−28, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-534.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-534/18-534.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-534.bib'},
#  {'title': 'Preference-based Online Learning with Dueling Bandits: A Survey',
#   'authors': 'Viktor Bengs, Róbert Busa-Fekete, Adil El Mesaoudi-Paul, Eyke Hüllermeier',
#   'journal_num': '(7):1−108, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-546.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-546/18-546.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-546.bib'},
#  {'title': 'A Unified Framework for Random Forest Prediction Error Estimation',
#   'authors': 'Benjamin Lu, Johanna Hardin',
#   'journal_num': '(8):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-558.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-558/18-558.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-558.bib'},
#  {'title': 'Convex Clustering: Model, Theoretical Guarantee and Efficient Algorithm',
#   'authors': 'Defeng Sun, Kim-Chuan Toh, Yancheng Yuan',
#   'journal_num': '(9):1−32, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-694.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-694/18-694.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-694.bib'},
#  {'title': 'Mixing Time of Metropolis-Hastings for Bayesian Community Detection',
#   'authors': 'Bumeng Zhuo, Chao Gao',
#   'journal_num': '(10):1−89, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-770.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-770/18-770.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-770.bib'},
#  {'title': 'Unfolding-Model-Based Visualization: Theory, Method and Applications',
#   'authors': 'Yunxiao Chen, Zhiliang Ying, Haoran Zhang',
#   'journal_num': '(11):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-846.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-846/18-846.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-846.bib',
#   'code': 'https://github.com/hrzhang16/mmdu.'},
#  {'title': 'Global and Quadratic Convergence of Newton Hard-Thresholding Pursuit',
#   'authors': 'Shenglong Zhou, Naihua Xiu, Hou-Duo Qi',
#   'journal_num': '(12):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-026.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-026/19-026.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-026.bib'},
#  {'title': 'Homogeneity Structure Learning in Large-scale Panel Data with Heavy-tailed Errors',
#   'authors': 'Di Xiao, Yuan Ke, Runze Li',
#   'journal_num': '(13):1−42, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1018.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1018/19-1018.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1018.bib'},
#  {'title': 'On Multi-Armed Bandit Designs for Dose-Finding Trials',
#   'authors': 'Maryam Aziz, Emilie Kaufmann, Marie-Karelle Riviere',
#   'journal_num': '(14):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-228.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-228/19-228.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-228.bib'},
#  {'title': 'Simple and Fast Algorithms for Interactive Machine Learning with Random Counter-examples',
#   'authors': 'Jagdeep Singh Bhatia',
#   'journal_num': '(15):1−30, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-372.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-372/19-372.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-372.bib'},
#  {'title': 'Pykg2vec: A Python Library for Knowledge Graph Embedding',
#   'authors': 'Shih-Yuan Yu, Sujit Rokka Chhetri, Arquimedes Canedo, Palash Goyal, Mohammad Abdullah Al Faruque',
#   'journal_num': '(16):1−6, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/19-433.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-433/19-433.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-433.bib',
#   'code': 'https://github.com/Sujit-O/pykg2vec'},
#  {'title': 'Continuous Time Analysis of Momentum Methods',
#   'authors': 'Nikola B. Kovachki, Andrew M. Stuart',
#   'journal_num': '(17):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-466.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-466/19-466.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-466.bib',
#   'supplementary': 'https://jmlr.org/papers/volume22/19-466/supplementary.pdf'},
#  {'title': 'A Unified Sample Selection Framework for Output Noise Filtering: An Error-Bound Perspective',
#   'authors': 'Gaoxia Jiang, Wenjian Wang, Yuhua Qian, Jiye Liang',
#   'journal_num': '(18):1−66, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-498.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-498/19-498.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-498.bib'},
#  {'title': 'Ranking and synchronization from pairwise measurements via SVD',
#   'authors': "Alexandre d'Aspremont, Mihai Cucuringu, Hemant Tyagi",
#   'journal_num': '(19):1−63, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-542.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-542/19-542.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-542.bib'},
#  {'title': 'Aggregated Hold-Out',
#   'authors': 'Guillaume Maillard, Sylvain Arlot, Matthieu Lerasle',
#   'journal_num': '(20):1−55, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-624.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-624/19-624.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-624.bib'},
#  {'title': 'A Fast Globally Linearly Convergent Algorithm for the Computation of Wasserstein Barycenters',
#   'authors': 'Lei Yang, Jia Li, Defeng Sun, Kim-Chuan Toh',
#   'journal_num': '(21):1−37, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-629.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-629/19-629.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-629.bib'},
#  {'title': 'When random initializations help: a study of variational inference for community detection',
#   'authors': 'Purnamrita Sarkar, Y. X. Rachel Wang, Soumendu S. Mukherjee',
#   'journal_num': '(22):1−46, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-630.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-630/19-630.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-630.bib'},
#  {'title': 'A Two-Level Decomposition Framework Exploiting First and Second Order Information for SVM Training Problems',
#   'authors': 'Giulio Galvan, Matteo Lapucci, Chih-Jen Lin, Marco Sciandrone',
#   'journal_num': '(23):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-632.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-632/19-632.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-632.bib'},
#  {'title': 'Entangled Kernels - Beyond Separability',
#   'authors': 'Riikka Huusari, Hachem Kadri',
#   'journal_num': '(24):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-665.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-665/19-665.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-665.bib',
#   'code': 'https://github.com/RiikkaHuu/EKL'},
#  {'title': 'Generalization Performance of Multi-pass Stochastic Gradient Descent with Convex Loss Functions',
#   'authors': 'Yunwen Lei, Ting Hu, Ke Tang',
#   'journal_num': '(25):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-716.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-716/19-716.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-716.bib'},
#  {'title': 'Finite Time LTI System Identification',
#   'authors': 'Tuhin Sarkar, Alexander Rakhlin, Munther A. Dahleh',
#   'journal_num': '(26):1−61, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-725.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-725/19-725.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-725.bib'},
#  {'title': 'Inference In High-dimensional Single-Index Models Under Symmetric Designs',
#   'authors': "Hamid Eftekhari, Moulinath Banerjee, Ya'acov Ritov",
#   'journal_num': '(27):1−63, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-744.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-744/19-744.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-744.bib',
#   'code': 'https://github.com/ehamid/sim_debiasing'},
#  {'title': 'Tsallis-INF: An Optimal Algorithm for Stochastic and Adversarial Bandits',
#   'authors': 'Julian Zimmert, Yevgeny Seldin',
#   'journal_num': '(28):1−49, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-753.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-753/19-753.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-753.bib'},
#  {'title': 'Single and Multiple Change-Point Detection with Differential Privacy',
#   'authors': 'Wanrong Zhang, Sara Krehbiel, Rui Tuo, Yajun Mei, Rachel Cummings',
#   'journal_num': '(29):1−36, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-770.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-770/19-770.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-770.bib'},
#  {'title': 'A Review of Robot Learning for Manipulation: Challenges, Representations, and Algorithms',
#   'authors': 'Oliver Kroemer, Scott Niekum, George Konidaris',
#   'journal_num': '(30):1−82, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-804.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-804/19-804.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-804.bib'},
#  {'title': 'FLAME: A Fast Large-scale Almost Matching Exactly Approach to Causal Inference',
#   'authors': 'Tianyu Wang, Marco Morucci, M. Usaid Awan, Yameng Liu, Sudeepa Roy, Cynthia Rudin, Alexander Volfovsky',
#   'journal_num': '(31):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-853.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-853/19-853.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-853.bib',
#   'website': 'https://almost-matching-exactly.github.io/'},
#  {'title': 'Learning interaction kernels in heterogeneous systems of agents from multiple trajectories',
#   'authors': 'Fei Lu, Mauro Maggioni, Sui Tang',
#   'journal_num': '(32):1−67, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-861.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-861/19-861.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-861.bib',
#   'code': 'https://github.com/MingZhongCodes/LearningDynamics.git'},
#  {'title': 'Asynchronous Online Testing of Multiple Hypotheses',
#   'authors': 'Tijana Zrnic, Aaditya Ramdas, Michael I. Jordan',
#   'journal_num': '(33):1−39, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-910.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-910/19-910.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-910.bib'},
#  {'title': 'Neighborhood Structure Assisted Non-negative Matrix Factorization and Its Application in Unsupervised Point-wise Anomaly Detection',
#   'authors': 'Imtiaz Ahmed, Xia Ben Hu, Mithun P. Acharya, Yu Ding',
#   'journal_num': '(34):1−32, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-924.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-924/19-924.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-924.bib',
#   'code': 'https://urldefense.com/v3/__https://tamucs-my.sharepoint.com/:u:/g/personal/yu-ding_tamu_edu/EdeIKFF07H1KlB0vIeGxtrABbs9DcQnL8Bf8_cNjNQeR3g?e=exOuZm__;!!KwNVnqRv!VnN480fumwOmmgvIA_xcK58wt1ax4nXdi2iYfu_pqjzo3-xnLb955YhS_HGh5pFUyQ$'},
#  {'title': 'Learning and Planning for Time-Varying MDPs Using Maximum Likelihood Estimation',
#   'authors': 'Melkior Ornik, Ufuk Topcu',
#   'journal_num': '(35):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-006.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-006/20-006.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-006.bib'},
#  {'title': 'Multi-class Gaussian Process Classification with Noisy Inputs',
#   'authors': 'Carlos Villacampa-Calvo, Bryan Zaldívar, Eduardo C. Garrido-Merchán, Daniel Hernández-Lobato',
#   'journal_num': '(36):1−52, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-107.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-107/20-107.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-107.bib',
#   'code': 'https://github.com/cvillacampa/GPInputNoise'},
#  {'title': 'A Bayesian Contiguous Partitioning Method for Learning Clustered Latent Variables',
#   'authors': 'Zhao Tang Luo, Huiyan Sang, Bani Mallick',
#   'journal_num': '(37):1−52, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-136.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-136/20-136.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-136.bib'},
#  {'title': 'Risk-Averse Learning by Temporal Difference Methods with Markov Risk Measures',
#   'authors': 'Umit Köse, Andrzej Ruszczyński',
#   'journal_num': '(38):1−34, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-168.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-168/20-168.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-168.bib'},
#  {'title': 'giotto-tda: : A Topological Data Analysis Toolkit for Machine Learning and Data Exploration',
#   'authors': 'Guillaume Tauzin, Umberto Lupo, Lewis Tunstall, Julian Burella Pérez, Matteo Caorsi, Anibal M. Medina-Mardones, Alberto Dassatti, Kathryn Hess',
#   'journal_num': '(39):1−6, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-325.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-325/20-325.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-325.bib',
#   'code': 'https://github.com/giotto-ai/giotto-tda'},
#  {'title': 'Residual Energy-Based Models for Text',
#   'authors': "Anton Bakhtin, Yuntian Deng, Sam Gross, Myle Ott, Marc'Aurelio Ranzato, Arthur Szlam",
#   'journal_num': '(40):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-326.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-326/20-326.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-326.bib'},
#  {'title': 'From Fourier to Koopman: Spectral Methods for Long-term Time Series Prediction',
#   'authors': 'Henning Lange, Steven L. Brunton, J. Nathan Kutz',
#   'journal_num': '(41):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-406.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-406/20-406.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-406.bib',
#   'code': 'https://github.com/helange23/from_fourier_to_koopman'},
#  {'title': 'High-Order Langevin Diffusion Yields an Accelerated MCMC Algorithm',
#   'authors': 'Wenlong Mou, Yi-An Ma, Martin J. Wainwright, Peter L. Bartlett, Michael I. Jordan',
#   'journal_num': '(42):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-576.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-576/20-576.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-576.bib'},
#  {'title': 'Banach Space Representer Theorems for Neural Networks and Ridge Splines',
#   'authors': 'Rahul Parhi, Robert D. Nowak',
#   'journal_num': '(43):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-583.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-583/20-583.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-583.bib'},
#  {'title': 'Wasserstein barycenters can be computed in polynomial time in fixed dimension',
#   'authors': 'Jason M Altschuler, Enric Boix-Adsera',
#   'journal_num': '(44):1−19, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-588.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-588/20-588.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-588.bib',
#   'code': 'https://github.com/eboix/high_precision_barycenters'},
#  {'title': 'RaSE: Random Subspace Ensemble Classification',
#   'authors': 'Ye Tian, Yang Feng',
#   'journal_num': '(45):1−93, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-600.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-600/20-600.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-600.bib',
#   'code': 'https://cran.r-project.org/web/packages/RaSEn/index.html'},
#  {'title': 'Optimal Structured Principal Subspace Estimation: Metric Entropy and Minimax Rates',
#   'authors': 'Tony Cai, Hongzhe Li, Rong Ma',
#   'journal_num': '(46):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-610.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-610/20-610.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-610.bib'},
#  {'title': 'Understanding Recurrent Neural Networks Using Nonequilibrium Response Theory',
#   'authors': 'Soon Hoe Lim',
#   'journal_num': '(47):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-620.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-620/20-620.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-620.bib'},
#  {'title': 'Optimal Feedback Law Recovery by Gradient-Augmented Sparse Polynomial Regression',
#   'authors': 'Behzad Azmi, Dante Kalise, Karl Kunisch',
#   'journal_num': '(48):1−32, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-755.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-755/20-755.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-755.bib'},
#  {'title': 'From Low Probability to High Confidence in Stochastic Convex Optimization',
#   'authors': 'Damek Davis, Dmitriy Drusvyatskiy, Lin Xiao, Junyu Zhang',
#   'journal_num': '(49):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-821.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-821/20-821.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-821.bib'},
#  {'title': 'Structure Learning of Undirected Graphical Models for Count Data',
#   'authors': 'Nguyen Thi Kim Hue, Monica Chiogna',
#   'journal_num': '(50):1−53, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-401.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-401/18-401.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-401.bib'},
#  {'title': 'Projection-free Decentralized Online Learning for Submodular Maximization over Time-Varying Networks',
#   'authors': 'Junlong Zhu, Qingtao Wu, Mingchuan Zhang, Ruijuan Zheng, Keqin Li',
#   'journal_num': '(51):1−42, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-407.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-407/18-407.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-407.bib'},
#  {'title': 'Sparse and Smooth Signal Estimation: Convexification of L0-Formulations',
#   'authors': 'Alper Atamturk, Andres Gomez, Shaoning Han',
#   'journal_num': '(52):1−43, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-745.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-745/18-745.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-745.bib'},
#  {'title': 'Subspace Clustering through Sub-Clusters',
#   'authors': 'Weiwei Li, Jan Hannig, Sayan Mukherjee',
#   'journal_num': '(53):1−37, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-780.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-780/18-780.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-780.bib'},
#  {'title': 'GemBag: Group Estimation of Multiple Bayesian Graphical Models',
#   'authors': 'Xinming Yang, Lingrui Gan, Naveen N. Narisetty, Feng Liang',
#   'journal_num': '(54):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1006.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1006/19-1006.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1006.bib'},
#  {'title': 'Integrative Generalized Convex Clustering Optimization and Feature Selection for Mixed Multi-View Data',
#   'authors': 'Minjie Wang, Genevera I. Allen',
#   'journal_num': '(55):1−73, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1012.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1012/19-1012.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1012.bib'},
#  {'title': 'Incorporating Unlabeled Data into Distributionally Robust Learning',
#   'authors': 'Charlie Frogner, Sebastian Claici, Edward Chien, Justin Solomon',
#   'journal_num': '(56):1−46, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1023.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1023/19-1023.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1023.bib'},
#  {'title': 'Normalizing Flows for Probabilistic Modeling and Inference',
#   'authors': 'George Papamakarios, Eric Nalisnick, Danilo Jimenez Rezende, Shakir Mohamed, Balaji Lakshminarayanan',
#   'journal_num': '(57):1−64, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1028.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1028/19-1028.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1028.bib'},
#  {'title': 'Estimation and Inference for High Dimensional Generalized Linear Models: A Splitting and Smoothing Approach',
#   'authors': 'Zhe Fei, Yi Li',
#   'journal_num': '(58):1−32, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-132.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-132/19-132.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-132.bib',
#   'code': 'https://github.com/feizhe/SSHDI'},
#  {'title': 'Predictive Learning on Hidden Tree-Structured Ising Models',
#   'authors': 'Konstantinos E. Nikolakakis, Dionysios S. Kalogerias, Anand D. Sarwate',
#   'journal_num': '(59):1−82, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-149.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-149/19-149.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-149.bib',
#   'code': 'https://github.com/KonstantinosNikolakakis'},
#  {'title': 'A Distributed Method for Fitting Laplacian Regularized Stratified Models',
#   'authors': 'Jonathan Tuck, Shane Barratt, Stephen Boyd',
#   'journal_num': '(60):1−37, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-345.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-345/19-345.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-345.bib',
#   'code': 'https://github.com/cvxgrp/strat_models'},
#  {'title': 'Stochastic Proximal AUC Maximization',
#   'authors': 'Yunwen Lei, Yiming Ying',
#   'journal_num': '(61):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-418.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-418/19-418.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-418.bib'},
#  {'title': 'How to Gain on Power: Novel  Conditional Independence Tests Based on Short Expansion of Conditional Mutual Information',
#   'authors': 'Mariusz Kubkowski, Jan Mielniczuk, Paweł Teisseyre',
#   'journal_num': '(62):1−57, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-600.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-600/19-600.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-600.bib'},
#  {'title': 'Geometric structure of graph Laplacian embeddings',
#   'authors': 'Nicolás García Trillos, Franca Hoffmann, Bamdad Hosseini',
#   'journal_num': '(63):1−55, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-683.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-683/19-683.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-683.bib'},
#  {'title': 'Sparse Tensor Additive Regression',
#   'authors': 'Botao Hao, Boxiang Wang, Pengyuan Wang, Jingfei Zhang, Jian Yang, Will Wei Sun',
#   'journal_num': '(64):1−43, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-769.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-769/19-769.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-769.bib'},
#  {'title': 'Dynamic Tensor Recommender Systems',
#   'authors': 'Yanqing Zhang, Xuan Bi, Niansheng Tang, Annie Qu',
#   'journal_num': '(65):1−35, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-792.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-792/19-792.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-792.bib'},
#  {'title': 'Approximate Newton Methods',
#   'authors': 'Haishan Ye, Luo Luo, Zhihua Zhang',
#   'journal_num': '(66):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-870.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-870/19-870.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-870.bib'},
#  {'title': 'A General Framework for Empirical Bayes Estimation in Discrete Linear Exponential Family',
#   'authors': 'Trambak Banerjee, Qiang Liu, Gourab Mukherjee, Wengunag Sun',
#   'journal_num': '(67):1−46, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-873.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-873/19-873.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-873.bib'},
#  {'title': 'Path Length Bounds for Gradient Descent and Flow',
#   'authors': 'Chirag Gupta, Sivaraman Balakrishnan, Aaditya Ramdas',
#   'journal_num': '(68):1−63, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-979.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-979/19-979.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-979.bib',
#   'blog': 'https://blog.ml.cmu.edu/2019/10/25/path-length-bounds-for-gradient-descent/'},
#  {'title': 'Determining the Number of Communities in Degree-corrected Stochastic Block Models',
#   'authors': 'Shujie Ma, Liangjun Su, Yichong Zhang',
#   'journal_num': '(69):1−63, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-037.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-037/20-037.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-037.bib'},
#  {'title': 'Testing Conditional Independence via Quantile Regression Based Partial Copulas',
#   'authors': 'Lasse Petersen, Niels Richard Hansen',
#   'journal_num': '(70):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1074.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1074/20-1074.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1074.bib',
#   'code': 'https://github.com/lassepetersen/partial-copula-CI-test'},
#  {'title': 'Phase Diagram for Two-layer ReLU Neural Networks at Infinite-width Limit',
#   'authors': 'Tao Luo, Zhi-Qin John Xu, Zheng Ma, Yaoyu Zhang',
#   'journal_num': '(71):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1123.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1123/20-1123.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1123.bib',
#   'code': 'https://github.com/xuzhiqin1990/phasediagram_twolayerNN'},
#  {'title': 'Prediction against a limited adversary',
#   'authors': 'Erhan Bayraktar, Ibrahim Ekren, Xin Zhang',
#   'journal_num': '(72):1−33, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1234.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1234/20-1234.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1234.bib'},
#  {'title': 'Optimization with Momentum: Dynamical, Control-Theoretic, and Symplectic Perspectives',
#   'authors': 'Michael Muehlebach, Michael I. Jordan',
#   'journal_num': '(73):1−50, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-207.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-207/20-207.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-207.bib'},
#  {'title': 'Kernel Operations on the GPU, with Autodiff, without Memory Overflows',
#   'authors': 'Benjamin Charlier, Jean Feydy, Joan Alexis Glaunès, François-David Collin, Ghislain Durif',
#   'journal_num': '(74):1−6, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-275.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-275/20-275.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-275.bib',
#   'code': 'https://github.com/getkeops/keops/'},
#  {'title': 'Attention is Turing-Complete',
#   'authors': 'Jorge Pérez, Pablo Barceló, Javier Marinkovic',
#   'journal_num': '(75):1−35, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-302.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-302/20-302.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-302.bib'},
#  {'title': 'Analyzing the discrepancy principle for kernelized spectral filter learning algorithms',
#   'authors': 'Alain Celisse, Martin Wahl',
#   'journal_num': '(76):1−59, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-358.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-358/20-358.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-358.bib'},
#  {'title': 'ChainerRL: A Deep Reinforcement Learning Library',
#   'authors': 'Yasuhiro Fujita, Prabhat Nagarajan, Toshiki Kataoka, Takahiro Ishikawa',
#   'journal_num': '(77):1−14, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-376.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-376/20-376.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-376.bib',
#   'code': 'https://github.com/chainer/chainerrl'},
#  {'title': 'POT: Python Optimal Transport',
#   'authors': 'Rémi Flamary, Nicolas Courty, Alexandre Gramfort, Mokhtar Z. Alaya, Aurélie Boisbunon, Stanislas Chambon, Laetitia Chapel, Adrien Corenflos, Kilian Fatras, Nemo Fournier, Léo Gautheron, Nathalie T.H. Gayraud, Hicham Janati, Alain Rakotomamonjy, Ievgen Redko, Antoine Rolet, Antony Schutz, Vivien Seguy, Danica J. Sutherland, Romain Tavenard, Alexander Tong, Titouan Vayer',
#   'journal_num': '(78):1−8, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-451.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-451/20-451.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-451.bib',
#   'code': 'https://github.com/PythonOT/POT'},
#  {'title': 'Is SGD a Bayesian sampler? Well, almost',
#   'authors': 'Chris Mingard, Guillermo Valle-Pérez, Joar Skalse, Ard A. Louis',
#   'journal_num': '(79):1−64, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-676.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-676/20-676.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-676.bib'},
#  {'title': 'Communication-Efficient Distributed Covariance Sketch, with Application to Distributed PCA',
#   'authors': 'Zengfeng Huang, Xuemin Lin, Wenjie Zhang, Ying Zhang',
#   'journal_num': '(80):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-705.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-705/20-705.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-705.bib'},
#  {'title': 'Knowing what You Know: valid and validated confidence sets in multiclass and multilabel prediction',
#   'authors': 'Maxime Cauchois, Suyash Gupta, John C. Duchi',
#   'journal_num': '(81):1−42, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-753.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-753/20-753.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-753.bib'},
#  {'title': 'PyKEEN 1.0: A Python Library for Training and Evaluating Knowledge Graph Embeddings',
#   'authors': 'Mehdi Ali, Max Berrendorf, Charles Tapley Hoyt, Laurent Vermue, Sahand Sharifzadeh, Volker Tresp, Jens Lehmann',
#   'journal_num': '(82):1−6, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-825.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-825/20-825.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-825.bib'},
#  {'title': 'Statistical Query Lower Bounds for Tensor PCA',
#   'authors': 'Rishabh Dudeja, Daniel Hsu',
#   'journal_num': '(83):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-837.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-837/20-837.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-837.bib'},
#  {'title': 'Variance Reduced Median-of-Means Estimator for Byzantine-Robust Distributed Inference',
#   'authors': 'Jiyuan Tu, Weidong Liu, Xiaojun Mao, Xi Chen',
#   'journal_num': '(84):1−67, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-950.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-950/20-950.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-950.bib'},
#  {'title': 'Gradient Methods Never Overfit On Separable Data',
#   'authors': 'Ohad Shamir',
#   'journal_num': '(85):1−20, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-997.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-997/20-997.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-997.bib'},
#  {'title': 'Multi-view Learning as a Nonparametric Nonlinear Inter-Battery Factor Analysis',
#   'authors': 'Andreas Damianou, Neil D. Lawrence, Carl Henrik Ek',
#   'journal_num': '(86):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/16-179.html',
#   'pdf': 'https://jmlr.org/papers/volume22/16-179/16-179.pdf',
#   'bib': 'https://jmlr.org/papers/v22/16-179.bib'},
#  {'title': 'On Solving Probabilistic Linear Diophantine Equations',
#   'authors': 'Patrick Kreitzberg, Oliver Serang',
#   'journal_num': '(87):1−24, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/17-474.html',
#   'pdf': 'https://jmlr.org/papers/volume22/17-474/17-474.pdf',
#   'bib': 'https://jmlr.org/papers/v22/17-474.bib',
#   'code': 'https://bitbucket.org/orserang/evergreenforest'},
#  {'title': 'Edge Sampling Using Local Network Information',
#   'authors': 'Can M. Le',
#   'journal_num': '(88):1−29, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-240.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-240/18-240.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-240.bib'},
#  {'title': 'Bayesian Text Classification and Summarization via A Class-Specified Topic Model',
#   'authors': 'Feifei Wang, Junni L. Zhang, Yichao Li, Ke Deng, Jun S. Liu',
#   'journal_num': '(89):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-332.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-332/18-332.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-332.bib'},
#  {'title': 'Risk Bounds for Unsupervised Cross-Domain Mapping with IPMs',
#   'authors': 'Tomer Galanti, Sagie Benaim, Lior Wolf',
#   'journal_num': '(90):1−42, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-489.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-489/18-489.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-489.bib',
#   'code': 'https://github.com/TomerGalanti/RiskBoundsCrossDomain'},
#  {'title': 'Analysis of high-dimensional Continuous Time Markov Chains using the Local Bouncy Particle Sampler',
#   'authors': 'Tingting Zhao, Alexandre Bouchard-Côté',
#   'journal_num': '(91):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-651.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-651/18-651.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-651.bib',
#   'code': 'https://github.com/zhaottcrystal/rejfreePy_main'},
#  {'title': 'NEU: A Meta-Algorithm for Universal UAP-Invariant Feature Representation',
#   'authors': 'Anastasis Kratsios, Cody Hyndman',
#   'journal_num': '(92):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/18-803.html',
#   'pdf': 'https://jmlr.org/papers/volume22/18-803/18-803.pdf',
#   'bib': 'https://jmlr.org/papers/v22/18-803.bib',
#   'code': 'https://github.com/AnastasisKratsios/NEU_Non_Euclidean_Upgrading'},
#  {'title': 'Flexible Signal Denoising via Flexible Empirical Bayes Shrinkage',
#   'authors': 'Zhengrong Xing, Peter Carbonetto, Matthew Stephens',
#   'journal_num': '(93):1−28, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-042.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-042/19-042.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-042.bib',
#   'code': 'https://www.github.com/stephenslab/smashr'},
#  {'title': 'Consistent Semi-Supervised Graph Regularization for High Dimensional Data',
#   'authors': 'Xiaoyi Mai, Romain Couillet',
#   'journal_num': '(94):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-081.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-081/19-081.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-081.bib'},
#  {'title': 'Histogram Transform Ensembles for Large-scale Regression',
#   'authors': 'Hanyuan Hang, Zhouchen Lin, Xiaoyu Liu, Hongwei Wen',
#   'journal_num': '(95):1−87, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-1004.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-1004/19-1004.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-1004.bib'},
#  {'title': 'Guided Visual Exploration of Relations in Data Sets',
#   'authors': 'Kai Puolamäki, Emilia Oikarinen, Andreas Henelius',
#   'journal_num': '(96):1−32, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-364.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-364/19-364.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-364.bib',
#   'code': 'https://github.com/edahelsinki/corand'},
#  {'title': 'Safe Policy Iteration: A Monotonically Improving Approximate Policy Iteration Approach',
#   'authors': 'Alberto Maria Metelli, Matteo Pirotta, Daniele Calandriello, Marcello Restelli',
#   'journal_num': '(97):1−83, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-707.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-707/19-707.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-707.bib'},
#  {'title': 'On the Theory of Policy Gradient Methods: Optimality, Approximation, and Distribution Shift',
#   'authors': 'Alekh Agarwal, Sham M. Kakade, Jason D. Lee, Gaurav Mahajan',
#   'journal_num': '(98):1−76, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-736.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-736/19-736.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-736.bib'},
#  {'title': 'Adaptive estimation of nonparametric functionals',
#   'authors': 'Lin Liu, Rajarshi Mukherjee, James M. Robins, Eric Tchetgen Tchetgen',
#   'journal_num': '(99):1−66, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-892.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-892/19-892.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-892.bib'},
#  {'title': 'OpenML-Python: an extensible Python API for OpenML',
#   'authors': 'Matthias Feurer, Jan N. van Rijn, Arlind Kadra, Pieter Gijsbers, Neeratyoy Mallik, Sahithya Ravi, Andreas Müller, Joaquin Vanschoren, Frank Hutter',
#   'journal_num': '(100):1−5, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/19-920.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-920/19-920.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-920.bib',
#   'code': 'https://github.com/openml/openml-python/'},
#  {'title': 'LocalGAN: Modeling Local Distributions for Adversarial Response Generation',
#   'authors': 'Baoxun Wang, Zhen Xu, Huan Zhang, Kexin Qiu, Deyuan Zhang, Chengjie Sun',
#   'journal_num': '(101):1−29, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-052.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-052/20-052.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-052.bib',
#   'code': 'https://github.com/dreasysnail/converse_GAN'},
#  {'title': 'Learning a High-dimensional Linear Structural Equation Model via l1-Regularized Regression',
#   'authors': 'Gunwoong Park, Sang Jun Moon, Sion Park, Jong-June Jeon',
#   'journal_num': '(102):1−41, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1005.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1005/20-1005.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1005.bib'},
#  {'title': 'A Unified Analysis of First-Order Methods for Smooth Games via Integral Quadratic Constraints',
#   'authors': 'Guodong Zhang, Xuchan Bao, Laurent Lessard, Roger Grosse',
#   'journal_num': '(103):1−39, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1068.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1068/20-1068.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1068.bib',
#   'code': 'https://github.com/gd-zhang/IQC-Game'},
#  {'title': 'Explaining Explanations: Axiomatic Feature Interactions for Deep Networks',
#   'authors': 'Joseph D. Janizek, Pascal Sturmfels, Su-In Lee',
#   'journal_num': '(104):1−54, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1223.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1223/20-1223.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1223.bib',
#   'code': 'https://github.com/suinleelab/path_explain'},
#  {'title': 'Pathwise Conditioning of Gaussian Processes',
#   'authors': 'James T. Wilson, Viacheslav Borovitskiy, Alexander Terenin, Peter Mostowsky, Marc Peter Deisenroth',
#   'journal_num': '(105):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1260.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1260/20-1260.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1260.bib',
#   'code': 'https://github.com/j-wilson/GPflowSampling'},
#  {'title': 'Online stochastic gradient descent on non-convex losses from high-dimensional inference',
#   'authors': 'Gerard Ben Arous, Reza Gheissari, Aukosh Jagannath',
#   'journal_num': '(106):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1288.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1288/20-1288.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1288.bib'},
#  {'title': 'Beyond English-Centric Multilingual Machine Translation',
#   'authors': 'Angela Fan, Shruti Bhosale, Holger Schwenk, Zhiyi Ma, Ahmed El-Kishky, Siddharth Goyal, Mandeep Baines, Onur Celebi, Guillaume Wenzek, Vishrav Chaudhary, Naman Goyal, Tom Birch, Vitaliy Liptchinsky, Sergey Edunov, Michael Auli, Armand Joulin',
#   'journal_num': '(107):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1307.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1307/20-1307.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1307.bib',
#   'code': 'https://github.com/pytorch/fairseq/tree/master/examples/m2m_100'},
#  {'title': 'Towards a Unified Analysis of Random Fourier Features',
#   'authors': 'Zhu Li, Jean-Francois Ton, Dino Oglic, Dino Sejdinovic',
#   'journal_num': '(108):1−51, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1369.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1369/20-1369.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1369.bib'},
#  {'title': 'mvlearn: Multiview Machine Learning in Python',
#   'authors': 'Ronan Perry, Gavin Mischler, Richard Guo, Theodore Lee, Alexander Chang, Arman Koul, Cameron Franz, Hugo Richard, Iain Carmichael, Pierre Ablin, Alexandre Gramfort, Joshua T. Vogelstein',
#   'journal_num': '(109):1−7, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-1370.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1370/20-1370.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1370.bib',
#   'code': 'https://github.com/mvlearn/mvlearn'},
#  {'title': 'River: machine learning for streaming data in Python',
#   'authors': 'Jacob Montiel, Max Halford, Saulo Martiello Mastelini, Geoffrey Bolmier, Raphael Sourty, Robin Vaysse, Adil Zouitine, Heitor Murilo Gomes, Jesse Read, Talel Abdessalem, Albert Bifet',
#   'journal_num': '(110):1−8, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-1380.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1380/20-1380.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1380.bib',
#   'code': 'https://github.com/online-ml/river'},
#  {'title': 'Non-parametric Quantile Regression via the K-NN Fused Lasso',
#   'authors': 'Steven Siwei Ye, Oscar Hernan Madrid Padilla',
#   'journal_num': '(111):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1462.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1462/20-1462.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1462.bib',
#   'code': 'https://github.com/stevenysw/qt_knnfl'},
#  {'title': 'L-SVRG and L-Katyusha with Arbitrary Sampling',
#   'authors': 'Xun Qian, Zheng Qu, Peter Richtárik',
#   'journal_num': '(112):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-156.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-156/20-156.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-156.bib'},
#  {'title': 'A Lyapunov Analysis of Accelerated Methods in Optimization',
#   'authors': 'Ashia C. Wilson, Ben Recht, Michael I. Jordan',
#   'journal_num': '(113):1−34, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-195.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-195/20-195.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-195.bib'},
#  {'title': 'NUQSGD: Provably Communication-efficient Data-parallel SGD via Nonuniform Quantization',
#   'authors': 'Ali Ramezani-Kebrya, Fartash Faghri, Ilya Markov, Vitalii Aksenov, Dan Alistarh, Daniel M. Roy',
#   'journal_num': '(114):1−43, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-255.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-255/20-255.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-255.bib'},
#  {'title': 'Stochastic Proximal Methods for Non-Smooth Non-Convex Constrained Sparse Optimization',
#   'authors': 'Michael R. Metel, Akiko Takeda',
#   'journal_num': '(115):1−36, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-287.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-287/20-287.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-287.bib'},
#  {'title': 'An Importance Weighted Feature Selection Stability Measure',
#   'authors': 'Victor Hamer, Pierre Dupont',
#   'journal_num': '(116):1−57, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-366.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-366/20-366.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-366.bib'},
#  {'title': 'Strong Consistency, Graph Laplacians, and the Stochastic Block Model',
#   'authors': 'Shaofeng Deng, Shuyang Ling, Thomas Strohmer',
#   'journal_num': '(117):1−44, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-391.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-391/20-391.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-391.bib'},
#  {'title': 'A General Framework for Adversarial Label Learning',
#   'authors': 'Chidubem Arachie, Bert Huang',
#   'journal_num': '(118):1−33, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-537.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-537/20-537.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-537.bib',
#   'code': 'https://github.com/VTCSML/Adversarial-Label-Learning'},
#  {'title': 'Some Theoretical Insights into Wasserstein GANs',
#   'authors': 'Gérard Biau, Maxime Sangnier, Ugo Tanielian',
#   'journal_num': '(119):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-553.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-553/20-553.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-553.bib'},
#  {'title': 'Empirical Bayes Matrix Factorization',
#   'authors': 'Wei Wang, Matthew Stephens',
#   'journal_num': '(120):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-589.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-589/20-589.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-589.bib',
#   'code': 'https://github.com/stephenslab/flashr'},
#  {'title': 'Langevin Dynamics for Adaptive Inverse Reinforcement Learning of Stochastic Gradient Algorithms',
#   'authors': 'Vikram Krishnamurthy, George Yin',
#   'journal_num': '(121):1−49, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-625.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-625/20-625.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-625.bib'},
#  {'title': 'Sparse Convex Optimization via Adaptively Regularized Hard Thresholding',
#   'authors': 'Kyriakos Axiotis, Maxim Sviridenko',
#   'journal_num': '(122):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-661.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-661/20-661.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-661.bib'},
#  {'title': 'Convergence Guarantees for Gaussian Process Means With  Misspecified Likelihoods and Smoothness',
#   'authors': 'George Wynne, François-Xavier Briol, Mark Girolami',
#   'journal_num': '(123):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-662.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-662/20-662.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-662.bib'},
#  {'title': 'A flexible model-free prediction-based framework for feature ranking',
#   'authors': 'Jingyi Jessica Li, Yiling Elaine Chen, Xin Tong',
#   'journal_num': '(124):1−54, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-673.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-673/20-673.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-673.bib',
#   'code': 'https://github.com/JSB-UCLA/frc'},
#  {'title': 'Bandit Convex Optimization in Non-stationary Environments',
#   'authors': 'Peng Zhao, Guanghui Wang, Lijun Zhang, Zhi-Hua Zhou',
#   'journal_num': '(125):1−45, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-763.html',
# ...
#   'abs': 'https://jmlr.org/papers/v22/19-658.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-658/19-658.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-658.bib'},
#  {'title': 'On efficient multilevel Clustering via Wasserstein distances',
#   'authors': 'Viet Huynh, Nhat Ho, Nhan Dam, XuanLong Nguyen, Mikhail Yurochkin, Hung Bui, Dinh Phung',
#   'journal_num': '(145):1−43, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-782.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-782/19-782.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-782.bib'},
#  {'title': 'Nonparametric Modeling of Higher-Order Interactions via Hypergraphons',
#   'authors': 'Krishnakumar Balasubramanian',
#   'journal_num': '(146):1−35, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-941.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-941/19-941.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-941.bib'},
#  {'title': 'Optimal Minimax Variable Selection for Large-Scale Matrix Linear Regression Model',
#   'authors': 'Meiling Hao, Lianqiang Qu, Dehan Kong, Liuquan Sun, Hongtu Zhu',
#   'journal_num': '(147):1−39, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/19-969.html',
#   'pdf': 'https://jmlr.org/papers/volume22/19-969/19-969.pdf',
#   'bib': 'https://jmlr.org/papers/v22/19-969.bib'},
#  {'title': 'Statistical guarantees for local graph clustering',
#   'authors': 'Wooseok Ha, Kimon Fountoulakis, Michael W. Mahoney',
#   'journal_num': '(148):1−54, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-029.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-029/20-029.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-029.bib'},
#  {'title': 'Hyperparameter Optimization via Sequential Uniform Designs',
#   'authors': 'Zebin Yang, Aijun Zhang',
#   'journal_num': '(149):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-058.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-058/20-058.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-058.bib',
#   'code': 'https://github.com/SelfExplainML/SeqUD'},
#  {'title': 'Accelerating Ill-Conditioned Low-Rank Matrix Estimation via Scaled Gradient Descent',
#   'authors': 'Tian Tong, Cong Ma, Yuejie Chi',
#   'journal_num': '(150):1−63, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1067.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1067/20-1067.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1067.bib',
#   'code': 'https://github.com/Titan-Tong/ScaledGD'},
#  {'title': 'Universal consistency and rates of convergence of multiclass prototype algorithms in metric spaces',
#   'authors': 'László Györfi, Roi Weiss',
#   'journal_num': '(151):1−25, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1081.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1081/20-1081.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1081.bib'},
#  {'title': 'Hardness of Identity Testing for Restricted Boltzmann Machines and Potts models',
#   'authors': 'Antonio Blanca, Zongchen Chen, Daniel Štefankovič, Eric Vigoda',
#   'journal_num': '(152):1−56, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1162.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1162/20-1162.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1162.bib'},
#  {'title': 'Factorization Machines with Regularization for Sparse Feature Interactions',
#   'authors': 'Kyohei Atarashi, Satoshi Oyama, Masahito Kurihara',
#   'journal_num': '(153):1−50, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1170.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1170/20-1170.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1170.bib'},
#  {'title': 'Kernel Smoothing, Mean Shift, and Their Learning Theory with Directional Data',
#   'authors': 'Yikun Zhang, Yen-Chi Chen',
#   'journal_num': '(154):1−92, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1194.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1194/20-1194.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1194.bib',
#   'code': 'https://github.com/zhangyk8/DirMS'},
#  {'title': 'What Causes the Test Error? Going Beyond Bias-Variance via ANOVA',
#   'authors': 'Licong Lin, Edgar Dobriban',
#   'journal_num': '(155):1−82, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1211.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1211/20-1211.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1211.bib'},
#  {'title': 'A Greedy Algorithm for Quantizing Neural Networks',
#   'authors': 'Eric Lybrand, Rayan Saab',
#   'journal_num': '(156):1−38, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1233.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1233/20-1233.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1233.bib',
#   'code': 'https://github.com/elybrand/quantized_neural_networks'},
#  {'title': 'The Ridgelet Prior: A Covariance Function Approach to Prior Specification for Bayesian Neural Networks',
#   'authors': 'Takuo Matsubara, Chris J. Oates, François-Xavier Briol',
#   'journal_num': '(157):1−57, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1300.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1300/20-1300.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1300.bib'},
#  {'title': 'Information criteria for non-normalized models',
#   'authors': 'Takeru Matsuda, Masatoshi Uehara, Aapo Hyvarinen',
#   'journal_num': '(158):1−33, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1366.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1366/20-1366.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1366.bib'},
#  {'title': 'When Does Gradient Descent with Logistic Loss Find Interpolating Two-Layer Networks?',
#   'authors': 'Niladri S. Chatterji, Philip M. Long, Peter L. Bartlett',
#   'journal_num': '(159):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1372.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1372/20-1372.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1372.bib'},
#  {'title': 'Are We Forgetting about Compositional Optimisers in Bayesian Optimisation?',
#   'authors': 'Antoine Grosnit, Alexander I. Cowen-Rivers, Rasul Tutunov, Ryan-Rhys Griffiths, Jun Wang, Haitham Bou-Ammar',
#   'journal_num': '(160):1−78, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1422.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1422/20-1422.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1422.bib',
#   'code': 'https://github.com/huawei-noah/noah-research/tree/CompBO/BO/HEBO/CompBO'},
#  {'title': 'MetaGrad: Adaptation using Multiple Learning Rates in Online Learning',
#   'authors': 'Tim van Erven, Wouter M. Koolen, Dirk van der Hoeven',
#   'journal_num': '(161):1−61, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-1444.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-1444/20-1444.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-1444.bib',
#   'code': 'https://github.com/DirkvdH/Online-Appendix-MetaGrad'},
#  {'title': 'Counterfactual Mean Embeddings',
#   'authors': 'Krikamol Muandet, Motonobu Kanagawa, Sorawit Saengkyongam, Sanparith Marukatat',
#   'journal_num': '(162):1−71, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-185.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-185/20-185.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-185.bib',
#   'code': 'https://github.com/sorawitj/counterfactual-mean-embedding'},
#  {'title': 'PeerReview4All: Fair and Accurate Reviewer Assignment in Peer Review',
#   'authors': 'Ivan Stelmakh, Nihar Shah, Aarti Singh',
#   'journal_num': '(163):1−66, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-190.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-190/20-190.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-190.bib'},
#  {'title': 'Improving Reproducibility in Machine Learning Research(A Report from the NeurIPS 2019 Reproducibility Program)',
#   'authors': "Joelle Pineau, Philippe Vincent-Lamarre, Koustuv Sinha, Vincent Lariviere, Alina Beygelzimer, Florence d'Alche-Buc, Emily Fox, Hugo Larochelle",
#   'journal_num': '(164):1−20, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-303.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-303/20-303.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-303.bib'},
#  {'title': 'Implicit Self-Regularization in Deep Neural Networks: Evidence from Random Matrix Theory and Implications for Learning',
#   'authors': 'Charles H. Martin, Michael W. Mahoney',
#   'journal_num': '(165):1−73, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-410.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-410/20-410.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-410.bib'},
#  {'title': 'The ensmallen library for flexible numerical optimization',
#   'authors': 'Ryan R. Curtin, Marcus Edel, Rahul Ganesh Prabhu, Suryoday Basak, Zhihao Lou, Conrad Sanderson',
#   'journal_num': '(166):1−6, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/20-416.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-416/20-416.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-416.bib',
#   'code': 'https://github.com/mlpack/ensmallen'},
#  {'title': 'Estimation and Optimization of Composite Outcomes',
#   'authors': 'Daniel J. Luckett, Eric B. Laber, Siyeon Kim, Michael R. Kosorok',
#   'journal_num': '(167):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-429.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-429/20-429.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-429.bib'},
#  {'title': 'Asymptotic Normality, Concentration, and Coverage of Generalized Posteriors',
#   'authors': 'Jeffrey W. Miller',
#   'journal_num': '(168):1−53, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-469.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-469/20-469.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-469.bib'},
#  {'title': 'First-order Convergence Theory for Weakly-Convex-Weakly-Concave Min-max Problems',
#   'authors': 'Mingrui Liu, Hassan Rafique, Qihang Lin, Tianbao Yang',
#   'journal_num': '(169):1−34, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-533.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-533/20-533.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-533.bib'},
#  {'title': 'Black-Box Reductions for Zeroth-Order Gradient  Algorithms  to Achieve Lower  Query Complexity',
#   'authors': 'Bin Gu, Xiyuan Wei, Shangqian Gao, Ziran Xiong, Cheng Deng, Heng Huang',
#   'journal_num': '(170):1−47, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-611.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-611/20-611.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-611.bib'},
#  {'title': 'Optimal Rates of Distributed Regression with Imperfect Kernels',
#   'authors': 'Hongwei Sun, Qiang Wu',
#   'journal_num': '(171):1−34, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-627.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-627/20-627.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-627.bib'},
#  {'title': 'Unlinked Monotone Regression',
#   'authors': 'Fadoua Balabdaoui, Charles R. Doss, Cécile Durot',
#   'journal_num': '(172):1−60, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-689.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-689/20-689.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-689.bib'},
#  {'title': 'Replica Exchange for Non-Convex Optimization',
#   'authors': 'Jing Dong, Xin T. Tong',
#   'journal_num': '(173):1−59, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-697.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-697/20-697.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-697.bib'},
#  {'title': 'Achieving Fairness in the Stochastic Multi-Armed Bandit Problem',
#   'authors': 'Vishakha Patil, Ganesh Ghalme, Vineet Nair, Y. Narahari',
#   'journal_num': '(174):1−31, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-704.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-704/20-704.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-704.bib'},
#  {'title': 'Doubly infinite residual neural networks: a diffusion process approach',
#   'authors': 'Stefano Peluchetti, Stefano Favaro',
#   'journal_num': '(175):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-706.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-706/20-706.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-706.bib'},
#  {'title': 'Locally Private k-Means Clustering',
#   'authors': 'Uri Stemmer',
#   'journal_num': '(176):1−30, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-721.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-721/20-721.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-721.bib'},
#  {'title': 'Prediction Under Latent Factor Regression: Adaptive PCR, Interpolating Predictors and Beyond',
#   'authors': 'Xin Bing, Florentina Bunea, Seth Strimas-Mackey, Marten Wegkamp',
#   'journal_num': '(177):1−50, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-768.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-768/20-768.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-768.bib'},
#  {'title': 'Conditional independences and causal relations implied by sets of equations',
#   'authors': 'Tineke Blom, Mirthe M. van Diepen, Joris M. Mooij',
#   'journal_num': '(178):1−62, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-863.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-863/20-863.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-863.bib'},
#  {'title': 'A Sharp Blockwise Tensor Perturbation Bound for Orthogonal Iteration',
#   'authors': 'Yuetian Luo, Garvesh Raskutti, Ming Yuan, Anru R. Zhang',
#   'journal_num': '(179):1−48, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/20-919.html',
#   'pdf': 'https://jmlr.org/papers/volume22/20-919/20-919.pdf',
#   'bib': 'https://jmlr.org/papers/v22/20-919.bib'},
#  {'title': 'Improved Shrinkage Prediction under a Spiked Covariance Structure',
#   'authors': 'Trambak Banerjee, Gourab Mukherjee, Debashis Paul',
#   'journal_num': '(180):1−40, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/21-0006.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0006/21-0006.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0006.bib'},
#  {'title': 'Alibi Explain: Algorithms for Explaining Machine Learning Models',
#   'authors': 'Janis Klaise, Arnaud Van Looveren, Giovanni Vacanti, Alexandru Coca',
#   'journal_num': '(181):1−7, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/21-0017.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0017/21-0017.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0017.bib',
#   'code': 'https://github.com/SeldonIO/alibi'},
#  {'title': 'A Probabilistic Interpretation of Self-Paced Learning with Applications to Reinforcement Learning',
#   'authors': "Pascal Klink, Hany Abdulsamad, Boris Belousov, Carlo D'Eramo, Jan Peters, Joni Pajarinen",
#   'journal_num': '(182):1−52, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/21-0112.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0112/21-0112.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0112.bib',
#   'code': 'https://github.com/psclklnk/pspl-code'},
#  {'title': 'Benchmarking Unsupervised Object Representations for Video Sequences',
#   'authors': 'Marissa A. Weis, Kashyap Chitta, Yash Sharma, Wieland Brendel, Matthias Bethge, Andreas Geiger, Alexander S. Ecker',
#   'journal_num': '(183):1−61, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/21-0199.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0199/21-0199.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0199.bib',
#   'code': 'https://eckerlab.org/code/weis2021/'},
#  {'title': 'mlr3pipelines - Flexible Machine Learning Pipelines in R',
#   'authors': 'Martin Binder, Florian Pfisterer, Michel Lang, Lennart Schneider, Lars Kotthoff, Bernd Bischl',
#   'journal_num': '(184):1−7, 2021.  (Machine Learning Open Source Software Paper)',
#   'abs': 'https://jmlr.org/papers/v22/21-0281.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0281/21-0281.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0281.bib',
#   'code': 'https://github.com/mlr-org/mlr3pipelines'},
#  {'title': 'Mode-wise Tensor Decompositions: Multi-dimensional Generalizations of CUR Decompositions',
#   'authors': 'HanQin Cai, Keaton Hamm, Longxiu Huang, Deanna Needell',
#   'journal_num': '(185):1−36, 2021.',
#   'abs': 'https://jmlr.org/papers/v22/21-0287.html',
#   'pdf': 'https://jmlr.org/papers/volume22/21-0287/21-0287.pdf',
#   'bib': 'https://jmlr.org/papers/v22/21-0287.bib',
#   'code': 'https://github.com/caesarcai/Modewise_Tensor_Decomp'}]

# %%
def get_abstract_skills(paper):
    page = requests.get(paper['abs'], headers=random.choice(headers_list))
    if page.status_code != 200:
        return None
    soup = BeautifulSoup(page.content, 'html.parser')
    abstract = soup.find('p', class_='abstract').get_text().strip('\n')
    all_skills = extract_skills(paper['title'] + ' ' + abstract)
    keep_skills, _ = extract_ignore(all_skills)
    keep_skills.sort()
    return abstract, keep_skills

# %%
for paper in papers:
    output = get_abstract_skills(paper)
    if output is not None:
        paper['abstract'] = output[0]
        paper['skills'] = '; '.join(output[1])

# %%
df = pd.DataFrame.from_dict(papers)
df.head()
# Out:
#                                                title  \
# 0  On the Optimality of Kernel-Embedding Based Go...
# 1  Domain Generalization by Marginal Transfer Lea...
# 2  Regulating Greed Over Time in Multi-Armed Bandits
# 3  An Empirical Study of Bayesian Optimization: A...
# 4  The Decoupled Extended Kalman Filter for Dynam...
#
#                                              authors      journal_num  \
# 0   Krishnakumar Balasubramanian, Tong Li, Ming Yuan  (1):1−45, 2021.
# 1  Gilles Blanchard, Aniket Anand Deshmukh, Urun ...  (2):1−55, 2021.
# 2            Stefano Tracà, Cynthia Rudin, Weiyu Yan  (3):1−99, 2021.
# 3  Erich Merrill, Alan Fern, Xiaoli Fern, Nima Do...  (4):1−25, 2021.
# 4                Carlos A. Gomez-Uribe, Brian Karrer  (5):1−25, 2021.
#
#                                        abs  \
# 0  https://jmlr.org/papers/v22/17-570.html
# 1  https://jmlr.org/papers/v22/17-679.html
# 2  https://jmlr.org/papers/v22/17-720.html
# 3  https://jmlr.org/papers/v22/18-220.html
# 4  https://jmlr.org/papers/v22/18-417.html
#
#                                                  pdf  \
# 0  https://jmlr.org/papers/volume22/17-570/17-570...
# 1  https://jmlr.org/papers/volume22/17-679/17-679...
# 2  https://jmlr.org/papers/volume22/17-720/17-720...
# 3  https://jmlr.org/papers/volume22/18-220/18-220...
# 4  https://jmlr.org/papers/volume22/18-417/18-417...
#
#                                       bib  \
# 0  https://jmlr.org/papers/v22/17-570.bib
# 1  https://jmlr.org/papers/v22/17-679.bib
# 2  https://jmlr.org/papers/v22/17-720.bib
# 3  https://jmlr.org/papers/v22/18-220.bib
# 4  https://jmlr.org/papers/v22/18-417.bib
#
#                                             abstract  \
# 0  The reproducing kernel Hilbert space (RKHS) em...
# 1  In the problem of domain generalization (DG), ...
# 2  In retail, there are predictable yet dramatic ...
# 3  Bayesian optimization (BO) is a popular framew...
# 4  Motivated by the needs of online large-scale r...
#
#                                               skills  \
# 0                                            Testing
# 1  Algorithm; Analysis; Supervised Learning; Trai...
# 2  Algorithm; Analysis; Exploit; Retail; Sentry; ...
# 3  Accounting; Algorithm; Bayesian Optimization; ...
# 4                    Exploit; Modelling; Uncertainty
#
#                                                 code supplementary website  \
# 0                                                NaN           NaN     NaN
# 1  https://github.com/aniketde/DomainGeneralizati...           NaN     NaN
# 2  https://github.com/ShrekFelix/Regulating-Greed...           NaN     NaN
# 3                    https://github.com/Eiii/opt_cmp           NaN     NaN
# 4                                                NaN           NaN     NaN
#
#   blog
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
df.loc[df['skills'].isna()]
# Out:
# Empty DataFrame
# Columns: [title, authors, journal_num, abs, pdf, bib, abstract, skills, code, supplementary, website, blog]
# Index: []

# %%
df.to_csv('results/jmlr.csv', index=False)
